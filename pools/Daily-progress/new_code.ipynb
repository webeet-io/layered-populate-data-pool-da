# %%
import pandas as pd
import seaborn as sns  #load dataset
import numpy as np #statistical calculations
import matplotlib.pyplot as plt # for visualization
import psycopg2
from sqlalchemy import create_engine

# %%
df = pd.read_csv("pools_berlin_citymap.csv")

# %%
df.head()
# Out:
#    Bad-ID                              Name     Badtyp                 Straße  \
# 0     472                  Strandbad Lübars   Naturbad           Am Freibad 9
# 1     473     Kleine Schwimmhalle Wuhlheide  Hallenbad   An der Wuhlheide 161
# 2     474               Kombibad Mariendorf   Kombibad          Ankogelweg 95
# 3     475  Schwimmhalle Anton-Saefkow-Platz  Hallenbad  Anton-Saefkow-Platz 1
# 4     476  Stadtbad Kreuzberg - Baerwaldbad  Hallenbad   Baerwaldstraße 64-67
#
#    Postleitzahl     Ort  Breitengrad  Längengrad eu_badegewaesser  \
# 0         13469  Berlin     52.61824    13.33519              NaN
# 1         12459  Berlin     52.45993    13.53965             nein
# 2         12107  Berlin     52.41972    13.40154             nein
# 3         10369  Berlin     52.53093    13.47184             nein
# 4         10961  Berlin     52.49451    13.40432             nein
#
#    Öffnungsstunden pro Jahr  Baujahr Ganzjährig geöffnet Name des Eigentümers  \
# 0                       NaN      NaN                nein          Henry Arzig
# 1                       NaN   1990.0                  ja                  NaN
# 2                       NaN   1974.0                  ja                  NaN
# 3                       NaN   1980.0                  ja                  NaN
# 4                       NaN   1955.0                  ja         Förderverein
#
#   Ermäßigung Kind Ermäßigung Familie Ermäßigung Behinderte
# 0              ja                 ja                    ja
# 1              ja               nein                    ja
# 2              ja                 ja                    ja
# 3              ja               nein                   NaN
# 4              ja                 ja                    ja

# %%
df.describe()
# Out:
#              Bad-ID  Postleitzahl  Breitengrad  Längengrad  \
# count    144.000000    144.000000   144.000000  144.000000
# mean    5096.506944  12565.152778    52.494014   13.364897
# std     4010.713202   1276.171872     0.055093    0.138273
# min      472.000000  10115.000000    52.373220   13.114743
# 25%     1043.750000  12105.000000    52.445267   13.255845
# 50%     6987.500000  12573.000000    52.492320   13.350150
# 75%     8500.250000  13587.000000    52.539145   13.452025
# max    10510.000000  14199.000000    52.628680   13.735059
#
#        Öffnungsstunden pro Jahr      Baujahr
# count                       0.0    49.000000
# mean                        NaN  1960.877551
# std                         NaN    25.381779
# min                         NaN  1896.000000
# 25%                         NaN  1950.000000
# 50%                         NaN  1970.000000
# 75%                         NaN  1980.000000
# max                         NaN  2000.000000

# %%
df.shape
# Out:
# (144, 16)

# %%
# Map of German column names → English column names
rename_map = {
    'Bad-ID': 'pool_id',
    'Name': 'name',
    'Badtyp': 'pool_type',
    'Straße': 'street',
    'Postleitzahl': 'postal_code',
    'Ort': 'city',
    'Breitengrad': 'latitude',
    'Längengrad': 'longitude',
    'eu_badegewaesser': 'eu_bathing_water',
    'Öffnungsstunden pro Jahr': 'annual_opening_hours',
    'Baujahr': 'year_built',
    'Ganzjährig geöffnet': 'open_all_year',
    'Name des Eigentümers': 'owner_name',
    'Ermäßigung Kind': 'discount_children',
    'Ermäßigung Familie': 'discount_family',
    'Ermäßigung Behinderte': 'discount_disabled'
}

# %%
df.rename(columns=rename_map, inplace=True)

# %%
df.head()
# Out:
#    pool_id                              name  pool_type  \
# 0      472                  Strandbad Lübars   Naturbad
# 1      473     Kleine Schwimmhalle Wuhlheide  Hallenbad
# 2      474               Kombibad Mariendorf   Kombibad
# 3      475  Schwimmhalle Anton-Saefkow-Platz  Hallenbad
# 4      476  Stadtbad Kreuzberg - Baerwaldbad  Hallenbad
#
#                   street  postal_code    city  latitude  longitude  \
# 0           Am Freibad 9        13469  Berlin  52.61824   13.33519
# 1   An der Wuhlheide 161        12459  Berlin  52.45993   13.53965
# 2          Ankogelweg 95        12107  Berlin  52.41972   13.40154
# 3  Anton-Saefkow-Platz 1        10369  Berlin  52.53093   13.47184
# 4   Baerwaldstraße 64-67        10961  Berlin  52.49451   13.40432
#
#   eu_bathing_water  annual_opening_hours  year_built open_all_year  \
# 0              NaN                   NaN         NaN          nein
# 1             nein                   NaN      1990.0            ja
# 2             nein                   NaN      1974.0            ja
# 3             nein                   NaN      1980.0            ja
# 4             nein                   NaN      1955.0            ja
#
#      owner_name discount_children discount_family discount_disabled
# 0   Henry Arzig                ja              ja                ja
# 1           NaN                ja            nein                ja
# 2           NaN                ja              ja                ja
# 3           NaN                ja            nein               NaN
# 4  Förderverein                ja              ja                ja

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pool_id            144 non-null    int64
#  1   name               144 non-null    object
#  2   pool_type          144 non-null    object
#  3   street             141 non-null    object
#  4   postal_code        144 non-null    object
#  5   city               144 non-null    object
#  6   latitude           144 non-null    float64
#  7   longitude          144 non-null    float64
#  8   eu_bathing_water   111 non-null    object
#  9   year_built         49 non-null     float64
#  10  open_all_year      114 non-null    object
#  11  owner_name         63 non-null     object
#  12  discount_children  111 non-null    object
#  13  discount_family    108 non-null    object
#  14  discount_disabled  105 non-null    object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 17.0+ KB

# %%
# cleaning the data

df.duplicated(subset='pool_id').sum()  # checking for duplicate
# Out:
# np.int64(0)

# %%
df['postal_code'] = df['postal_code'].astype(str)
df['city'] = df['city'].str.title()

# %%
df

# Convert yes/no or German terms to Boolean
yes_values = ['Ja', 'Yes', 'yes', 'ja', True]
df['open_all_year'] = df['open_all_year'].apply(lambda x: True if x in yes_values else False)

# %%
df = df[(df['latitude'].between(-90, 90)) & (df['longitude'].between(-180, 180))]

# %%
mapping_cols = [
    'pool_id', 'name', 'pool_type', 'street', 'postal_code', 'city',
    'latitude', 'longitude', 'open_all_year'
]
df = df[mapping_cols]

# %%
df['street'] = df['street'].fillna("Unknown")

# %%
df.head()
# Out:
#    pool_id                              name  pool_type  \
# 0      472                  Strandbad Lübars   Naturbad
# 1      473     Kleine Schwimmhalle Wuhlheide  Hallenbad
# 2      474               Kombibad Mariendorf   Kombibad
# 3      475  Schwimmhalle Anton-Saefkow-Platz  Hallenbad
# 4      476  Stadtbad Kreuzberg - Baerwaldbad  Hallenbad
#
#                   street postal_code    city  latitude  longitude  \
# 0           Am Freibad 9       13469  Berlin  52.61824   13.33519
# 1   An der Wuhlheide 161       12459  Berlin  52.45993   13.53965
# 2          Ankogelweg 95       12107  Berlin  52.41972   13.40154
# 3  Anton-Saefkow-Platz 1       10369  Berlin  52.53093   13.47184
# 4   Baerwaldstraße 64-67       10961  Berlin  52.49451   13.40432
#
#    open_all_year
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True

# %%
df.to_csv("berlin_pools_clean.csv", index=False)
