# %% [markdown]
# ## Populating_DB_Playgrounds:

# %%
import pandas as pd
import numpy as np
import psycopg2 
from sqlalchemy import create_engine, text
import warnings
warnings.filterwarnings("ignore")

from geopy.geocoders import Nominatim 
import time

# %%
# SQLAlchemy connection string format:
# postgresql+psycopg2://user:password@host:port/dbname
# Create engine and establish connection

DATABASE_URL = (
    "postgresql+psycopg2://neondb_owner:npg_CeS9fJg2azZD"
    "@ep-falling-glitter-a5m0j5gk-pooler.us-east-2.aws.neon.tech:5432/neondb"
    "?sslmode=require"
)


engine = create_engine(DATABASE_URL)

# %%
## Creating a new table:

with engine.begin() as conn:
    conn.execute(text("""
    CREATE TABLE IF NOT EXISTS test_berlin_data.playgrounds (
    technical_id VARCHAR(100) UNIQUE NOT NULL,
    key VARCHAR(50) UNIQUE NOT NULL,
    object_number VARCHAR(100),
    district  VARCHAR(100) NOT NULL, 
    neighborhood  VARCHAR(100),
    green_area_type VARCHAR(100),
    playground_name VARCHAR(100) , 
    playground_suffix  VARCHAR(100), 
    year_built FLOAT,
    last_renovation_year FLOAT, 
    area_sqm FLOAT,
    dedication VARCHAR(100),
    planning_area_number FLOAT, 
    planning_area_name VARCHAR(100), 
    net_play_area_sqm FLOAT,
    full_address VARCHAR(200),
    latitude DECIMAL(9,6),
    longitude DECIMAL(9,6),
    FOREIGN KEY (district) REFERENCES test_berlin_data.neighborhood(neighborhood) ON DELETE RESTRICT ON UPDATE CASCADE
    )

"""))

# %%
df=pd.read_csv('../sources/playground_transformed.csv')

df.head()
# Out:
#         technical_id                key object_number              district  \
# 0  00008100_002f2c6b  00008100:002f2c6b         19441  Tempelhof-Schöneberg
# 1  00008100_0033cfac  00008100:0033cfac         35098         Reinickendorf
# 2  00008100_0032a99a  00008100:0032a99a        21AS10           Lichtenberg
# 3  00008100_00199411  00008100:00199411         00156   Marzahn-Hellersdorf
# 4  00008100_00281623  00008100:00281623        150072      Treptow-Köpenick
#
#   neighborhood green_area_type  \
# 0  Lichtenrade      Spielplatz
# 1        Tegel      Spielplatz
# 2  Lichtenberg      Spielplatz
# 3      Marzahn      Spielplatz
# 4  Schmöckwitz      Spielplatz
#
#                                    playground_name  \
# 0                                     Nuthestr. 26
# 1                        Borsigdamm 4 (Spielplatz)
# 2                         Gudrunstr. 14 Spielplatz
# 3         Hohenwalder/Schorfheider Straße -Dreieck
# 4  Biebersdorfer Weg 12/ Lübbenauer Weg 23 Sch KSP
#
# ...

# %%
df['district'].nunique()
# Out:
# 12

# %%
df.to_sql(name="playgrounds",
         con=engine,
         schema="test_berlin_data",
         if_exists= "append",
         index = False)
# Out:
# 879
