# %% [markdown]
# ###  Step 1: Research & Data Modelling
# PR Branch Name: clubs-data-modelling
#
# This notebook documents the process for Step 1 of the "Clubs & Social Activities in Berlin" project:
#
# - **1.1 Data Source Discovery**
# - **1.2 Modelling & Planning**
# - **1.3 Prepare the /sources Directory**
# - **1.4 Review**
#
# ---
#
# ###  Goal
# - Identify and document relevant data sources.
# - Select the key parameters for our use case.
# - Draft the planned table schema.
# - Plan cleaning and transformation steps before database population.
#
# ---
#
# ## 1.1 Data Source Discovery
#
# **Topic:** Clubs & Social Activities in Berlin
#
# **Main source:**
# - **Name:** OpenStreetMap (OSM) via OSMnx / Overpass API
# - **Source and origin:** Public crowdsourced geospatial database
# - **Update frequency:** Continuous (dynamic)
# - **Data type:** Dynamic (API query using tags such as `club=*`, `leisure=*`, `sport=*`, `community_centre=*`)
# - **Reason for selection:**
#   - Covers a wide variety of sports clubs, cultural clubs, and social activity centers in Berlin
#   - Includes geospatial data (coordinates, polygons), names, addresses, and attributes
#   - Open, free, and queryable programmatically
#
# **Optional additional sources:**
# - **Name:** Berliner Turn- und Freizeitsport-Bund (BTFB)  (https://btfb.de/vereinsservice/vereinssuche/#Vereine-im-Portrait)
#   - Source: Official Berlin sports association website
#   - Type: Static (manual export / scraping)
#   - Use: Provides official structured list of sports clubs in Berlin
#
# - **Name:** Berlin Open Data Portal (daten.berlin.de)
#   - Source: Berlin city government
#   - Type: Static or semi-static (CSV, GeoJSON)
#   - Use: Enrichment with official district boundaries or metadata
#
#   **Enrichment potential:**
# - Use Berlin shapefiles (districts, neighborhoods) for spatial joins.
#
#
# ---
#
# ## 1.2 Modelling & Planning
#
# **Key Parameters (planned):**
# - Identification: `name`, `club`, `category`, `subcategory`
# - Location: `address`, `district`, `geometry (lat/lon)`
# - Contact: `website`, `phone`, `email`
# - Attributes: `opening_hours`, `membership`, `fees`, `sport` / `leisure type`
# - Metadata: `source`, `last_updated`
#
# **Integration with existing tables:**
# - Join on `district_id` from the Berlin districts reference table.
#
#
# **Planned table schema:**
# ```sql
# CREATE TABLE berlin_clubs (
#     club_id SERIAL PRIMARY KEY,
#     name TEXT NOT NULL,
#     club TEXT,
#     leisure TEXT,
#     sport TEXT,
#     amenity TEXT,
#     street TEXT,
#     housenumber TEXT,
#     postcode TEXT,
#     district TEXT,
#     city TEXT,
#     country TEXT,
#     district_id INT REFERENCES berlin_districts(district_id),
#     latitude FLOAT NOT NULL,
#     longitude FLOAT NOT NULL,
#     website TEXT,
#     phone TEXT,
#     email TEXT,
#     opening_hours TEXT,
#     wheelchair TEXT
# );

# %%
# Install Libraries

# !pip install osmnx geopandas

# %%
# Import Libraries

import osmnx as ox
import geopandas as gpd
import pandas as pd

# %%
ox.settings.use_cache = False

# %%
# Define multiple tags
# tags = {
    # "amenity": ["community_centre", "arts_centre", "youth_centre", "music_school"],
    # "leisure": ["sports_centre", "fitness_centre", "dance"],
    # "club": True  # will capture all club types
# }
tags = {
    "amenity": [
        "community_centre", "arts_centre", "social_centre", 
        "youth_centre", "social_club", "music_school","events_venue",
        "music_venue", 
        "dojo", "dancing_school","studio",
        "theatre"
    ],
    "leisure": [
       "sports_centre", "fitness_centre", "dance", 
        "hackerspace", "music_venue", "garden"
    ],
   "club": True 
}
clubs_gdf = ox.features_from_place("Berlin, Germany", tags)

print(clubs_gdf.head())
print(len(clubs_gdf), "clubs/activities found in Berlin")
# Out:
#                                    geometry       amenity     contact:phone  \
# element id
# node    30012753  POINT (13.42919 52.49404)  events_venue  +49 30 338402320
#         60775321  POINT (13.48162 52.53862)           NaN               NaN
#         66917094  POINT (13.38888 52.52392)       theatre               NaN
#         66917098  POINT (13.38862 52.52362)       theatre   +49 30 27879030
#         66917115  POINT (13.38851 52.52067)       theatre   +49 30 203000-0
#
#                                        contact:website  \
# element id
# node    30012753  http://www.umspannwerk-kreuzberg.de/
#         60775321                                   NaN
#         66917094                                   NaN
#         66917098                                   NaN
#         66917115                                   NaN
#
#                                      name wheelchair addr:housenumber  \
# element id
# node    30012753              Umspannwerk        yes              NaN
#         60775321                     KW76        NaN               76
#         66917094    Friedrichstadt-Palast        yes              107
#         66917098      Quatsch Comedy Club    limited              107
#         66917115  Kabarett-Theater Distel        yes              101
#
#                          addr:street   club addr:city  ... name:it nickname  \
# element id                                             ...
# node    30012753                 NaN    NaN       NaN  ...     NaN      NaN
#         60775321  Konrad-Wolf-Straße  poker       NaN  ...     NaN      NaN
#         66917094     Friedrichstraße    NaN    Berlin  ...     NaN      NaN
#         66917098     Friedrichstraße    NaN    Berlin  ...     NaN      NaN
#         66917115     Friedrichstraße    NaN    Berlin  ...     NaN      NaN
#
#                  construction manufacturer monitoring:harvesting type  \
# element id
# node    30012753          NaN          NaN                   NaN  NaN
#         60775321          NaN          NaN                   NaN  NaN
#         66917094          NaN          NaN                   NaN  NaN
#         66917098          NaN          NaN                   NaN  NaN
#         66917115          NaN          NaN                   NaN  NaN
#
#                  not:name length maxdepth communication:amateur_radio:pota
# element id
# node    30012753      NaN    NaN      NaN                              NaN
#         60775321      NaN    NaN      NaN                              NaN
#         66917094      NaN    NaN      NaN                              NaN
#         66917098      NaN    NaN      NaN                              NaN
#         66917115      NaN    NaN      NaN                              NaN
#
# [5 rows x 473 columns]
# 6495 clubs/activities found in Berlin

# %%
clubs_gdf = clubs_gdf.to_crs(epsg=4326)

# %%
clubs_gdf['geometry'] = clubs_gdf['geometry'].apply(lambda geom: geom if geom.geom_type == 'Point' else geom.representative_point())
#Extract latitude and longitude
clubs_gdf["latitude"] = clubs_gdf.geometry.y
clubs_gdf["longitude"] = clubs_gdf.geometry.x
clubs_gdf
# Out:
#                                      geometry       amenity     contact:phone  \
# element id
# node    30012753    POINT (13.42919 52.49404)  events_venue  +49 30 338402320
#         60775321    POINT (13.48162 52.53862)           NaN               NaN
#         66917094    POINT (13.38888 52.52392)       theatre               NaN
#         66917098    POINT (13.38862 52.52362)       theatre   +49 30 27879030
#         66917115    POINT (13.38851 52.52067)       theatre   +49 30 203000-0
# ...                                       ...           ...               ...
# way     1428999282   POINT (13.3565 52.56115)           NaN               NaN
#         1428999283  POINT (13.35644 52.56128)           NaN               NaN
#         1428999284  POINT (13.35655 52.56104)           NaN               NaN
#         1429788653  POINT (13.42016 52.47043)           NaN               NaN
#         1429892018   POINT (13.4244 52.46842)           NaN               NaN
#
#                                          contact:website  \
# element id
# node    30012753    http://www.umspannwerk-kreuzberg.de/
#         60775321                                     NaN
#         66917094                                     NaN
#         66917098                                     NaN
#         66917115                                     NaN
# ...                                                  ...
# way     1428999282                                   NaN
#         1428999283                                   NaN
#         1428999284                                   NaN
#         1429788653                                   NaN
#         1429892018                                   NaN
#
#                                        name wheelchair addr:housenumber  \
# element id
# node    30012753                Umspannwerk        yes              NaN
#         60775321                       KW76        NaN               76
#         66917094      Friedrichstadt-Palast        yes              107
#         66917098        Quatsch Comedy Club    limited              107
#         66917115    Kabarett-Theater Distel        yes              101
# ...                                     ...        ...              ...
# way     1428999282                      NaN        NaN              NaN
#         1428999283                      NaN        NaN              NaN
#         1428999284                      NaN        NaN              NaN
#         1429788653                 Nanowald        NaN              NaN
#         1429892018                      NaN        NaN              NaN
#
#                            addr:street   club addr:city  ... construction  \
# element id                                               ...
# node    30012753                   NaN    NaN       NaN  ...          NaN
#         60775321    Konrad-Wolf-Straße  poker       NaN  ...          NaN
#         66917094       Friedrichstraße    NaN    Berlin  ...          NaN
#         66917098       Friedrichstraße    NaN    Berlin  ...          NaN
#         66917115       Friedrichstraße    NaN    Berlin  ...          NaN
# ...                                ...    ...       ...  ...          ...
# way     1428999282                 NaN    NaN       NaN  ...          NaN
#         1428999283                 NaN    NaN       NaN  ...          NaN
#         1428999284                 NaN    NaN       NaN  ...          NaN
#         1429788653                 NaN    NaN       NaN  ...          NaN
#         1429892018                 NaN    NaN       NaN  ...          NaN
#
#                    manufacturer monitoring:harvesting type not:name length  \
# element id
# node    30012753            NaN                   NaN  NaN      NaN    NaN
#         60775321            NaN                   NaN  NaN      NaN    NaN
#         66917094            NaN                   NaN  NaN      NaN    NaN
#         66917098            NaN                   NaN  NaN      NaN    NaN
#         66917115            NaN                   NaN  NaN      NaN    NaN
# ...                         ...                   ...  ...      ...    ...
# way     1428999282          NaN                   NaN  NaN      NaN    NaN
#         1428999283          NaN                   NaN  NaN      NaN    NaN
#         1428999284          NaN                   NaN  NaN      NaN    NaN
#         1429788653          NaN                   NaN  NaN      NaN    NaN
#         1429892018          NaN                   NaN  NaN      NaN    NaN
#
#                    maxdepth communication:amateur_radio:pota   latitude  \
# element id
# node    30012753        NaN                              NaN  52.494042
#         60775321        NaN                              NaN  52.538623
#         66917094        NaN                              NaN  52.523922
#         66917098        NaN                              NaN  52.523624
#         66917115        NaN                              NaN  52.520667
# ...                     ...                              ...        ...
# way     1428999282      NaN                              NaN  52.561152
#         1428999283      NaN                              NaN  52.561283
#         1428999284      NaN                              NaN  52.561039
#         1429788653      NaN                              NaN  52.470430
#         1429892018      NaN                              NaN  52.468417
#
#                     longitude
# element id
# node    30012753    13.429187
#         60775321    13.481623
#         66917094    13.388879
#         66917098    13.388621
#         66917115    13.388505
# ...                       ...
# way     1428999282  13.356499
#         1428999283  13.356439
#         1428999284  13.356547
#         1429788653  13.420161
#         1429892018  13.424398
#
# [6495 rows x 475 columns]

# %%
print(clubs_gdf.notnull().sum().sort_values(ascending=False).head(30))
# Out:
# geometry                6495
# latitude                6495
# longitude               6495
# leisure                 4633
# name                    3400
# garden:type             2168
# access                  2151
# addr:street             1926
# addr:housenumber        1910
# addr:postcode           1843
# addr:city               1800
# amenity                 1614
# addr:country            1298
# addr:suburb             1284
# website                 1237
# wheelchair              1071
# sport                    952
# operator                 904
# contact:website          772
# building                 761
# opening_hours            688
# check_date               535
# phone                    505
# community_centre         480
# contact:phone            435
# club                     384
# building:levels          334
# contact:email            308
# community_centre:for     308
# wikidata                 299
# dtype: int64

# %%
# Select important columns
important_cols = [
    "name",               
    "club",                 
    "leisure",             
    "sport",                
    "amenity",               
    "addr:street",           
    "addr:housenumber",
    "addr:suburb",      
    "addr:postcode",         
    "addr:city",
    "addr:country",            
    "website",              
    "phone",             
    "email",               
    "opening_hours",         
    "geometry" ,
    "wheelchair",
    "latitude",
    "longitude"              
]

# %%
clubs_df = clubs_gdf[important_cols].copy()

print(clubs_df.head(10))
# Out:
#                                       name   club leisure sport       amenity  \
# element id
# node    30012753               Umspannwerk    NaN     NaN   NaN  events_venue
#         60775321                      KW76  poker     NaN   NaN           NaN
#         66917094     Friedrichstadt-Palast    NaN     NaN   NaN       theatre
#         66917098       Quatsch Comedy Club    NaN     NaN   NaN       theatre
#         66917115   Kabarett-Theater Distel    NaN     NaN   NaN       theatre
#         66917188            Admiralspalast    NaN     NaN   NaN       theatre
#         79808389             Die Wühlmäuse    NaN     NaN   NaN       theatre
#         173985100   HAU 2 (Hebbel am Ufer)    NaN     NaN   NaN       theatre
#         229948256              Sophiensæle    NaN     NaN   NaN       theatre
#         257709121       Kulturhaus Spandau    NaN     NaN   NaN   arts_centre
#
#                           addr:street addr:housenumber addr:suburb  \
# element id
# node    30012753                  NaN              NaN         NaN
#         60775321   Konrad-Wolf-Straße               76         NaN
#         66917094      Friedrichstraße              107       Mitte
#         66917098      Friedrichstraße              107       Mitte
#         66917115      Friedrichstraße              101       Mitte
#         66917188      Friedrichstraße              101       Mitte
#         79808389         Pommernallee              2-4     Westend
#         173985100     Hallesches Ufer               34   Kreuzberg
#         229948256       Sophienstraße               18       Mitte
#         257709121                 NaN              NaN         NaN
#
#                   addr:postcode addr:city addr:country  \
# element id
# node    30012753            NaN       NaN          NaN
#         60775321            NaN       NaN          NaN
#         66917094          10117    Berlin           DE
#         66917098          10117    Berlin           DE
#         66917115          10117    Berlin           DE
#         66917188          10117    Berlin           DE
#         79808389          14052    Berlin           DE
#         173985100         10963    Berlin           DE
#         229948256         10178    Berlin           DE
#         257709121           NaN       NaN          NaN
#
#                                                website            phone email  \
# element id
# node    30012753                                   NaN              NaN   NaN
#         60775321                                   NaN              NaN   NaN
#         66917094            https://www.palast.berlin/  +49 30 23262326   NaN
#         66917098   https://www.quatsch-comedy-club.de/              NaN   NaN
#         66917115           http://www.distel-berlin.de              NaN   NaN
#         66917188   https://www.admiralspalast.theater/              NaN   NaN
#         79808389                                   NaN              NaN   NaN
#         173985100       https://www.hebbel-am-ufer.de/              NaN   NaN
#         229948256                                  NaN              NaN   NaN
#         257709121                                  NaN              NaN   NaN
#
#                   opening_hours                   geometry wheelchair  \
# element id
# node    30012753            NaN  POINT (13.42919 52.49404)        yes
#         60775321            NaN  POINT (13.48162 52.53862)        NaN
#         66917094            NaN  POINT (13.38888 52.52392)        yes
#         66917098            NaN  POINT (13.38862 52.52362)    limited
#         66917115            NaN  POINT (13.38851 52.52067)        yes
#         66917188            NaN   POINT (13.3889 52.52077)    limited
#         79808389            NaN  POINT (13.27075 52.50887)        yes
#         173985100           NaN  POINT (13.38587 52.49911)        yes
#         229948256           NaN   POINT (13.4016 52.52588)        yes
#         257709121           NaN  POINT (13.20231 52.53548)        yes
#
#                     latitude  longitude
# element id
# node    30012753   52.494042  13.429187
#         60775321   52.538623  13.481623
#         66917094   52.523922  13.388879
#         66917098   52.523624  13.388621
#         66917115   52.520667  13.388505
#         66917188   52.520771  13.388902
#         79808389   52.508865  13.270751
#         173985100  52.499114  13.385872
#         229948256  52.525883  13.401602
#         257709121  52.535479  13.202312

# %%
# Rename map for only the columns that need renaming
rename_map = {
    "addr:street": "street",
    "addr:housenumber": "housenumber",
    "addr:postcode": "postcode",
    "addr:city": "city",
    "addr:country": "country",
    "addr:suburb": "district"
}

# %%
# Rename the columns
clubs_df = clubs_df.rename(columns=rename_map)

# %%
clubs_df.head()
# Out:
#                                      name   club leisure sport       amenity  \
# element id
# node    30012753              Umspannwerk    NaN     NaN   NaN  events_venue
#         60775321                     KW76  poker     NaN   NaN           NaN
#         66917094    Friedrichstadt-Palast    NaN     NaN   NaN       theatre
#         66917098      Quatsch Comedy Club    NaN     NaN   NaN       theatre
#         66917115  Kabarett-Theater Distel    NaN     NaN   NaN       theatre
#
#                               street housenumber district postcode    city  \
# element id
# node    30012753                 NaN         NaN      NaN      NaN     NaN
#         60775321  Konrad-Wolf-Straße          76      NaN      NaN     NaN
#         66917094     Friedrichstraße         107    Mitte    10117  Berlin
#         66917098     Friedrichstraße         107    Mitte    10117  Berlin
#         66917115     Friedrichstraße         101    Mitte    10117  Berlin
#
#                  country                              website  \
# element id
# node    30012753     NaN                                  NaN
#         60775321     NaN                                  NaN
#         66917094      DE           https://www.palast.berlin/
#         66917098      DE  https://www.quatsch-comedy-club.de/
#         66917115      DE          http://www.distel-berlin.de
#
#                             phone email opening_hours  \
# element id
# node    30012753              NaN   NaN           NaN
#         60775321              NaN   NaN           NaN
#         66917094  +49 30 23262326   NaN           NaN
#         66917098              NaN   NaN           NaN
#         66917115              NaN   NaN           NaN
#
#                                    geometry wheelchair   latitude  longitude
# element id
# node    30012753  POINT (13.42919 52.49404)        yes  52.494042  13.429187
#         60775321  POINT (13.48162 52.53862)        NaN  52.538623  13.481623
#         66917094  POINT (13.38888 52.52392)        yes  52.523922  13.388879
#         66917098  POINT (13.38862 52.52362)    limited  52.523624  13.388621
#         66917115  POINT (13.38851 52.52067)        yes  52.520667  13.388505

# %%
for col in [ "name", "club", "leisure", "sport", "amenity"]:
    print(f"\n--- {col.upper()} ---")
    print(clubs_df[col].dropna().unique())
# Out:
# --- NAME ---
# ['Umspannwerk' 'KW76' 'Friedrichstadt-Palast' ... 'Gemeinschaftsbeet'
#  'Hochbeet Annie Heuser Waldorfschule'
#  'Begegnungszentrum im Kölner Viertel']
#
# --- CLUB ---
# ['poker' 'scout' 'sport' 'social' 'yes' 'dance' 'amateur_radio'
#  'automobile' 'fishing' 'Körperschaft_des_Öffentlichen_Rechts' 'culture'
#  'fan' 'animals' 'elderly' 'bonsai' 'dog' 'freemasonry' 'student'
#  'business' 'game' 'music' 'ethnic' 'Agrarbörse Deutschland Ost' 'linux'
#  'history' 'education' 'computer' 'religion' 'art' 'politics'
#  'board_games' 'youth_movement' 'archive' 'chess' 'sailing' 'science'
#  'humanist' 'charity' 'nature' 'hdk_0' 'youth' 'academic' 'motorcycle'
#  'allotment_club' 'allotments' 'TC Berolina Biesdorf' 'gardening']
#
# --- LEISURE ---
# ['hackerspace' 'fitness_centre' 'sports_centre' 'garden' 'dance'
#  'music_venue' 'pitch' 'playground' 'stadium' 'ice_rink' 'marina' 'track']
#
# --- SPORT ---
# ['bowling' '10pin' 'rowing' 'fitness' 'soccer' 'yoga' 'pilates'
#  'gymnastics' 'hapkido' 'karate' 'swimming' 'kung_fu'
#  'fitness;weightlifting;yoga' 'athletics;fitness;multi' 'sailing'
#  'cycling' 'karting' 'dance' 'multi' 'fitness;gymnastics;exercise'
#  'martial_art' 'judo' 'equestrian' 'scuba_diving' 'martial_arts' 'aikido'
#  'taijiquan' 'taekwondo' 'tennis' 'table_tennis' 'dancing' 'darts'
#  'climbing_adventure' 'gymnastics;fitness' 'tai_chi' 'martial_arts;judo'
#  'handball;athletics;basketball;triatlon;volleyball;gymnastics;water_sports;dance;9pin;fistball'
#  'climbing' 'kung_fu;taijiquan;qigong' 'poledance' 'karate;jiu-jitsu'
#  'budo' 'ems' 'boxing;kickboxing;wendo' 'bowling;table_tennis;badminton'
#  'yoga;pilates' 'rugby_union' 'chess' 'dance;dancing;fitness' 'kickboxing'
#  'taijiquan;qigong' 'axe_throwing' 'shooting' 'yoga;capoeira'
#  'tennis;ice_hockey' 'boxing' 'archery;shooting' 'baseball'
#  'martial_arts;self_defense' 'yoga;dance' 'aikido;kenjutsu;zen'
#  'bouldering' 'pole_dance' 'wingtsun' 'krav_maga' 'aikido;qigong'
#  'taekwondo;jiu-jitsu;judo;kickboxing' 'jiu-jitsu' 'fitness;climbing'
#  'bicycle' 'shuffleboard'
#  'fitness;karate;kickboxing;kempo;arnis;kobudo;strength;selfdefense;personaltraining'
#  'judo;karate;aikido;kickboxing' 'fitness;dancing;martial_arts'
#  'volleyball;basketball;badminton;table_tennis;gymnastics;handball;soccer'
#  'wingtsun;escrima' 'fitness;gym'
#  'fitness;basketball;handball;volleyball;orienteering;table_tennis;dancing;dance;gymnastics'
#  'archery' 'bodybuilding;fitness' 'fitness;crossfit' 'aikido;kendo'
#  'rehasport;kinderkarate;yoga;shotokan;kindertanz;ballett' 'basketball'
#  'ems;power_plate' 'fitness;weightlifting' 'arrow_tag' 'laser_tag'
#  'snooker' 'crossfit;martial_arts;hyrox;hiit' 'volleyball'
#  'multi;yoga;fitness;running;swimming' 'canoe' 'taekwondo;aikido' 'padel'
#  'quadball;quidditch' 'yoga;fitness'
#  'aikido;kummooyeh;taekwondo;tai_chi;self_defense'
#  'martial_arts,kung_fu,wingtsun' 'kayak' 'kendo'
#  'athletics; handball; chess; gymnastics' 'climbing;bouldering'
#  'beachvolleyball;soccer' 'roller_hockey;roller_derby' 'ice_skating'
#  'soccer;field_hockey;rugby;athletics' 'soccer;hockey' 'surfing'
#  'field_hockey' 'swimming;tennis;badminton' 'squash' 'athletics'
#  'skateboard' 'paddle_tennis' 'gym' 'bowls'
#  'squash;9pin;badminton;table_tennis;billiard;dart' 'soccer;tennis' '9pin'
#  'soccer;basketball' 'canoe;sailing'
#  'Karatedo Doshinkan;Serrada Escrima;Judo;Kung Fu;Karate;Bauchtanz;Boxen;Kick-Boxen'
#  'rowing;sailing'
#  'tennis;fitness;badminton;beachvolleyball;table_tennis;soccer'
#  'miniature_golf' 'boules' 'canoeing' 'hockey;tennis' 'boating' 'fishing'
#  'fitness;table_tennis;gymnastics' 'rowing;scuba_diving;sailing' 'bmx'
#  'beachvolleyball' 'soccer;athletics' 'cycling;swimming'
#  'softball;baseball' 'bmx;mtb']
#
# --- AMENITY ---
# ['events_venue' 'theatre' 'arts_centre' 'community_centre' 'social_centre'
#  'studio' 'dojo' 'music_school' 'pub' 'nightclub' 'dancing_school' 'cafe'
#  'restaurant' 'music_venue' 'bicycle_parking' 'photo_booth' 'school'
#  'social_club']

# %%
print(clubs_df["amenity"].unique())
# Out:
# ['events_venue' nan 'theatre' 'arts_centre' 'community_centre'
#  'social_centre' 'studio' 'dojo' 'music_school' 'pub' 'nightclub'
#  'dancing_school' 'cafe' 'restaurant' 'music_venue' 'bicycle_parking'
#  'photo_booth' 'school' 'social_club']

# %%
# Define lists of allowed values for 'amenity' and 'leisure' categories
# Keep only rows that match these categories or have a non-empty 'club' field
# This filters out irrelevant OSM features like restaurants, pubs, etc.
allowed_amenities = [
    'arts_centre', 'community_centre', 'events_venue', 'music_venue',
    'social_centre', 'studio', 'dojo', 'music_school',
    'social_club', 'dancing_school'
]

allowed_leisure = [
    'hackerspace' 'fitness_centre' 'sports_centre' 'garden' 'dance'
 'music_venue' 'pitch' 'playground' 'stadium' 'ice_rink' 'marina' 'track'
]



clubs_df = clubs_df[
    (clubs_df['amenity'].isin(allowed_amenities)) |
    (clubs_df['leisure'].isin(allowed_leisure)) |
    (clubs_df['club'].notna())
]

exclude = ["theatre", "pub", "cafe", "bar", "nightclub", "restaurant"]
clubs_df = clubs_df[~clubs_df["amenity"].isin(exclude)]

print(clubs_df[['name', 'amenity', 'leisure', 'club']].head())
print(len(clubs_df), "clubs/activities after filtering")
# Out:
#                                    name           amenity leisure   club
# element id
# node    30012753            Umspannwerk      events_venue     NaN    NaN
#         60775321                   KW76               NaN     NaN  poker
#         257709121    Kulturhaus Spandau       arts_centre     NaN    NaN
#         266630320  Buergeramt Mahlsdorf  community_centre     NaN    NaN
#         268915262           Karame e.V.  community_centre     NaN    NaN
# 1731 clubs/activities after filtering

# %%
# Check for unwanted values in 'amenity' column
check_values = ["theatre", "pub", "cafe", "bar", "nightclub", "restaurant"]


if "amenity" in clubs_df.columns:
    found = clubs_df["amenity"].dropna().unique()
    print("Unique amenity values currently in the dataset:")
    print(found)

    
    unwanted = set(found).intersection(check_values)
    if unwanted:
        print("\n⚠️ Unwanted values found:", unwanted)
    else:
        print("\n✅ No unwanted values present in 'amenity'.")
else:
    print("No 'amenity' column found in dataset.")
# Out:
# Unique amenity values currently in the dataset:
# ['events_venue' 'arts_centre' 'community_centre' 'social_centre' 'studio'
#  'dojo' 'music_school' 'dancing_school' 'music_venue' 'photo_booth'
#  'social_club']
#
# ✅ No unwanted values present in 'amenity'.

# %%
clubs_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# MultiIndex: 1731 entries, ('node', np.int64(30012753)) to ('way', np.int64(1423837870))
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1685 non-null   object
#  1   club           379 non-null    object
#  2   leisure        63 non-null     object
#  3   sport          226 non-null    object
#  4   amenity        1401 non-null   object
#  5   street         1124 non-null   object
#  6   housenumber    1114 non-null   object
#  7   district       738 non-null    object
#  8   postcode       1072 non-null   object
#  9   city           1057 non-null   object
#  10  country        744 non-null    object
#  11  website        717 non-null    object
#  12  phone          282 non-null    object
#  13  email          174 non-null    object
#  14  opening_hours  374 non-null    object
#  15  geometry       1731 non-null   geometry
#  16  wheelchair     457 non-null    object
#  17  latitude       1731 non-null   float64
#  18  longitude      1731 non-null   float64
# dtypes: float64(2), geometry(1), object(16)
# memory usage: 574.3+ KB

# %%
clubs_df = clubs_df.drop_duplicates()
clubs_df = clubs_df.drop_duplicates(subset=['name', 'street', 'housenumber'])
clubs_df = clubs_df.dropna(subset=['name', 'geometry'])

# %%
clubs_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# MultiIndex: 1658 entries, ('node', np.int64(30012753)) to ('way', np.int64(1423837870))
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1658 non-null   object
#  1   club           345 non-null    object
#  2   leisure        62 non-null     object
#  3   sport          215 non-null    object
#  4   amenity        1356 non-null   object
#  5   street         1105 non-null   object
#  6   housenumber    1095 non-null   object
#  7   district       730 non-null    object
#  8   postcode       1056 non-null   object
#  9   city           1042 non-null   object
#  10  country        736 non-null    object
#  11  website        703 non-null    object
#  12  phone          279 non-null    object
#  13  email          173 non-null    object
#  14  opening_hours  369 non-null    object
#  15  geometry       1658 non-null   geometry
#  16  wheelchair     455 non-null    object
#  17  latitude       1658 non-null   float64
#  18  longitude      1658 non-null   float64
# dtypes: float64(2), geometry(1), object(16)
# memory usage: 563.2+ KB

# %%
clubs_df.head()
# Out:
#                                    name   club leisure sport  \
# element id
# node    30012753            Umspannwerk    NaN     NaN   NaN
#         60775321                   KW76  poker     NaN   NaN
#         257709121    Kulturhaus Spandau    NaN     NaN   NaN
#         266630320  Buergeramt Mahlsdorf    NaN     NaN   NaN
#         268915262           Karame e.V.    NaN     NaN   NaN
#
#                             amenity                  street housenumber  \
# element id
# node    30012753       events_venue                     NaN         NaN
#         60775321                NaN      Konrad-Wolf-Straße          76
#         257709121       arts_centre                     NaN         NaN
#         266630320  community_centre          Hönower Straße          91
#         268915262  community_centre  Wilhelmshavener Straße          22
#
#                     district postcode    city country website phone email  \
# element id
# node    30012753         NaN      NaN     NaN     NaN     NaN   NaN   NaN
#         60775321         NaN      NaN     NaN     NaN     NaN   NaN   NaN
#         257709121        NaN      NaN     NaN     NaN     NaN   NaN   NaN
#         266630320  Mahlsdorf    12623  Berlin      DE     NaN   NaN   NaN
#         268915262     Moabit    10551  Berlin      DE     NaN   NaN   NaN
#
#                                      opening_hours                   geometry  \
# element id
# node    30012753                               NaN  POINT (13.42919 52.49404)
#         60775321                               NaN  POINT (13.48162 52.53862)
#         257709121                              NaN  POINT (13.20231 52.53548)
#         266630320                              NaN  POINT (13.61206 52.51314)
#         268915262  Mo-Fr 13:00-18:00; Sa-Su,PH off    POINT (13.34154 52.531)
#
#                   wheelchair   latitude  longitude
# element id
# node    30012753         yes  52.494042  13.429187
#         60775321         NaN  52.538623  13.481623
#         257709121        yes  52.535479  13.202312
#         266630320        yes  52.513140  13.612063
#         268915262         no  52.531002  13.341544

# %% [markdown]
# ## Geometry sanity checks

# %%
print("Missing geometries:", clubs_df.geometry.isna().sum())
# Out:
# Missing geometries: 0

# %%
# Goal: Verify lat/lon look realistic.
# Why? If values are way off, something went wrong in conversion.

print("Latitude range:", clubs_df["latitude"].min(), "to", clubs_df["latitude"].max())

print("Longitude range:", clubs_df["longitude"].min(), "to", clubs_df["longitude"].max())
# Out:
# Latitude range: 52.37387955 to 52.6448252
# Longitude range: 13.12237797012892 to 13.7311336

# %% [markdown]
# ## 1.3 Prepare the /sources Directory
# ### Raw Data Files:
#
# - **clubs_raw.geojson** (includes geometry)
# - **clubs_raw.csv** (tabular only, no geometry)
# - **README.md** in /sources will contain:
#
# **Data sources used.**
# **Planned transformation steps.**

# %%
# Save locally
clubs_gdf.to_file("clubs_raw.geojson", driver="GeoJSON")
clubs_gdf.to_csv("clubs_raw.csv", index=False)

# %% [markdown]
# ### Step 2: Data Transformation

# %%
# Standardize column names

clubs_df.columns = clubs_df.columns.str.lower().str.strip().str.replace(" ", "_").str.replace("-", "_")

# Normalize yes/no columns into Boolean (True/False)

clubs_df["wheelchair"] = clubs_df["wheelchair"].map({"yes": True, "no": False})

# %%
print(clubs_df.dtypes)
# Out:
# name               object
# club               object
# leisure            object
# sport              object
# amenity            object
# street             object
# housenumber        object
# district           object
# postcode           object
# city               object
# country            object
# website            object
# phone              object
# email              object
# opening_hours      object
# geometry         geometry
# wheelchair         object
# latitude          float64
# longitude         float64
# dtype: object

# %% [markdown]
# ## Drop irrelevant / redundant columns

# %%
clubs_df.drop(columns=["city","district" ,"country"], inplace=True)

# %% [markdown]
# ## Normalize categories

# %%
clubs_df["wheelchair"] = clubs_df["wheelchair"].fillna("unknown").astype(str).str.strip().str.lower()

# %%
clubs_df["opening_hours"] = clubs_df["opening_hours"].fillna("unknown").astype(str).str.strip().str.lower()

# %%
clubs_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# MultiIndex: 1658 entries, ('node', np.int64(30012753)) to ('way', np.int64(1423837870))
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1658 non-null   object
#  1   club           345 non-null    object
#  2   leisure        62 non-null     object
#  3   sport          215 non-null    object
#  4   amenity        1356 non-null   object
#  5   street         1105 non-null   object
#  6   housenumber    1095 non-null   object
#  7   postcode       1056 non-null   object
#  8   website        703 non-null    object
#  9   phone          279 non-null    object
#  10  email          173 non-null    object
#  11  opening_hours  1658 non-null   object
#  12  geometry       1658 non-null   geometry
#  13  wheelchair     1658 non-null   object
#  14  latitude       1658 non-null   float64
#  15  longitude      1658 non-null   float64
# dtypes: float64(2), geometry(1), object(13)
# memory usage: 524.4+ KB

# %%
clubs_df.head()
# Out:
#                                    name   club leisure sport  \
# element id
# node    30012753            Umspannwerk    NaN     NaN   NaN
#         60775321                   KW76  poker     NaN   NaN
#         257709121    Kulturhaus Spandau    NaN     NaN   NaN
#         266630320  Buergeramt Mahlsdorf    NaN     NaN   NaN
#         268915262           Karame e.V.    NaN     NaN   NaN
#
#                             amenity                  street housenumber  \
# element id
# node    30012753       events_venue                     NaN         NaN
#         60775321                NaN      Konrad-Wolf-Straße          76
#         257709121       arts_centre                     NaN         NaN
#         266630320  community_centre          Hönower Straße          91
#         268915262  community_centre  Wilhelmshavener Straße          22
#
#                   postcode website phone email  \
# element id
# node    30012753       NaN     NaN   NaN   NaN
#         60775321       NaN     NaN   NaN   NaN
#         257709121      NaN     NaN   NaN   NaN
#         266630320    12623     NaN   NaN   NaN
#         268915262    10551     NaN   NaN   NaN
#
#                                      opening_hours                   geometry  \
# element id
# node    30012753                           unknown  POINT (13.42919 52.49404)
#         60775321                           unknown  POINT (13.48162 52.53862)
#         257709121                          unknown  POINT (13.20231 52.53548)
#         266630320                          unknown  POINT (13.61206 52.51314)
#         268915262  mo-fr 13:00-18:00; sa-su,ph off    POINT (13.34154 52.531)
#
#                   wheelchair   latitude  longitude
# element id
# node    30012753        true  52.494042  13.429187
#         60775321     unknown  52.538623  13.481623
#         257709121       true  52.535479  13.202312
#         266630320       true  52.513140  13.612063
#         268915262      false  52.531002  13.341544

# %% [markdown]
# ### Add district and district_id to the data frame

# %%
# conda install -c conda-forge geopy

# %%
import geopandas as gpd

gdf_clubs = gpd.GeoDataFrame(
    clubs_df,  # assumes you already built df_unique with station_id
    geometry=gpd.points_from_xy(clubs_df.longitude, clubs_df.latitude),
    crs="EPSG:4326"
)


neighborhoods = gpd.read_file(
    "lor_ortsteile.geojson"
).to_crs("EPSG:4326")


#harmonizing column names coming from the GeoJSON
neighborhoods = neighborhoods.rename(columns={
    "BEZIRK": "district",
    "OTEIL": "neighborhood",
    "spatial_name": "neighborhood_id"
})

gdf_with_districts = gpd.sjoin(
    gdf_clubs,
    neighborhoods[["district", "neighborhood_id", "neighborhood", "geometry"]],
    how="left",
    predicate="within"
)

df_final = gdf_with_districts.drop(columns=["index_right"])

# %%
df_final = df_final.reset_index()

# Rename the "id" column to "club_id"

df_final = df_final.rename(columns={"id": "club_id"})

# Change bank_id column type to string

df_final["club_id"] = df_final["club_id"].astype(str)

# %%
df_final.head()
# Out:
#   element    club_id                  name   club leisure sport  \
# 0    node   30012753           Umspannwerk    NaN     NaN   NaN
# 1    node   60775321                  KW76  poker     NaN   NaN
# 2    node  257709121    Kulturhaus Spandau    NaN     NaN   NaN
# 3    node  266630320  Buergeramt Mahlsdorf    NaN     NaN   NaN
# 4    node  268915262           Karame e.V.    NaN     NaN   NaN
#
#             amenity                  street housenumber postcode  ... phone  \
# 0      events_venue                     NaN         NaN      NaN  ...   NaN
# 1               NaN      Konrad-Wolf-Straße          76      NaN  ...   NaN
# 2       arts_centre                     NaN         NaN      NaN  ...   NaN
# 3  community_centre          Hönower Straße          91    12623  ...   NaN
# 4  community_centre  Wilhelmshavener Straße          22    10551  ...   NaN
#
#   email                    opening_hours                   geometry  \
# 0   NaN                          unknown  POINT (13.42919 52.49404)
# 1   NaN                          unknown  POINT (13.48162 52.53862)
# 2   NaN                          unknown  POINT (13.20231 52.53548)
# 3   NaN                          unknown  POINT (13.61206 52.51314)
# 4   NaN  mo-fr 13:00-18:00; sa-su,ph off    POINT (13.34154 52.531)
#
#   wheelchair   latitude  longitude                  district neighborhood_id  \
# 0       true  52.494042  13.429187  Friedrichshain-Kreuzberg            0202
# 1    unknown  52.538623  13.481623               Lichtenberg            1110
# 2       true  52.535479  13.202312                   Spandau            0501
# 3       true  52.513140  13.612063       Marzahn-Hellersdorf            1004
# 4      false  52.531002  13.341544                     Mitte            0102
#
#            neighborhood
# 0             Kreuzberg
# 1  Alt-Hohenschönhausen
# 2               Spandau
# 3             Mahlsdorf
# 4                Moabit
#
# [5 rows x 21 columns]

# %%
# Reverse Geolocation
import requests
import time

def get_address(lat, lon):
    """Retrieve full formatted address from Nominatim"""
    url = "https://nominatim.openstreetmap.org/reverse"
    params = {"lat": lat, "lon": lon, "format": "json", "addressdetails": 1}
    headers = {"User-Agent": "berlin-venues-scraper/1.0"}
    try:
        r = requests.get(url, params=params, headers=headers, timeout=10)
        r.raise_for_status()
        data = r.json()
        return data.get("display_name")
    except requests.exceptions.RequestException as e:
        logging.warning(f"Error fetching address for ({lat}, {lon}): {e}")
        return None

# Apply reverse geolocation with throttling (to respect Nominatim usage policy)
full_addresses = []
for i, row in df_final.iterrows():
    print(f"fetching missing data for {i}")
    lat, lon = row["latitude"], row["longitude"]
    if pd.notna(lat) and pd.notna(lon):
        
        full_addresses.append(get_address(lat, lon))
        time.sleep(1)  # polite delay between requests
    else:
        
        full_addresses.append(None)


df_final["full_address"] = full_addresses
# Out:
# fetching missing data for 0
# fetching missing data for 1
# fetching missing data for 2
# fetching missing data for 3
# fetching missing data for 4
# fetching missing data for 5
# fetching missing data for 6
# fetching missing data for 7
# fetching missing data for 8
# fetching missing data for 9
# fetching missing data for 10
# fetching missing data for 11
# fetching missing data for 12
# fetching missing data for 13
# fetching missing data for 14
# fetching missing data for 15
# fetching missing data for 16
# fetching missing data for 17
# fetching missing data for 18
# fetching missing data for 19
# fetching missing data for 20
# fetching missing data for 21
# fetching missing data for 22
# fetching missing data for 23
# fetching missing data for 24
# fetching missing data for 25
# fetching missing data for 26
# fetching missing data for 27
# fetching missing data for 28
# fetching missing data for 29
# fetching missing data for 30
# fetching missing data for 31
# fetching missing data for 32
# fetching missing data for 33
# fetching missing data for 34
# fetching missing data for 35
# fetching missing data for 36
# fetching missing data for 37
# fetching missing data for 38
# fetching missing data for 39
# fetching missing data for 40
# fetching missing data for 41
# fetching missing data for 42
# fetching missing data for 43
# fetching missing data for 44
# fetching missing data for 45
# fetching missing data for 46
# fetching missing data for 47
# fetching missing data for 48
# fetching missing data for 49
# fetching missing data for 50
# fetching missing data for 51
# fetching missing data for 52
# fetching missing data for 53
# fetching missing data for 54
# fetching missing data for 55
# fetching missing data for 56
# fetching missing data for 57
# fetching missing data for 58
# fetching missing data for 59
# fetching missing data for 60
# fetching missing data for 61
# fetching missing data for 62
# fetching missing data for 63
# fetching missing data for 64
# fetching missing data for 65
# fetching missing data for 66
# fetching missing data for 67
# fetching missing data for 68
# fetching missing data for 69
# fetching missing data for 70
# fetching missing data for 71
# fetching missing data for 72
# fetching missing data for 73
# fetching missing data for 74
# fetching missing data for 75
# fetching missing data for 76
# fetching missing data for 77
# fetching missing data for 78
# fetching missing data for 79
# fetching missing data for 80
# fetching missing data for 81
# fetching missing data for 82
# fetching missing data for 83
# fetching missing data for 84
# fetching missing data for 85
# fetching missing data for 86
# fetching missing data for 87
# fetching missing data for 88
# fetching missing data for 89
# fetching missing data for 90
# fetching missing data for 91
# fetching missing data for 92
# fetching missing data for 93
# fetching missing data for 94
# fetching missing data for 95
# fetching missing data for 96
# fetching missing data for 97
# fetching missing data for 98
# fetching missing data for 99
# fetching missing data for 100
# fetching missing data for 101
# fetching missing data for 102
# fetching missing data for 103
# fetching missing data for 104
# fetching missing data for 105
# fetching missing data for 106
# fetching missing data for 107
# fetching missing data for 108
# fetching missing data for 109
# fetching missing data for 110
# fetching missing data for 111
# fetching missing data for 112
# fetching missing data for 113
# fetching missing data for 114
# fetching missing data for 115
# fetching missing data for 116
# fetching missing data for 117
# fetching missing data for 118
# fetching missing data for 119
# fetching missing data for 120
# fetching missing data for 121
# fetching missing data for 122
# fetching missing data for 123
# fetching missing data for 124
# fetching missing data for 125
# fetching missing data for 126
# fetching missing data for 127
# fetching missing data for 128
# fetching missing data for 129
# fetching missing data for 130
# fetching missing data for 131
# fetching missing data for 132
# fetching missing data for 133
# fetching missing data for 134
# fetching missing data for 135
# fetching missing data for 136
# fetching missing data for 137
# fetching missing data for 138
# fetching missing data for 139
# fetching missing data for 140
# fetching missing data for 141
# fetching missing data for 142
# fetching missing data for 143
# fetching missing data for 144
# fetching missing data for 145
# fetching missing data for 146
# fetching missing data for 147
# fetching missing data for 148
# fetching missing data for 149
# fetching missing data for 150
# fetching missing data for 151
# fetching missing data for 152
# fetching missing data for 153
# fetching missing data for 154
# fetching missing data for 155
# fetching missing data for 156
# fetching missing data for 157
# fetching missing data for 158
# fetching missing data for 159
# fetching missing data for 160
# fetching missing data for 161
# fetching missing data for 162
# fetching missing data for 163
# fetching missing data for 164
# fetching missing data for 165
# fetching missing data for 166
# fetching missing data for 167
# fetching missing data for 168
# fetching missing data for 169
# fetching missing data for 170
# fetching missing data for 171
# fetching missing data for 172
# fetching missing data for 173
# fetching missing data for 174
# fetching missing data for 175
# fetching missing data for 176
# fetching missing data for 177
# fetching missing data for 178
# fetching missing data for 179
# fetching missing data for 180
# fetching missing data for 181
# fetching missing data for 182
# fetching missing data for 183
# fetching missing data for 184
# fetching missing data for 185
# fetching missing data for 186
# fetching missing data for 187
# fetching missing data for 188
# fetching missing data for 189
# fetching missing data for 190
# fetching missing data for 191
# fetching missing data for 192
# fetching missing data for 193
# fetching missing data for 194
# fetching missing data for 195
# fetching missing data for 196
# fetching missing data for 197
# fetching missing data for 198
# fetching missing data for 199
# fetching missing data for 200
# fetching missing data for 201
# fetching missing data for 202
# fetching missing data for 203
# fetching missing data for 204
# fetching missing data for 205
# fetching missing data for 206
# fetching missing data for 207
# fetching missing data for 208
# fetching missing data for 209
# fetching missing data for 210
# fetching missing data for 211
# fetching missing data for 212
# fetching missing data for 213
# fetching missing data for 214
# fetching missing data for 215
# fetching missing data for 216
# fetching missing data for 217
# fetching missing data for 218
# fetching missing data for 219
# fetching missing data for 220
# fetching missing data for 221
# fetching missing data for 222
# fetching missing data for 223
# fetching missing data for 224
# fetching missing data for 225
# fetching missing data for 226
# fetching missing data for 227
# fetching missing data for 228
# fetching missing data for 229
# fetching missing data for 230
# fetching missing data for 231
# fetching missing data for 232
# fetching missing data for 233
# fetching missing data for 234
# fetching missing data for 235
# fetching missing data for 236
# fetching missing data for 237
# fetching missing data for 238
# fetching missing data for 239
# fetching missing data for 240
# fetching missing data for 241
# fetching missing data for 242
# fetching missing data for 243
# fetching missing data for 244
# fetching missing data for 245
# fetching missing data for 246
# fetching missing data for 247
# fetching missing data for 248
# fetching missing data for 249
# fetching missing data for 250
# fetching missing data for 251
# fetching missing data for 252
# fetching missing data for 253
# fetching missing data for 254
# fetching missing data for 255
# fetching missing data for 256
# fetching missing data for 257
# fetching missing data for 258
# fetching missing data for 259
# fetching missing data for 260
# fetching missing data for 261
# fetching missing data for 262
# fetching missing data for 263
# fetching missing data for 264
# fetching missing data for 265
# fetching missing data for 266
# fetching missing data for 267
# fetching missing data for 268
# fetching missing data for 269
# fetching missing data for 270
# fetching missing data for 271
# fetching missing data for 272
# fetching missing data for 273
# fetching missing data for 274
# fetching missing data for 275
# fetching missing data for 276
# fetching missing data for 277
# fetching missing data for 278
# fetching missing data for 279
# fetching missing data for 280
# fetching missing data for 281
# fetching missing data for 282
# fetching missing data for 283
# fetching missing data for 284
# fetching missing data for 285
# fetching missing data for 286
# fetching missing data for 287
# fetching missing data for 288
# fetching missing data for 289
# fetching missing data for 290
# fetching missing data for 291
# fetching missing data for 292
# fetching missing data for 293
# fetching missing data for 294
# fetching missing data for 295
# fetching missing data for 296
# fetching missing data for 297
# fetching missing data for 298
# fetching missing data for 299
# fetching missing data for 300
# fetching missing data for 301
# fetching missing data for 302
# fetching missing data for 303
# fetching missing data for 304
# fetching missing data for 305
# fetching missing data for 306
# fetching missing data for 307
# fetching missing data for 308
# fetching missing data for 309
# fetching missing data for 310
# fetching missing data for 311
# fetching missing data for 312
# fetching missing data for 313
# fetching missing data for 314
# fetching missing data for 315
# fetching missing data for 316
# fetching missing data for 317
# fetching missing data for 318
# fetching missing data for 319
# fetching missing data for 320
# fetching missing data for 321
# fetching missing data for 322
# fetching missing data for 323
# fetching missing data for 324
# fetching missing data for 325
# fetching missing data for 326
# fetching missing data for 327
# fetching missing data for 328
# fetching missing data for 329
# fetching missing data for 330
# fetching missing data for 331
# fetching missing data for 332
# fetching missing data for 333
# fetching missing data for 334
# fetching missing data for 335
# fetching missing data for 336
# fetching missing data for 337
# fetching missing data for 338
# fetching missing data for 339
# fetching missing data for 340
# fetching missing data for 341
# fetching missing data for 342
# fetching missing data for 343
# fetching missing data for 344
# fetching missing data for 345
# fetching missing data for 346
# fetching missing data for 347
# fetching missing data for 348
# fetching missing data for 349
# fetching missing data for 350
# fetching missing data for 351
# fetching missing data for 352
# fetching missing data for 353
# fetching missing data for 354
# fetching missing data for 355
# fetching missing data for 356
# fetching missing data for 357
# fetching missing data for 358
# fetching missing data for 359
# fetching missing data for 360
# fetching missing data for 361
# fetching missing data for 362
# fetching missing data for 363
# fetching missing data for 364
# fetching missing data for 365
# fetching missing data for 366
# fetching missing data for 367
# fetching missing data for 368
# fetching missing data for 369
# fetching missing data for 370
# fetching missing data for 371
# fetching missing data for 372
# fetching missing data for 373
# fetching missing data for 374
# fetching missing data for 375
# fetching missing data for 376
# fetching missing data for 377
# fetching missing data for 378
# fetching missing data for 379
# fetching missing data for 380
# fetching missing data for 381
# fetching missing data for 382
# fetching missing data for 383
# fetching missing data for 384
# fetching missing data for 385
# fetching missing data for 386
# fetching missing data for 387
# fetching missing data for 388
# fetching missing data for 389
# fetching missing data for 390
# fetching missing data for 391
# fetching missing data for 392
# fetching missing data for 393
# fetching missing data for 394
# fetching missing data for 395
# fetching missing data for 396
# fetching missing data for 397
# fetching missing data for 398
# fetching missing data for 399
# fetching missing data for 400
# fetching missing data for 401
# fetching missing data for 402
# fetching missing data for 403
# fetching missing data for 404
# fetching missing data for 405
# fetching missing data for 406
# fetching missing data for 407
# fetching missing data for 408
# fetching missing data for 409
# fetching missing data for 410
# fetching missing data for 411
# fetching missing data for 412
# fetching missing data for 413
# fetching missing data for 414
# fetching missing data for 415
# fetching missing data for 416
# fetching missing data for 417
# fetching missing data for 418
# fetching missing data for 419
# fetching missing data for 420
# fetching missing data for 421
# fetching missing data for 422
# fetching missing data for 423
# fetching missing data for 424
# fetching missing data for 425
# fetching missing data for 426
# fetching missing data for 427
# fetching missing data for 428
# fetching missing data for 429
# fetching missing data for 430
# fetching missing data for 431
# fetching missing data for 432
# fetching missing data for 433
# fetching missing data for 434
# fetching missing data for 435
# fetching missing data for 436
# fetching missing data for 437
# fetching missing data for 438
# fetching missing data for 439
# fetching missing data for 440
# fetching missing data for 441
# fetching missing data for 442
# fetching missing data for 443
# fetching missing data for 444
# fetching missing data for 445
# fetching missing data for 446
# fetching missing data for 447
# fetching missing data for 448
# fetching missing data for 449
# fetching missing data for 450
# fetching missing data for 451
# fetching missing data for 452
# fetching missing data for 453
# fetching missing data for 454
# fetching missing data for 455
# fetching missing data for 456
# fetching missing data for 457
# fetching missing data for 458
# fetching missing data for 459
# fetching missing data for 460
# fetching missing data for 461
# fetching missing data for 462
# fetching missing data for 463
# fetching missing data for 464
# fetching missing data for 465
# fetching missing data for 466
# fetching missing data for 467
# fetching missing data for 468
# fetching missing data for 469
# fetching missing data for 470
# fetching missing data for 471
# fetching missing data for 472
# fetching missing data for 473
# fetching missing data for 474
# fetching missing data for 475
# fetching missing data for 476
# fetching missing data for 477
# fetching missing data for 478
# fetching missing data for 479
# fetching missing data for 480
# fetching missing data for 481
# fetching missing data for 482
# fetching missing data for 483
# fetching missing data for 484
# fetching missing data for 485
# fetching missing data for 486
# fetching missing data for 487
# fetching missing data for 488
# fetching missing data for 489
# fetching missing data for 490
# fetching missing data for 491
# fetching missing data for 492
# fetching missing data for 493
# fetching missing data for 494
# fetching missing data for 495
# fetching missing data for 496
# fetching missing data for 497
# fetching missing data for 498
# fetching missing data for 499
# fetching missing data for 500
# fetching missing data for 501
# fetching missing data for 502
# fetching missing data for 503
# fetching missing data for 504
# fetching missing data for 505
# fetching missing data for 506
# fetching missing data for 507
# fetching missing data for 508
# fetching missing data for 509
# fetching missing data for 510
# fetching missing data for 511
# fetching missing data for 512
# fetching missing data for 513
# fetching missing data for 514
# fetching missing data for 515
# fetching missing data for 516
# fetching missing data for 517
# fetching missing data for 518
# fetching missing data for 519
# fetching missing data for 520
# fetching missing data for 521
# fetching missing data for 522
# fetching missing data for 523
# fetching missing data for 524
# fetching missing data for 525
# fetching missing data for 526
# fetching missing data for 527
# fetching missing data for 528
# fetching missing data for 529
# fetching missing data for 530
# fetching missing data for 531
# fetching missing data for 532
# fetching missing data for 533
# fetching missing data for 534
# fetching missing data for 535
# fetching missing data for 536
# fetching missing data for 537
# fetching missing data for 538
# fetching missing data for 539
# fetching missing data for 540
# fetching missing data for 541
# fetching missing data for 542
# fetching missing data for 543
# fetching missing data for 544
# fetching missing data for 545
# fetching missing data for 546
# fetching missing data for 547
# fetching missing data for 548
# fetching missing data for 549
# fetching missing data for 550
# fetching missing data for 551
# fetching missing data for 552
# fetching missing data for 553
# fetching missing data for 554
# fetching missing data for 555
# fetching missing data for 556
# fetching missing data for 557
# fetching missing data for 558
# fetching missing data for 559
# fetching missing data for 560
# fetching missing data for 561
# fetching missing data for 562
# fetching missing data for 563
# fetching missing data for 564
# fetching missing data for 565
# fetching missing data for 566
# fetching missing data for 567
# fetching missing data for 568
# fetching missing data for 569
# fetching missing data for 570
# fetching missing data for 571
# fetching missing data for 572
# fetching missing data for 573
# fetching missing data for 574
# fetching missing data for 575
# fetching missing data for 576
# fetching missing data for 577
# fetching missing data for 578
# fetching missing data for 579
# fetching missing data for 580
# fetching missing data for 581
# fetching missing data for 582
# fetching missing data for 583
# fetching missing data for 584
# fetching missing data for 585
# fetching missing data for 586
# fetching missing data for 587
# fetching missing data for 588
# fetching missing data for 589
# fetching missing data for 590
# fetching missing data for 591
# fetching missing data for 592
# fetching missing data for 593
# fetching missing data for 594
# fetching missing data for 595
# fetching missing data for 596
# fetching missing data for 597
# fetching missing data for 598
# fetching missing data for 599
# fetching missing data for 600
# fetching missing data for 601
# fetching missing data for 602
# fetching missing data for 603
# fetching missing data for 604
# fetching missing data for 605
# fetching missing data for 606
# fetching missing data for 607
# fetching missing data for 608
# fetching missing data for 609
# fetching missing data for 610
# fetching missing data for 611
# fetching missing data for 612
# fetching missing data for 613
# fetching missing data for 614
# fetching missing data for 615
# fetching missing data for 616
# fetching missing data for 617
# fetching missing data for 618
# fetching missing data for 619
# fetching missing data for 620
# fetching missing data for 621
# fetching missing data for 622
# fetching missing data for 623
# fetching missing data for 624
# fetching missing data for 625
# fetching missing data for 626
# fetching missing data for 627
# fetching missing data for 628
# fetching missing data for 629
# fetching missing data for 630
# fetching missing data for 631
# fetching missing data for 632
# fetching missing data for 633
# fetching missing data for 634
# fetching missing data for 635
# fetching missing data for 636
# fetching missing data for 637
# fetching missing data for 638
# fetching missing data for 639
# fetching missing data for 640
# fetching missing data for 641
# fetching missing data for 642
# fetching missing data for 643
# fetching missing data for 644
# fetching missing data for 645
# fetching missing data for 646
# fetching missing data for 647
# fetching missing data for 648
# fetching missing data for 649
# fetching missing data for 650
# fetching missing data for 651
# fetching missing data for 652
# fetching missing data for 653
# fetching missing data for 654
# fetching missing data for 655
# fetching missing data for 656
# fetching missing data for 657
# fetching missing data for 658
# fetching missing data for 659
# fetching missing data for 660
# fetching missing data for 661
# fetching missing data for 662
# fetching missing data for 663
# fetching missing data for 664
# fetching missing data for 665
# fetching missing data for 666
# fetching missing data for 667
# fetching missing data for 668
# fetching missing data for 669
# fetching missing data for 670
# fetching missing data for 671
# fetching missing data for 672
# fetching missing data for 673
# fetching missing data for 674
# fetching missing data for 675
# fetching missing data for 676
# fetching missing data for 677
# fetching missing data for 678
# fetching missing data for 679
# fetching missing data for 680
# fetching missing data for 681
# fetching missing data for 682
# fetching missing data for 683
# fetching missing data for 684
# fetching missing data for 685
# fetching missing data for 686
# fetching missing data for 687
# fetching missing data for 688
# fetching missing data for 689
# fetching missing data for 690
# fetching missing data for 691
# fetching missing data for 692
# fetching missing data for 693
# fetching missing data for 694
# fetching missing data for 695
# fetching missing data for 696
# fetching missing data for 697
# fetching missing data for 698
# fetching missing data for 699
# fetching missing data for 700
# fetching missing data for 701
# fetching missing data for 702
# fetching missing data for 703
# fetching missing data for 704
# fetching missing data for 705
# fetching missing data for 706
# fetching missing data for 707
# fetching missing data for 708
# fetching missing data for 709
# fetching missing data for 710
# fetching missing data for 711
# fetching missing data for 712
# fetching missing data for 713
# fetching missing data for 714
# fetching missing data for 715
# fetching missing data for 716
# fetching missing data for 717
# fetching missing data for 718
# fetching missing data for 719
# fetching missing data for 720
# fetching missing data for 721
# fetching missing data for 722
# fetching missing data for 723
# fetching missing data for 724
# fetching missing data for 725
# fetching missing data for 726
# fetching missing data for 727
# fetching missing data for 728
# fetching missing data for 729
# fetching missing data for 730
# fetching missing data for 731
# fetching missing data for 732
# fetching missing data for 733
# fetching missing data for 734
# fetching missing data for 735
# fetching missing data for 736
# fetching missing data for 737
# fetching missing data for 738
# fetching missing data for 739
# fetching missing data for 740
# fetching missing data for 741
# fetching missing data for 742
# fetching missing data for 743
# fetching missing data for 744
# fetching missing data for 745
# fetching missing data for 746
# fetching missing data for 747
# fetching missing data for 748
# fetching missing data for 749
# fetching missing data for 750
# fetching missing data for 751
# fetching missing data for 752
# fetching missing data for 753
# fetching missing data for 754
# fetching missing data for 755
# fetching missing data for 756
# fetching missing data for 757
# fetching missing data for 758
# fetching missing data for 759
# fetching missing data for 760
# fetching missing data for 761
# fetching missing data for 762
# fetching missing data for 763
# fetching missing data for 764
# fetching missing data for 765
# fetching missing data for 766
# fetching missing data for 767
# fetching missing data for 768
# fetching missing data for 769
# fetching missing data for 770
# fetching missing data for 771
# fetching missing data for 772
# fetching missing data for 773
# fetching missing data for 774
# fetching missing data for 775
# fetching missing data for 776
# fetching missing data for 777
# fetching missing data for 778
# fetching missing data for 779
# fetching missing data for 780
# fetching missing data for 781
# fetching missing data for 782
# fetching missing data for 783
# fetching missing data for 784
# fetching missing data for 785
# fetching missing data for 786
# fetching missing data for 787
# fetching missing data for 788
# fetching missing data for 789
# fetching missing data for 790
# fetching missing data for 791
# fetching missing data for 792
# fetching missing data for 793
# fetching missing data for 794
# fetching missing data for 795
# fetching missing data for 796
# fetching missing data for 797
# fetching missing data for 798
# fetching missing data for 799
# fetching missing data for 800
# fetching missing data for 801
# fetching missing data for 802
# fetching missing data for 803
# fetching missing data for 804
# fetching missing data for 805
# fetching missing data for 806
# fetching missing data for 807
# fetching missing data for 808
# fetching missing data for 809
# fetching missing data for 810
# fetching missing data for 811
# fetching missing data for 812
# fetching missing data for 813
# fetching missing data for 814
# fetching missing data for 815
# fetching missing data for 816
# fetching missing data for 817
# fetching missing data for 818
# fetching missing data for 819
# fetching missing data for 820
# fetching missing data for 821
# fetching missing data for 822
# fetching missing data for 823
# fetching missing data for 824
# fetching missing data for 825
# fetching missing data for 826
# fetching missing data for 827
# fetching missing data for 828
# fetching missing data for 829
# fetching missing data for 830
# fetching missing data for 831
# fetching missing data for 832
# fetching missing data for 833
# fetching missing data for 834
# fetching missing data for 835
# fetching missing data for 836
# fetching missing data for 837
# fetching missing data for 838
# fetching missing data for 839
# fetching missing data for 840
# fetching missing data for 841
# fetching missing data for 842
# fetching missing data for 843
# fetching missing data for 844
# fetching missing data for 845
# fetching missing data for 846
# fetching missing data for 847
# fetching missing data for 848
# fetching missing data for 849
# fetching missing data for 850
# fetching missing data for 851
# fetching missing data for 852
# fetching missing data for 853
# fetching missing data for 854
# fetching missing data for 855
# fetching missing data for 856
# fetching missing data for 857
# fetching missing data for 858
# fetching missing data for 859
# fetching missing data for 860
# fetching missing data for 861
# fetching missing data for 862
# fetching missing data for 863
# fetching missing data for 864
# fetching missing data for 865
# fetching missing data for 866
# fetching missing data for 867
# fetching missing data for 868
# fetching missing data for 869
# fetching missing data for 870
# fetching missing data for 871
# fetching missing data for 872
# fetching missing data for 873
# fetching missing data for 874
# fetching missing data for 875
# fetching missing data for 876
# fetching missing data for 877
# fetching missing data for 878
# fetching missing data for 879
# fetching missing data for 880
# fetching missing data for 881
# fetching missing data for 882
# fetching missing data for 883
# fetching missing data for 884
# fetching missing data for 885
# fetching missing data for 886
# fetching missing data for 887
# fetching missing data for 888
# fetching missing data for 889
# fetching missing data for 890
# fetching missing data for 891
# fetching missing data for 892
# fetching missing data for 893
# fetching missing data for 894
# fetching missing data for 895
# fetching missing data for 896
# fetching missing data for 897
# fetching missing data for 898
# fetching missing data for 899
# fetching missing data for 900
# fetching missing data for 901
# fetching missing data for 902
# fetching missing data for 903
# fetching missing data for 904
# fetching missing data for 905
# fetching missing data for 906
# fetching missing data for 907
# fetching missing data for 908
# fetching missing data for 909
# fetching missing data for 910
# fetching missing data for 911
# fetching missing data for 912
# fetching missing data for 913
# fetching missing data for 914
# fetching missing data for 915
# fetching missing data for 916
# fetching missing data for 917
# fetching missing data for 918
# fetching missing data for 919
# fetching missing data for 920
# fetching missing data for 921
# fetching missing data for 922
# fetching missing data for 923
# fetching missing data for 924
# fetching missing data for 925
# fetching missing data for 926
# fetching missing data for 927
# fetching missing data for 928
# fetching missing data for 929
# fetching missing data for 930
# fetching missing data for 931
# fetching missing data for 932
# fetching missing data for 933
# fetching missing data for 934
# fetching missing data for 935
# fetching missing data for 936
# fetching missing data for 937
# fetching missing data for 938
# fetching missing data for 939
# fetching missing data for 940
# fetching missing data for 941
# fetching missing data for 942
# fetching missing data for 943
# fetching missing data for 944
# fetching missing data for 945
# fetching missing data for 946
# fetching missing data for 947
# fetching missing data for 948
# fetching missing data for 949
# fetching missing data for 950
# fetching missing data for 951
# fetching missing data for 952
# fetching missing data for 953
# fetching missing data for 954
# fetching missing data for 955
# fetching missing data for 956
# fetching missing data for 957
# fetching missing data for 958
# fetching missing data for 959
# fetching missing data for 960
# fetching missing data for 961
# fetching missing data for 962
# fetching missing data for 963
# fetching missing data for 964
# fetching missing data for 965
# fetching missing data for 966
# fetching missing data for 967
# fetching missing data for 968
# fetching missing data for 969
# fetching missing data for 970
# fetching missing data for 971
# fetching missing data for 972
# fetching missing data for 973
# fetching missing data for 974
# fetching missing data for 975
# fetching missing data for 976
# fetching missing data for 977
# fetching missing data for 978
# fetching missing data for 979
# fetching missing data for 980
# fetching missing data for 981
# fetching missing data for 982
# fetching missing data for 983
# fetching missing data for 984
# fetching missing data for 985
# fetching missing data for 986
# fetching missing data for 987
# fetching missing data for 988
# fetching missing data for 989
# fetching missing data for 990
# fetching missing data for 991
# fetching missing data for 992
# fetching missing data for 993
# fetching missing data for 994
# fetching missing data for 995
# fetching missing data for 996
# fetching missing data for 997
# fetching missing data for 998
# fetching missing data for 999
# fetching missing data for 1000
# fetching missing data for 1001
# fetching missing data for 1002
# fetching missing data for 1003
# fetching missing data for 1004
# fetching missing data for 1005
# fetching missing data for 1006
# fetching missing data for 1007
# fetching missing data for 1008
# fetching missing data for 1009
# fetching missing data for 1010
# fetching missing data for 1011
# fetching missing data for 1012
# fetching missing data for 1013
# fetching missing data for 1014
# fetching missing data for 1015
# fetching missing data for 1016
# fetching missing data for 1017
# fetching missing data for 1018
# fetching missing data for 1019
# fetching missing data for 1020
# fetching missing data for 1021
# fetching missing data for 1022
# fetching missing data for 1023
# fetching missing data for 1024
# fetching missing data for 1025
# fetching missing data for 1026
# fetching missing data for 1027
# fetching missing data for 1028
# fetching missing data for 1029
# fetching missing data for 1030
# fetching missing data for 1031
# fetching missing data for 1032
# fetching missing data for 1033
# fetching missing data for 1034
# fetching missing data for 1035
# fetching missing data for 1036
# fetching missing data for 1037
# fetching missing data for 1038
# fetching missing data for 1039
# fetching missing data for 1040
# fetching missing data for 1041
# fetching missing data for 1042
# fetching missing data for 1043
# fetching missing data for 1044
# fetching missing data for 1045
# fetching missing data for 1046
# fetching missing data for 1047
# fetching missing data for 1048
# fetching missing data for 1049
# fetching missing data for 1050
# fetching missing data for 1051
# fetching missing data for 1052
# fetching missing data for 1053
# fetching missing data for 1054
# fetching missing data for 1055
# fetching missing data for 1056
# fetching missing data for 1057
# fetching missing data for 1058
# fetching missing data for 1059
# fetching missing data for 1060
# fetching missing data for 1061
# fetching missing data for 1062
# fetching missing data for 1063
# fetching missing data for 1064
# fetching missing data for 1065
# fetching missing data for 1066
# fetching missing data for 1067
# fetching missing data for 1068
# fetching missing data for 1069
# fetching missing data for 1070
# fetching missing data for 1071
# fetching missing data for 1072
# fetching missing data for 1073
# fetching missing data for 1074
# fetching missing data for 1075
# fetching missing data for 1076
# fetching missing data for 1077
# fetching missing data for 1078
# fetching missing data for 1079
# fetching missing data for 1080
# fetching missing data for 1081
# fetching missing data for 1082
# fetching missing data for 1083
# fetching missing data for 1084
# fetching missing data for 1085
# fetching missing data for 1086
# fetching missing data for 1087
# fetching missing data for 1088
# fetching missing data for 1089
# fetching missing data for 1090
# fetching missing data for 1091
# fetching missing data for 1092
# fetching missing data for 1093
# fetching missing data for 1094
# fetching missing data for 1095
# fetching missing data for 1096
# fetching missing data for 1097
# fetching missing data for 1098
# fetching missing data for 1099
# fetching missing data for 1100
# fetching missing data for 1101
# fetching missing data for 1102
# fetching missing data for 1103
# fetching missing data for 1104
# fetching missing data for 1105
# fetching missing data for 1106
# fetching missing data for 1107
# fetching missing data for 1108
# fetching missing data for 1109
# fetching missing data for 1110
# fetching missing data for 1111
# fetching missing data for 1112
# fetching missing data for 1113
# fetching missing data for 1114
# fetching missing data for 1115
# fetching missing data for 1116
# fetching missing data for 1117
# fetching missing data for 1118
# fetching missing data for 1119
# fetching missing data for 1120
# fetching missing data for 1121
# fetching missing data for 1122
# fetching missing data for 1123
# fetching missing data for 1124
# fetching missing data for 1125
# fetching missing data for 1126
# fetching missing data for 1127
# fetching missing data for 1128
# fetching missing data for 1129
# fetching missing data for 1130
# fetching missing data for 1131
# fetching missing data for 1132
# fetching missing data for 1133
# fetching missing data for 1134
# fetching missing data for 1135
# fetching missing data for 1136
# fetching missing data for 1137
# fetching missing data for 1138
# fetching missing data for 1139
# fetching missing data for 1140
# fetching missing data for 1141
# fetching missing data for 1142
# fetching missing data for 1143
# fetching missing data for 1144
# fetching missing data for 1145
# fetching missing data for 1146
# fetching missing data for 1147
# fetching missing data for 1148
# fetching missing data for 1149
# fetching missing data for 1150
# fetching missing data for 1151
# fetching missing data for 1152
# fetching missing data for 1153
# fetching missing data for 1154
# fetching missing data for 1155
# fetching missing data for 1156
# fetching missing data for 1157
# fetching missing data for 1158
# fetching missing data for 1159
# fetching missing data for 1160
# fetching missing data for 1161
# fetching missing data for 1162
# fetching missing data for 1163
# fetching missing data for 1164
# fetching missing data for 1165
# fetching missing data for 1166
# fetching missing data for 1167
# fetching missing data for 1168
# fetching missing data for 1169
# fetching missing data for 1170
# fetching missing data for 1171
# fetching missing data for 1172
# fetching missing data for 1173
# fetching missing data for 1174
# fetching missing data for 1175
# fetching missing data for 1176
# fetching missing data for 1177
# fetching missing data for 1178
# fetching missing data for 1179
# fetching missing data for 1180
# fetching missing data for 1181
# fetching missing data for 1182
# fetching missing data for 1183
# fetching missing data for 1184
# fetching missing data for 1185
# fetching missing data for 1186
# fetching missing data for 1187
# fetching missing data for 1188
# fetching missing data for 1189
# fetching missing data for 1190
# fetching missing data for 1191
# fetching missing data for 1192
# fetching missing data for 1193
# fetching missing data for 1194
# fetching missing data for 1195
# fetching missing data for 1196
# fetching missing data for 1197
# fetching missing data for 1198
# fetching missing data for 1199
# fetching missing data for 1200
# fetching missing data for 1201
# fetching missing data for 1202
# fetching missing data for 1203
# fetching missing data for 1204
# fetching missing data for 1205
# fetching missing data for 1206
# fetching missing data for 1207
# fetching missing data for 1208
# fetching missing data for 1209
# fetching missing data for 1210
# fetching missing data for 1211
# fetching missing data for 1212
# fetching missing data for 1213
# fetching missing data for 1214
# fetching missing data for 1215
# fetching missing data for 1216
# fetching missing data for 1217
# fetching missing data for 1218
# fetching missing data for 1219
# fetching missing data for 1220
# fetching missing data for 1221
# fetching missing data for 1222
# fetching missing data for 1223
# fetching missing data for 1224
# fetching missing data for 1225
# fetching missing data for 1226
# fetching missing data for 1227
# fetching missing data for 1228
# fetching missing data for 1229
# fetching missing data for 1230
# fetching missing data for 1231
# fetching missing data for 1232
# fetching missing data for 1233
# fetching missing data for 1234
# fetching missing data for 1235
# fetching missing data for 1236
# fetching missing data for 1237
# fetching missing data for 1238
# fetching missing data for 1239
# fetching missing data for 1240
# fetching missing data for 1241
# fetching missing data for 1242
# fetching missing data for 1243
# fetching missing data for 1244
# fetching missing data for 1245
# fetching missing data for 1246
# fetching missing data for 1247
# fetching missing data for 1248
# fetching missing data for 1249
# fetching missing data for 1250
# fetching missing data for 1251
# fetching missing data for 1252
# fetching missing data for 1253
# fetching missing data for 1254
# fetching missing data for 1255
# fetching missing data for 1256
# fetching missing data for 1257
# fetching missing data for 1258
# fetching missing data for 1259
# fetching missing data for 1260
# fetching missing data for 1261
# fetching missing data for 1262
# fetching missing data for 1263
# fetching missing data for 1264
# fetching missing data for 1265
# fetching missing data for 1266
# fetching missing data for 1267
# fetching missing data for 1268
# fetching missing data for 1269
# fetching missing data for 1270
# fetching missing data for 1271
# fetching missing data for 1272
# fetching missing data for 1273
# fetching missing data for 1274
# fetching missing data for 1275
# fetching missing data for 1276
# fetching missing data for 1277
# fetching missing data for 1278
# fetching missing data for 1279
# fetching missing data for 1280
# fetching missing data for 1281
# fetching missing data for 1282
# fetching missing data for 1283
# fetching missing data for 1284
# fetching missing data for 1285
# fetching missing data for 1286
# fetching missing data for 1287
# fetching missing data for 1288
# fetching missing data for 1289
# fetching missing data for 1290
# fetching missing data for 1291
# fetching missing data for 1292
# fetching missing data for 1293
# fetching missing data for 1294
# fetching missing data for 1295
# fetching missing data for 1296
# fetching missing data for 1297
# fetching missing data for 1298
# fetching missing data for 1299
# fetching missing data for 1300
# fetching missing data for 1301
# fetching missing data for 1302
# fetching missing data for 1303
# fetching missing data for 1304
# fetching missing data for 1305
# fetching missing data for 1306
# fetching missing data for 1307
# fetching missing data for 1308
# fetching missing data for 1309
# fetching missing data for 1310
# fetching missing data for 1311
# fetching missing data for 1312
# fetching missing data for 1313
# fetching missing data for 1314
# fetching missing data for 1315
# fetching missing data for 1316
# fetching missing data for 1317
# fetching missing data for 1318
# fetching missing data for 1319
# fetching missing data for 1320
# fetching missing data for 1321
# fetching missing data for 1322
# fetching missing data for 1323
# fetching missing data for 1324
# fetching missing data for 1325
# fetching missing data for 1326
# fetching missing data for 1327
# fetching missing data for 1328
# fetching missing data for 1329
# fetching missing data for 1330
# fetching missing data for 1331
# fetching missing data for 1332
# fetching missing data for 1333
# fetching missing data for 1334
# fetching missing data for 1335
# fetching missing data for 1336
# fetching missing data for 1337
# fetching missing data for 1338
# fetching missing data for 1339
# fetching missing data for 1340
# fetching missing data for 1341
# fetching missing data for 1342
# fetching missing data for 1343
# fetching missing data for 1344
# fetching missing data for 1345
# fetching missing data for 1346
# fetching missing data for 1347
# fetching missing data for 1348
# fetching missing data for 1349
# fetching missing data for 1350
# fetching missing data for 1351
# fetching missing data for 1352
# fetching missing data for 1353
# fetching missing data for 1354
# fetching missing data for 1355
# fetching missing data for 1356
# fetching missing data for 1357
# fetching missing data for 1358
# fetching missing data for 1359
# fetching missing data for 1360
# fetching missing data for 1361
# fetching missing data for 1362
# fetching missing data for 1363
# fetching missing data for 1364
# fetching missing data for 1365
# fetching missing data for 1366
# fetching missing data for 1367
# fetching missing data for 1368
# fetching missing data for 1369
# fetching missing data for 1370
# fetching missing data for 1371
# fetching missing data for 1372
# fetching missing data for 1373
# fetching missing data for 1374
# fetching missing data for 1375
# fetching missing data for 1376
# fetching missing data for 1377
# fetching missing data for 1378
# fetching missing data for 1379
# fetching missing data for 1380
# fetching missing data for 1381
# fetching missing data for 1382
# fetching missing data for 1383
# fetching missing data for 1384
# fetching missing data for 1385
# fetching missing data for 1386
# fetching missing data for 1387
# fetching missing data for 1388
# fetching missing data for 1389
# fetching missing data for 1390
# fetching missing data for 1391
# fetching missing data for 1392
# fetching missing data for 1393
# fetching missing data for 1394
# fetching missing data for 1395
# fetching missing data for 1396
# fetching missing data for 1397
# fetching missing data for 1398
# fetching missing data for 1399
# fetching missing data for 1400
# fetching missing data for 1401
# fetching missing data for 1402
# fetching missing data for 1403
# fetching missing data for 1404
# fetching missing data for 1405
# fetching missing data for 1406
# fetching missing data for 1407
# fetching missing data for 1408
# fetching missing data for 1409
# fetching missing data for 1410
# fetching missing data for 1411
# fetching missing data for 1412
# fetching missing data for 1413
# fetching missing data for 1414
# fetching missing data for 1415
# fetching missing data for 1416
# fetching missing data for 1417
# fetching missing data for 1418
# fetching missing data for 1419
# fetching missing data for 1420
# fetching missing data for 1421
# fetching missing data for 1422
# fetching missing data for 1423
# fetching missing data for 1424
# fetching missing data for 1425
# fetching missing data for 1426
# fetching missing data for 1427
# fetching missing data for 1428
# fetching missing data for 1429
# fetching missing data for 1430
# fetching missing data for 1431
# fetching missing data for 1432
# fetching missing data for 1433
# fetching missing data for 1434
# fetching missing data for 1435
# fetching missing data for 1436
# fetching missing data for 1437
# fetching missing data for 1438
# fetching missing data for 1439
# fetching missing data for 1440
# fetching missing data for 1441
# fetching missing data for 1442
# fetching missing data for 1443
# fetching missing data for 1444
# fetching missing data for 1445
# fetching missing data for 1446
# fetching missing data for 1447
# fetching missing data for 1448
# fetching missing data for 1449
# fetching missing data for 1450
# fetching missing data for 1451
# fetching missing data for 1452
# fetching missing data for 1453
# fetching missing data for 1454
# fetching missing data for 1455
# fetching missing data for 1456
# fetching missing data for 1457
# fetching missing data for 1458
# fetching missing data for 1459
# fetching missing data for 1460
# fetching missing data for 1461
# fetching missing data for 1462
# fetching missing data for 1463
# fetching missing data for 1464
# fetching missing data for 1465
# fetching missing data for 1466
# fetching missing data for 1467
# fetching missing data for 1468
# fetching missing data for 1469
# fetching missing data for 1470
# fetching missing data for 1471
# fetching missing data for 1472
# fetching missing data for 1473
# fetching missing data for 1474
# fetching missing data for 1475
# fetching missing data for 1476
# fetching missing data for 1477
# fetching missing data for 1478
# fetching missing data for 1479
# fetching missing data for 1480
# fetching missing data for 1481
# fetching missing data for 1482
# fetching missing data for 1483
# fetching missing data for 1484
# fetching missing data for 1485
# fetching missing data for 1486
# fetching missing data for 1487
# fetching missing data for 1488
# fetching missing data for 1489
# fetching missing data for 1490
# fetching missing data for 1491
# fetching missing data for 1492
# fetching missing data for 1493
# fetching missing data for 1494
# fetching missing data for 1495
# fetching missing data for 1496
# fetching missing data for 1497
# fetching missing data for 1498
# fetching missing data for 1499
# fetching missing data for 1500
# fetching missing data for 1501
# fetching missing data for 1502
# fetching missing data for 1503
# fetching missing data for 1504
# fetching missing data for 1505
# fetching missing data for 1506
# fetching missing data for 1507
# fetching missing data for 1508
# fetching missing data for 1509
# fetching missing data for 1510
# fetching missing data for 1511
# fetching missing data for 1512
# fetching missing data for 1513
# fetching missing data for 1514
# fetching missing data for 1515
# fetching missing data for 1516
# fetching missing data for 1517
# fetching missing data for 1518
# fetching missing data for 1519
# fetching missing data for 1520
# fetching missing data for 1521
# fetching missing data for 1522
# fetching missing data for 1523
# fetching missing data for 1524
# fetching missing data for 1525
# fetching missing data for 1526
# fetching missing data for 1527
# fetching missing data for 1528
# fetching missing data for 1529
# fetching missing data for 1530
# fetching missing data for 1531
# fetching missing data for 1532
# fetching missing data for 1533
# fetching missing data for 1534
# fetching missing data for 1535
# fetching missing data for 1536
# fetching missing data for 1537
# fetching missing data for 1538
# fetching missing data for 1539
# fetching missing data for 1540
# fetching missing data for 1541
# fetching missing data for 1542
# fetching missing data for 1543
# fetching missing data for 1544
# fetching missing data for 1545
# fetching missing data for 1546
# fetching missing data for 1547
# fetching missing data for 1548
# fetching missing data for 1549
# fetching missing data for 1550
# fetching missing data for 1551
# fetching missing data for 1552
# fetching missing data for 1553
# fetching missing data for 1554
# fetching missing data for 1555
# fetching missing data for 1556
# fetching missing data for 1557
# fetching missing data for 1558
# fetching missing data for 1559
# fetching missing data for 1560
# fetching missing data for 1561
# fetching missing data for 1562
# fetching missing data for 1563
# fetching missing data for 1564
# fetching missing data for 1565
# fetching missing data for 1566
# fetching missing data for 1567
# fetching missing data for 1568
# fetching missing data for 1569
# fetching missing data for 1570
# fetching missing data for 1571
# fetching missing data for 1572
# fetching missing data for 1573
# fetching missing data for 1574
# fetching missing data for 1575
# fetching missing data for 1576
# fetching missing data for 1577
# fetching missing data for 1578
# fetching missing data for 1579
# fetching missing data for 1580
# fetching missing data for 1581
# fetching missing data for 1582
# fetching missing data for 1583
# fetching missing data for 1584
# fetching missing data for 1585
# fetching missing data for 1586
# fetching missing data for 1587
# fetching missing data for 1588
# fetching missing data for 1589
# fetching missing data for 1590
# fetching missing data for 1591
# fetching missing data for 1592
# fetching missing data for 1593
# fetching missing data for 1594
# fetching missing data for 1595
# fetching missing data for 1596
# fetching missing data for 1597
# fetching missing data for 1598
# fetching missing data for 1599
# fetching missing data for 1600
# fetching missing data for 1601
# fetching missing data for 1602
# fetching missing data for 1603
# fetching missing data for 1604
# fetching missing data for 1605
# fetching missing data for 1606
# fetching missing data for 1607
# fetching missing data for 1608
# fetching missing data for 1609
# fetching missing data for 1610
# fetching missing data for 1611
# fetching missing data for 1612
# fetching missing data for 1613
# fetching missing data for 1614
# fetching missing data for 1615
# fetching missing data for 1616
# fetching missing data for 1617
# fetching missing data for 1618
# fetching missing data for 1619
# fetching missing data for 1620
# fetching missing data for 1621
# fetching missing data for 1622
# fetching missing data for 1623
# fetching missing data for 1624
# fetching missing data for 1625
# fetching missing data for 1626
# fetching missing data for 1627
# fetching missing data for 1628
# fetching missing data for 1629
# fetching missing data for 1630
# fetching missing data for 1631
# fetching missing data for 1632
# fetching missing data for 1633
# fetching missing data for 1634
# fetching missing data for 1635
# fetching missing data for 1636
# fetching missing data for 1637
# fetching missing data for 1638
# fetching missing data for 1639
# fetching missing data for 1640
# fetching missing data for 1641
# fetching missing data for 1642
# fetching missing data for 1643
# fetching missing data for 1644
# fetching missing data for 1645
# fetching missing data for 1646
# fetching missing data for 1647
# fetching missing data for 1648
# fetching missing data for 1649
# fetching missing data for 1650
# fetching missing data for 1651
# fetching missing data for 1652
# fetching missing data for 1653
# fetching missing data for 1654
# fetching missing data for 1655
# fetching missing data for 1656
# fetching missing data for 1657

# %%
df_final
# Out:
#      element     club_id                                 name       club  \
# 0       node    30012753                          Umspannwerk        NaN
# 1       node    60775321                                 KW76      poker
# 2       node   257709121                   Kulturhaus Spandau        NaN
# 3       node   266630320                 Buergeramt Mahlsdorf        NaN
# 4       node   268915262                          Karame e.V.        NaN
# ...      ...         ...                                  ...        ...
# 1653     way  1352576785   DAV OG Berlin Oberschöneweide e.V.    fishing
# 1654     way  1353882816                 Haus Wolfgang Raeder  gardening
# 1655     way  1387340919            Kulturzentrum Alte Schule        NaN
# 1656     way  1413964279              Vereinsheim Treue Seele        NaN
# 1657     way  1423837870  Begegnungszentrum im Kölner Viertel        NaN
#
#      leisure sport           amenity                  street housenumber  \
# 0        NaN   NaN      events_venue                     NaN         NaN
# 1        NaN   NaN               NaN      Konrad-Wolf-Straße          76
# 2        NaN   NaN       arts_centre                     NaN         NaN
# 3        NaN   NaN  community_centre          Hönower Straße          91
# 4        NaN   NaN  community_centre  Wilhelmshavener Straße          22
# ...      ...   ...               ...                     ...         ...
# 1653     NaN   NaN               NaN            Nalepastraße          56
# 1654     NaN   NaN  community_centre         Leonberger Ring          54
# 1655     NaN   NaN  community_centre                     NaN         NaN
# 1656     NaN   NaN  community_centre                     NaN         NaN
# 1657     NaN   NaN  community_centre    Müngersdorfer Straße          18
#
#      postcode  ... email                    opening_hours  \
# 0         NaN  ...   NaN                          unknown
# 1         NaN  ...   NaN                          unknown
# 2         NaN  ...   NaN                          unknown
# 3       12623  ...   NaN                          unknown
# 4       10551  ...   NaN  mo-fr 13:00-18:00; sa-su,ph off
# ...       ...  ...   ...                              ...
# 1653      NaN  ...   NaN                          unknown
# 1654      NaN  ...   NaN                          unknown
# 1655      NaN  ...   NaN                          unknown
# 1656      NaN  ...   NaN                          unknown
# 1657    12524  ...   NaN                          unknown
#
#                        geometry wheelchair   latitude  longitude  \
# 0     POINT (13.42919 52.49404)       true  52.494042  13.429187
# 1     POINT (13.48162 52.53862)    unknown  52.538623  13.481623
# 2     POINT (13.20231 52.53548)       true  52.535479  13.202312
# 3     POINT (13.61206 52.51314)       true  52.513140  13.612063
# 4       POINT (13.34154 52.531)      false  52.531002  13.341544
# ...                         ...        ...        ...        ...
# 1653  POINT (13.49774 52.47722)    unknown  52.477217  13.497736
# 1654  POINT (13.42883 52.42721)    unknown  52.427209  13.428828
# 1655  POINT (13.54977 52.43896)    unknown  52.438961  13.549769
# 1656  POINT (13.46274 52.47362)    unknown  52.473617  13.462736
# 1657   POINT (13.54737 52.4038)    unknown  52.403802  13.547368
#
#                       district  neighborhood_id          neighborhood  \
# 0     Friedrichshain-Kreuzberg             0202             Kreuzberg
# 1                  Lichtenberg             1110  Alt-Hohenschönhausen
# 2                      Spandau             0501               Spandau
# 3          Marzahn-Hellersdorf             1004             Mahlsdorf
# 4                        Mitte             0102                Moabit
# ...                        ...              ...                   ...
# 1653          Treptow-Köpenick             0909       Oberschöneweide
# 1654                  Neukölln             0802                 Britz
# 1655          Treptow-Köpenick             0907             Adlershof
# 1656                  Neukölln             0801              Neukölln
# 1657          Treptow-Köpenick             0906          Altglienicke
#
#                                            full_address
# 0     Umspannwerk, Ohlauer Straße, Luisenstadt, Kreu...
# 1     KW76, 76, Konrad-Wolf-Straße, Wilhelmsberg, Al...
# 2     Kulturhaus Spandau, Mauerstraße, Altstadt, Spa...
# 3     Buergeramt Mahlsdorf, 91, Hönower Straße, Lich...
# 4     Karame e.V., 22, Wilhelmshavener Straße, Alt-M...
# ...                                                 ...
# 1653  DAV OG Berlin Oberschöneweide e.V., 56, Nalepa...
# 1654  Haus Wolfgang Raeder, 54, Leonberger Ring, Alt...
# 1655  Kulturzentrum Alte Schule, Selchowstraße, Sied...
# 1656  Narzissenweg, Kleingartenanlage Treue Seele, N...
# 1657  18, Müngersdorfer Straße, Siedlung Sachsenberg...
#
# [1658 rows x 22 columns]

# %%
# District mapping (official codes as strings)
district_mapping = {
    'Mitte': '11001001',
    'Friedrichshain-Kreuzberg': '11002002',
    'Pankow': '11003003',
    'Charlottenburg-Wilmersdorf': '11004004',
    'Spandau': '11005005',
    'Steglitz-Zehlendorf': '11006006',
    'Tempelhof-Schöneberg': '11007007',
    'Neukölln': '11008008',
    'Treptow-Köpenick': '11009009',
    'Marzahn-Hellersdorf': '11010010',
    'Lichtenberg': '11011011',
    'Reinickendorf': '11012012'
}

# Apply mapping to create district_id column
df_final['district_id'] = (
    df_final['district']
    .map(district_mapping)
    .astype(str)
)

# %%
df_final
# Out:
#      element     club_id                                 name       club  \
# 0       node    30012753                          Umspannwerk        NaN
# 1       node    60775321                                 KW76      poker
# 2       node   257709121                   Kulturhaus Spandau        NaN
# 3       node   266630320                 Buergeramt Mahlsdorf        NaN
# 4       node   268915262                          Karame e.V.        NaN
# ...      ...         ...                                  ...        ...
# 1653     way  1352576785   DAV OG Berlin Oberschöneweide e.V.    fishing
# 1654     way  1353882816                 Haus Wolfgang Raeder  gardening
# 1655     way  1387340919            Kulturzentrum Alte Schule        NaN
# 1656     way  1413964279              Vereinsheim Treue Seele        NaN
# 1657     way  1423837870  Begegnungszentrum im Kölner Viertel        NaN
#
#      leisure sport           amenity                  street housenumber  \
# 0        NaN   NaN      events_venue                     NaN         NaN
# 1        NaN   NaN               NaN      Konrad-Wolf-Straße          76
# 2        NaN   NaN       arts_centre                     NaN         NaN
# 3        NaN   NaN  community_centre          Hönower Straße          91
# 4        NaN   NaN  community_centre  Wilhelmshavener Straße          22
# ...      ...   ...               ...                     ...         ...
# 1653     NaN   NaN               NaN            Nalepastraße          56
# 1654     NaN   NaN  community_centre         Leonberger Ring          54
# 1655     NaN   NaN  community_centre                     NaN         NaN
# 1656     NaN   NaN  community_centre                     NaN         NaN
# 1657     NaN   NaN  community_centre    Müngersdorfer Straße          18
#
#      postcode  ...                    opening_hours  \
# 0         NaN  ...                          unknown
# 1         NaN  ...                          unknown
# 2         NaN  ...                          unknown
# 3       12623  ...                          unknown
# 4       10551  ...  mo-fr 13:00-18:00; sa-su,ph off
# ...       ...  ...                              ...
# 1653      NaN  ...                          unknown
# 1654      NaN  ...                          unknown
# 1655      NaN  ...                          unknown
# 1656      NaN  ...                          unknown
# 1657    12524  ...                          unknown
#
#                        geometry wheelchair   latitude  longitude  \
# 0     POINT (13.42919 52.49404)       true  52.494042  13.429187
# 1     POINT (13.48162 52.53862)    unknown  52.538623  13.481623
# 2     POINT (13.20231 52.53548)       true  52.535479  13.202312
# 3     POINT (13.61206 52.51314)       true  52.513140  13.612063
# 4       POINT (13.34154 52.531)      false  52.531002  13.341544
# ...                         ...        ...        ...        ...
# 1653  POINT (13.49774 52.47722)    unknown  52.477217  13.497736
# 1654  POINT (13.42883 52.42721)    unknown  52.427209  13.428828
# 1655  POINT (13.54977 52.43896)    unknown  52.438961  13.549769
# 1656  POINT (13.46274 52.47362)    unknown  52.473617  13.462736
# 1657   POINT (13.54737 52.4038)    unknown  52.403802  13.547368
#
#                       district  neighborhood_id          neighborhood  \
# 0     Friedrichshain-Kreuzberg             0202             Kreuzberg
# 1                  Lichtenberg             1110  Alt-Hohenschönhausen
# 2                      Spandau             0501               Spandau
# 3          Marzahn-Hellersdorf             1004             Mahlsdorf
# 4                        Mitte             0102                Moabit
# ...                        ...              ...                   ...
# 1653          Treptow-Köpenick             0909       Oberschöneweide
# 1654                  Neukölln             0802                 Britz
# 1655          Treptow-Köpenick             0907             Adlershof
# 1656                  Neukölln             0801              Neukölln
# 1657          Treptow-Köpenick             0906          Altglienicke
#
#                                            full_address district_id
# 0     Umspannwerk, Ohlauer Straße, Luisenstadt, Kreu...    11002002
# 1     KW76, 76, Konrad-Wolf-Straße, Wilhelmsberg, Al...    11011011
# 2     Kulturhaus Spandau, Mauerstraße, Altstadt, Spa...    11005005
# 3     Buergeramt Mahlsdorf, 91, Hönower Straße, Lich...    11010010
# 4     Karame e.V., 22, Wilhelmshavener Straße, Alt-M...    11001001
# ...                                                 ...         ...
# 1653  DAV OG Berlin Oberschöneweide e.V., 56, Nalepa...    11009009
# 1654  Haus Wolfgang Raeder, 54, Leonberger Ring, Alt...    11008008
# 1655  Kulturzentrum Alte Schule, Selchowstraße, Sied...    11009009
# 1656  Narzissenweg, Kleingartenanlage Treue Seele, N...    11008008
# 1657  18, Müngersdorfer Straße, Siedlung Sachsenberg...    11009009
#
# [1658 rows x 23 columns]

# %%
df_final = df_final.drop(columns=["element"])

# %%
# (Optional) Save enriched dataset for later use
df_final.to_csv("clubs_with_districts.csv", index=False)

# %% [markdown]
# ### Final Summary of Cleaned and Transformed Data

# %%
print("✅ Dataset after Steps cleaning and transforming\n")

# Shape of dataframe
print(f"Number of rows: {df_final.shape[0]}")
print(f"Number of columns: {df_final.shape[1]}")

# Column list
print("\nRemaining columns:")
print(df_final.columns.tolist())

# Missing values check
missing = df_final.isnull().sum()
print("\nMissing values after cleaning and transforming :")
print(missing)
# Out:
# ✅ Dataset after Steps cleaning and transforming
#
# Number of rows: 1658
# Number of columns: 22
#
# Remaining columns:
# ['club_id', 'name', 'club', 'leisure', 'sport', 'amenity', 'street', 'housenumber', 'postcode', 'website', 'phone', 'email', 'opening_hours', 'geometry', 'wheelchair', 'latitude', 'longitude', 'district', 'neighborhood_id', 'neighborhood', 'full_address', 'district_id']
#
# Missing values after cleaning and transforming :
# club_id               0
# name                  0
# club               1313
# leisure            1596
# sport              1443
# amenity             302
# street              553
# housenumber         563
# postcode            602
# website             955
# phone              1379
# email              1485
# opening_hours         0
# geometry              0
# wheelchair            0
# latitude              0
# longitude             0
# district              0
# neighborhood_id       0
# neighborhood          0
# full_address          0
# district_id           0
# dtype: int64

# %%
df_final.dtypes
# Out:
# club_id              object
# name                 object
# club                 object
# leisure              object
# sport                object
# amenity              object
# street               object
# housenumber          object
# postcode             object
# website              object
# phone                object
# email                object
# opening_hours        object
# geometry           geometry
# wheelchair           object
# latitude            float64
# longitude           float64
# district             object
# neighborhood_id      object
# neighborhood         object
# full_address         object
# district_id          object
# dtype: object

# %% [markdown]
# ### Step 3: Populate Database (Layereddb)

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine, text
import warnings

warnings.filterwarnings("ignore")

# %%
# convert 'geometry' as text
from shapely import wkt

df_final["geometry"] = df_final["geometry"].apply(lambda g: g.wkt if g else None)

# %%
# Connection details
host = 'localhost'
port = 5433
database = 'layereddb'
user = '*******'
password = '******'

# Create connection string
connection_string = f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}"

# Create engine
engine = create_engine(connection_string)

# %%
#this is where you create table with constraints and references first
create_table_query = f"""
CREATE TABLE IF NOT EXISTS berlin_source_data.social_clubs_activities (
    club_id VARCHAR(100) PRIMARY KEY,   -- OSM element id, stored as string
    name VARCHAR(200) NOT NULL,
    club VARCHAR(100),
    leisure VARCHAR(100),
    sport VARCHAR(100),
    amenity VARCHAR(100),
    street VARCHAR(200),
    housenumber VARCHAR(50),
    postcode VARCHAR(20),
    website VARCHAR(250),
    phone VARCHAR(100),
    email VARCHAR(150),
    opening_hours TEXT,
    wheelchair VARCHAR(50),
    latitude DECIMAL(9,6) NOT NULL,
    longitude DECIMAL(9,6) NOT NULL,
    district VARCHAR(100),
    neighborhood_id VARCHAR(100),
    neighborhood VARCHAR(100),
    full_address TEXT,
    district_id VARCHAR(100) NOT NULL,
    geometry TEXT,
    CONSTRAINT district_id_fk FOREIGN KEY (district_id)
        REFERENCES berlin_source_data.districts(district_id)
        ON DELETE RESTRICT
        ON UPDATE CASCADE
);
"""

# Execute the query to create empty table
with engine.connect() as conn:
    conn.execute(text(create_table_query))
    conn.commit()  # commit the transaction

# %%
#  Send the DataFrame to the database using .to_sql()
df_final.to_sql(
    'social_clubs_activities',      
    engine,
    schema='berlin_source_data' ,
    if_exists='append', # ✅ keeps table, just inserts data
    index=False
)

print("DataFrame sent to PostgreSQL using .to_sql() with psycopg2!")
# Out:
# DataFrame sent to PostgreSQL using .to_sql() with psycopg2!

# %%
##let's query test data!
query = f"""
SELECT * from berlin_source_data.social_clubs_activities
"""

# Execute the query
with engine.connect() as conn:
    df= pd.read_sql(text(query), conn)
    conn.commit()  # commit the transaction
df
# Out:
#          club_id                                 name       club leisure  \
# 0       30012753                          Umspannwerk       None    None
# 1       60775321                                 KW76      poker    None
# 2      257709121                   Kulturhaus Spandau       None    None
# 3      266630320                 Buergeramt Mahlsdorf       None    None
# 4      268915262                          Karame e.V.       None    None
# ...          ...                                  ...        ...     ...
# 1653  1352576785   DAV OG Berlin Oberschöneweide e.V.    fishing    None
# 1654  1353882816                 Haus Wolfgang Raeder  gardening    None
# 1655  1387340919            Kulturzentrum Alte Schule       None    None
# 1656  1413964279              Vereinsheim Treue Seele       None    None
# 1657  1423837870  Begegnungszentrum im Kölner Viertel       None    None
#
#      sport           amenity                  street housenumber postcode  \
# 0     None      events_venue                    None        None     None
# 1     None              None      Konrad-Wolf-Straße          76     None
# 2     None       arts_centre                    None        None     None
# 3     None  community_centre          Hönower Straße          91    12623
# 4     None  community_centre  Wilhelmshavener Straße          22    10551
# ...    ...               ...                     ...         ...      ...
# 1653  None              None            Nalepastraße          56     None
# 1654  None  community_centre         Leonberger Ring          54     None
# 1655  None  community_centre                    None        None     None
# 1656  None  community_centre                    None        None     None
# 1657  None  community_centre    Müngersdorfer Straße          18    12524
#
#                     website  ...                    opening_hours wheelchair  \
# 0                      None  ...                          unknown       true
# 1                      None  ...                          unknown    unknown
# 2                      None  ...                          unknown       true
# 3                      None  ...                          unknown       true
# 4                      None  ...  mo-fr 13:00-18:00; sa-su,ph off      false
# ...                     ...  ...                              ...        ...
# 1653                   None  ...                          unknown    unknown
# 1654                   None  ...                          unknown    unknown
# 1655                   None  ...                          unknown    unknown
# 1656                   None  ...                          unknown    unknown
# 1657  https://bik-verein.de  ...                          unknown    unknown
#
#        latitude  longitude                  district  neighborhood_id  \
# 0     52.494043  13.429187  Friedrichshain-Kreuzberg             0202
# 1     52.538623  13.481623               Lichtenberg             1110
# 2     52.535479  13.202312                   Spandau             0501
# 3     52.513140  13.612063       Marzahn-Hellersdorf             1004
# 4     52.531003  13.341544                     Mitte             0102
# ...         ...        ...                       ...              ...
# 1653  52.477217  13.497736          Treptow-Köpenick             0909
# 1654  52.427209  13.428828                  Neukölln             0802
# 1655  52.438961  13.549769          Treptow-Köpenick             0907
# 1656  52.473617  13.462736                  Neukölln             0801
# 1657  52.403802  13.547368          Treptow-Köpenick             0906
#
#               neighborhood                                       full_address  \
# 0                Kreuzberg  Umspannwerk, Ohlauer Straße, Luisenstadt, Kreu...
# 1     Alt-Hohenschönhausen  KW76, 76, Konrad-Wolf-Straße, Wilhelmsberg, Al...
# 2                  Spandau  Kulturhaus Spandau, Mauerstraße, Altstadt, Spa...
# 3                Mahlsdorf  Buergeramt Mahlsdorf, 91, Hönower Straße, Lich...
# 4                   Moabit  Karame e.V., 22, Wilhelmshavener Straße, Alt-M...
# ...                    ...                                                ...
# 1653       Oberschöneweide  DAV OG Berlin Oberschöneweide e.V., 56, Nalepa...
# 1654                 Britz  Haus Wolfgang Raeder, 54, Leonberger Ring, Alt...
# 1655             Adlershof  Kulturzentrum Alte Schule, Selchowstraße, Sied...
# 1656              Neukölln  Narzissenweg, Kleingartenanlage Treue Seele, N...
# 1657          Altglienicke  18, Müngersdorfer Straße, Siedlung Sachsenberg...
#
#      district_id                                       geometry
# 0       11002002                  POINT (13.4291868 52.4940425)
# 1       11011011                  POINT (13.4816226 52.5386233)
# 2       11005005                  POINT (13.2023117 52.5354787)
# 3       11010010                    POINT (13.6120626 52.51314)
# 4       11001001                  POINT (13.3415438 52.5310025)
# ...          ...                                            ...
# 1653    11009009                  POINT (13.4977362 52.4772169)
# 1654    11008008           POINT (13.428828205550849 52.427209)
# 1655    11009009  POINT (13.549768602710081 52.438960699999996)
# 1656    11008008  POINT (13.462735720606702 52.473617250000004)
# 1657    11009009  POINT (13.547368437940236 52.403802049999996)
#
# [1658 rows x 22 columns]
