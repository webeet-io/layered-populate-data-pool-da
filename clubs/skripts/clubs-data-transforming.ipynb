# %% [markdown]
# ### 🧪 Step 1: Research & Data Modelling
# PR Branch Name: clubs-data-modelling
#
# This notebook documents the process for Step 1 of the "Clubs & Social Activities in Berlin" project:
#
# - **1.1 Data Source Discovery**
# - **1.2 Modelling & Planning**
# - **1.3 Prepare the /sources Directory**
# - **1.4 Review**
#
# ---
#
# ### 🎯 Goal
# - Identify and document relevant data sources.
# - Select the key parameters for our use case.
# - Draft the planned table schema.
# - Plan cleaning and transformation steps before database population.
#
# ---
#
# ## 1.1 Data Source Discovery
#
# **Topic:** Clubs & Social Activities in Berlin
#
# **Main source:**
# - **Name:** OpenStreetMap (OSM) via OSMnx / Overpass API
# - **Source and origin:** Public crowdsourced geospatial database
# - **Update frequency:** Continuous (dynamic)
# - **Data type:** Dynamic (API query using tags such as `club=*`, `leisure=*`, `sport=*`, `community_centre=*`)
# - **Reason for selection:**
#   - Covers a wide variety of sports clubs, cultural clubs, and social activity centers in Berlin
#   - Includes geospatial data (coordinates, polygons), names, addresses, and attributes
#   - Open, free, and queryable programmatically
#
# **Optional additional sources:**
# - **Name:** Berliner Turn- und Freizeitsport-Bund (BTFB)  (https://btfb.de/vereinsservice/vereinssuche/#Vereine-im-Portrait)
#   - Source: Official Berlin sports association website
#   - Type: Static (manual export / scraping)
#   - Use: Provides official structured list of sports clubs in Berlin
#
# - **Name:** Berlin Open Data Portal (daten.berlin.de)
#   - Source: Berlin city government
#   - Type: Static or semi-static (CSV, GeoJSON)
#   - Use: Enrichment with official district boundaries or metadata
#
#   **Enrichment potential:**
# - Use Berlin shapefiles (districts, neighborhoods) for spatial joins.
#
#
# ---
#
# ## 1.2 Modelling & Planning
#
# **Key Parameters (planned):**
# - Identification: `name`, `club`, `category`, `subcategory`
# - Location: `address`, `district`, `geometry (lat/lon)`
# - Contact: `website`, `phone`, `email`
# - Attributes: `opening_hours`, `membership`, `fees`, `sport` / `leisure type`
# - Metadata: `source`, `last_updated`
#
# **Integration with existing tables:**
# - Join on `district_id` from the Berlin districts reference table.
#
#
# **Planned table schema:**
# ```sql
# CREATE TABLE berlin_clubs (
#     club_id SERIAL PRIMARY KEY,
#     name TEXT,
#     category TEXT,
#     subcategory TEXT,
#     street TEXT,
#     housenumber TEXT,
#     postcode TEXT,
#     district TEXT,
#     city TEXT,
#     country TEXT,
#     district_id INT REFERENCES berlin_districts(district_id),
#     latitude FLOAT,
#     longitude FLOAT,
#     website TEXT,
#     phone TEXT,
#     email TEXT,
#     opening_hours TEXT,
#     wheelchair TEXT
#
# );

# %%
# Install Libraries

# !pip install osmnx geopandas

# %%
# Import Libraries

import osmnx as ox
import geopandas as gpd
import pandas as pd

# %%
ox.settings.use_cache = False

# %%
# Define multiple tags
tags = {
    "amenity": ["community_centre", "arts_centre", "youth_centre", "music_school"],
    "leisure": ["sports_centre", "fitness_centre", "dance"],
    "club": True  # will capture all club types
}

clubs_gdf = ox.features_from_place("Berlin, Germany", tags)

print(clubs_gdf.head())
print(len(clubs_gdf), "clubs/activities found in Berlin")
# Out:
#                                     geometry addr:housenumber  \
# element id
# node    60775321   POINT (13.48162 52.53862)               76
#         257709121  POINT (13.20231 52.53548)              NaN
#         266630320  POINT (13.61206 52.51314)               91
#         268915262    POINT (13.34154 52.531)               22
#         268915306  POINT (13.41931 52.48888)                5
#
#                               addr:street   club                  name  \
# element id
# node    60775321       Konrad-Wolf-Straße  poker                  KW76
#         257709121                     NaN    NaN    Kulturhaus Spandau
#         266630320          Hönower Straße    NaN  Buergeramt Mahlsdorf
#         268915262  Wilhelmshavener Straße    NaN           Karame e.V.
#         268915306              Jahnstraße    NaN             Biberzahn
#
#                             amenity    contact:phone  \
# element id
# node    60775321                NaN              NaN
#         257709121       arts_centre   +49 30 3334021
#         266630320  community_centre              NaN
#         268915262  community_centre  +49 30 39035516
#         268915306  community_centre              NaN
#
#                                                      contact:website  \
# element id
# node    60775321                                                 NaN
#         257709121                  http://www.kulturhaus-spandau.de/
#         266630320                                                NaN
#         268915262                                  http://karame.de/
#         268915306  https://www.koop-verbund.de/koop-schülerläden/...
#
#                   toilets:wheelchair wheelchair  ... climbing source:geometry  \
# element id                                       ...
# node    60775321                 NaN        NaN  ...      NaN             NaN
#         257709121                yes        yes  ...      NaN             NaN
#         266630320                NaN        yes  ...      NaN             NaN
#         268915262                NaN         no  ...      NaN             NaN
#         268915306                NaN         no  ...      NaN             NaN
#
#                   name:he name:it nickname construction type length maxdepth  \
# element id
# node    60775321      NaN     NaN      NaN          NaN  NaN    NaN      NaN
#         257709121     NaN     NaN      NaN          NaN  NaN    NaN      NaN
#         266630320     NaN     NaN      NaN          NaN  NaN    NaN      NaN
#         268915262     NaN     NaN      NaN          NaN  NaN    NaN      NaN
#         268915306     NaN     NaN      NaN          NaN  NaN    NaN      NaN
#
#                   nudism
# element id
# node    60775321     NaN
#         257709121    NaN
#         266630320    NaN
#         268915262    NaN
#         268915306    NaN
#
# [5 rows x 387 columns]
# 2691 clubs/activities found in Berlin

# %%
clubs_gdf.describe()
# Out:
#                              geometry addr:housenumber        addr:street  \
# count                            2691             1506               1520
# unique                           2690              405                936
# top     POINT (13.3852669 52.5579387)                1  Schönhauser Allee
# freq                                2               41                 13
#
#          club        name           amenity    contact:phone  \
# count     385        2418              1045              322
# unique     47        2187                15              315
# top     sport  Sporthalle  community_centre  +49 30 22190011
# freq      204          20               775                5
#
#                    contact:website toilets:wheelchair wheelchair  ...  \
# count                          596                118        767  ...
# unique                         587                  2          3  ...
# top     https://www.teledisko.com/                yes        yes  ...
# freq                             3                 80        358  ...
#
#        climbing                               source:geometry  \
# count         1                                             1
# unique        1                                             1
# top     boulder  Geoportal Berlin / ALKIS Berlin - Flurstücke
# freq          1                                             1
#
#                   name:he                          name:it           nickname  \
# count                   1                                1                  1
# unique                  1                                1                  1
# top     בית תרבויות העולם  La casa delle culture del mondo  Schwangere Auster
# freq                    1                                1                  1
#
#        construction          type length maxdepth nudism
# count             3            19      1        1      1
# unique            1             1      1        1      1
# top             yes  multipolygon     50       12     no
# freq              3            19      1        1      1
#
# [4 rows x 387 columns]

# %%
clubs_gdf.columns
# Out:
# Index(['geometry', 'addr:housenumber', 'addr:street', 'club', 'name',
#        'amenity', 'contact:phone', 'contact:website', 'toilets:wheelchair',
#        'wheelchair',
#        ...
#        'climbing', 'source:geometry', 'name:he', 'name:it', 'nickname',
#        'construction', 'type', 'length', 'maxdepth', 'nudism'],
#       dtype='object', length=387)

# %%
clubs_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# MultiIndex: 2691 entries, ('node', np.int64(60775321)) to ('way', np.int64(1427539730))
# Columns: 387 entries, geometry to nudism
# dtypes: geometry(1), object(386)
# memory usage: 8.0+ MB

# %%
print(clubs_gdf.notnull().sum().sort_values(ascending=False).head(30))
# Out:
# geometry                    2691
# name                        2418
# addr:street                 1520
# addr:housenumber            1506
# addr:postcode               1450
# addr:city                   1416
# leisure                     1377
# addr:country                1046
# amenity                     1045
# addr:suburb                 1037
# website                      924
# sport                        907
# wheelchair                   767
# building                     692
# operator                     681
# opening_hours                639
# contact:website              596
# community_centre             479
# phone                        408
# club                         385
# check_date                   377
# contact:phone                322
# community_centre:for         308
# building:levels              291
# email                        232
# check_date:opening_hours     219
# contact:email                212
# source                       188
# description                  184
# opening_hours:signed         162
# dtype: int64

# %%
print(clubs_gdf.columns.tolist())
# Out:
# ['geometry', 'addr:housenumber', 'addr:street', 'club', 'name', 'amenity', 'contact:phone', 'contact:website', 'toilets:wheelchair', 'wheelchair', 'wheelchair:description', 'operator', 'website', 'addr:city', 'addr:country', 'addr:postcode', 'addr:suburb', 'check_date:opening_hours', 'community_centre', 'community_centre:for', 'description', 'opening_hours', 'fax', 'health_facility:type', 'lgbtq', 'phone', 'provided_for:homosexual', 'check_date', 'opening_hours:signed', 'operator:type', 'brand', 'brand:wikidata', 'brand:wikipedia', 'email', 'leisure', 'contact:email', 'contact:fax', 'sport', 'addr:floor', 'level', 'dance:teaching', 'mapillary', 'wikidata', 'wikimedia_commons', 'wikipedia', 'disused:name', 'disused:short_name', 'addr:housename', 'denomination', 'source', 'disused', 'outdoor_seating', 'smoking', 'dispensing', 'old_name', 'disused:shop', 'alt_name', 'description:en', 'fixme', 'short_name', 'access', 'contact:email_1', 'contact:name', 'fee', 'identity', 'indoor', 'interaction', 'internet_access', 'internet_access:fee', 'mode_of_organisation:decision_making', 'mode_of_organisation:hierarchy_chef', 'mode_of_organisation:members', 'mode_of_organisation:ownership_structure', 'mode_of_organisation:purpose', 'mode_of_organisation:scale_of_activity', 'mode_of_organisation:self_managed', 'owner', 'payment:cash', 'payment:donations', 'production_input:knowledge:free_licence', 'production_input:knowledge:p2p_licence', 'production_input:knowledge:public_domain', 'production_input:money:crowdfunding', 'production_input:money:gift', 'production_input:natural_recources:democratic', 'production_input:natural_recources:fair', 'production_input:natural_recources:regional', 'production_input:natural_resources:sustainable', 'production_input:supply_chain:fair', 'production_input:work:ilo_standards', 'provides', 'smoking:outside', 'start_date', 'contact:facebook', 'drink:coffee', 'second_hand', 'shop', 'name:alt', 'note', 'internet_access:ssid', 'payment:cards', 'payment:credit_cards', 'payment:debit_cards', 'bin', 'cold_water', 'contact:mastodon', 'contact:twitter', 'dishwasher', 'fridge', 'hot_water', 'kitchen:facilities', 'location', 'polling_station', 'service:3dprinter', 'toilets', 'toilets:access', 'toilets:handwashing', 'toilets:menstrual_products', 'toilets:num_chambers', 'url:spaceapi', 'indoor_seating', 'old_addr:housenumber', 'old_addr:street', 'table_football', 'dance:style', 'image', 'sauna', 'branch', 'mobile', 'culture', 'beauty', 'entrance', 'contact:foursquare', 'tourism', 'building', 'name:etymology:wikidata', 'contact:mobile', 'name:de', 'name:en', 'lgbtq:women', 'office', 'contact:instagram', 'lgbtq:men', 'callsign', 'communication:amateur_radio:callsign', 'fetish:bdsm', 'fetish:bears', 'fetish:leather', 'fetish:rubber', 'fetish:sneakers', 'fetish:uniform', 'fitness_centre:for', 'name:ja', 'drink:beer', 'drink:club-mate', 'alt_name:en', 'addr:inclusion', 'max_age', 'min_age', 'payment:coins', 'payment:maestro', 'payment:mastercard', 'payment:visa_electron', 'official_name', 'addr:room', 'facebook', 'instagram', 'name_1', 'personal_trainer', 'seamark:type', 'contact:phone:counter', 'contact:phone:member', 'opening_hours:member', 'network', 'phone:booking', 'currency:XBT', 'payment:lightning', 'payment:lightning_contactless', 'payment:onchain', 'survey:date', 'ref:vatin', 'opening_hours:covid19', 'disused:amenity', 'website:de', 'website:en', 'opening_hours:url', 'contact:linkedin', 'contact:youtube', 'swimming_pool', 'topic', 'diet:vegan', 'diet:vegetarian', 'contact:email:PGP', 'contact:bluesky', 'brewery', 'check_date:smoking', 'cuisine', 'reservation', 'drink:spezi', 'kitchen', 'microwave', 'ref', 'socket:schuko', 'addr:county', 'contact:email:pgp', 'contact:matrix', 'payment:notes', 'note:de', 'description:de', 'climbing:boulder', 'climbing:sport', 'climbing:toprope', 'is_in:city', 'is_in:country', 'is_in:country_code', 'name:fr', 'name:ro', 'operator:wikidata', 'female', 'air_conditioning', 'contact:telegram', ...

# %%
important_cols = [
    "name",               
    "club",                 
    "leisure",             
    "sport",                
    "amenity",               
    "addr:street",           
    "addr:housenumber",
    "addr:suburb",      
    "addr:postcode",         
    "addr:city",            
    "website",              
    "phone",             
    "email",               
    "opening_hours",         
    "geometry" ,
    "wheelchair"               
]

# %%
clubs_clean = clubs_gdf[important_cols].copy()

print(clubs_clean.head(10))
# Out:
#                                                           name   club leisure  \
# element id
# node    60775321                                          KW76  poker     NaN
#         257709121                           Kulturhaus Spandau    NaN     NaN
#         266630320                         Buergeramt Mahlsdorf    NaN     NaN
#         268915262                                  Karame e.V.    NaN     NaN
#         268915306                                    Biberzahn    NaN     NaN
#         268915454                            K3 Kiez-Kids-Klub    NaN     NaN
#         268916576  Katholische Pfarrei St. Matthias Schöneberg    NaN     NaN
#         268917395                      Schwulenberatung Berlin    NaN     NaN
#         270742541                                Max und Marek    NaN     NaN
#         270919303                                Stamm Kimbern  scout     NaN
#
#                   sport           amenity             addr:street  \
# element id
# node    60775321    NaN               NaN      Konrad-Wolf-Straße
#         257709121   NaN       arts_centre                     NaN
#         266630320   NaN  community_centre          Hönower Straße
#         268915262   NaN  community_centre  Wilhelmshavener Straße
#         268915306   NaN  community_centre              Jahnstraße
#         268915454   NaN  community_centre             Kirchstraße
#         268916576   NaN  community_centre             Goltzstraße
#         268917395   NaN  community_centre           Niebuhrstraße
#         270742541   NaN  community_centre         Neue Hochstraße
#         270919303   NaN               NaN       Kaiserstuhlstraße
#
#                   addr:housenumber    addr:suburb addr:postcode addr:city  \
# element id
# node    60775321                76            NaN           NaN       NaN
#         257709121              NaN            NaN           NaN       NaN
#         266630320               91      Mahlsdorf         12623    Berlin
#         268915262               22         Moabit         10551    Berlin
#         268915306                5      Kreuzberg         10967    Berlin
#         268915454                4         Moabit         10557    Berlin
#         268916576               29     Schöneberg         10781    Berlin
#         268917395            59/60            NaN         10629    Berlin
#         270742541               24            NaN         13347    Berlin
#         270919303               25  Schlachtensee         14129    Berlin
#
#                                                      website           phone  \
# element id
# node    60775321                                         NaN             NaN
#         257709121                                        NaN             NaN
#         266630320                                        NaN             NaN
#         268915262                                        NaN             NaN
#         268915306                                        NaN             NaN
#         268915454  http://www.frecherspatz.de/index.php/home             NaN
#         268916576                                        NaN             NaN
#         268917395         https://schwulenberatungberlin.de/  +49 233 690 70
#         270742541      https://clubberer04.de/max-und-marek/             NaN
#         270919303                   https://stamm-kimbern.de             NaN
#
#                   email                    opening_hours  \
# element id
# node    60775321    NaN                              NaN
#         257709121   NaN                              NaN
#         266630320   NaN                              NaN
#         268915262   NaN  Mo-Fr 13:00-18:00; Sa-Su,PH off
#         268915306   NaN                              NaN
#         268915454   NaN                              NaN
#         268916576   NaN                              NaN
#         268917395   NaN                Mo-Fr 09:00-20:00
#         270742541   NaN                              NaN
#         270919303   NaN                              NaN
#
#                                     geometry wheelchair
# element id
# node    60775321   POINT (13.48162 52.53862)        NaN
#         257709121  POINT (13.20231 52.53548)        yes
#         266630320  POINT (13.61206 52.51314)        yes
#         268915262    POINT (13.34154 52.531)         no
#         268915306  POINT (13.41931 52.48888)         no
#         268915454  POINT (13.34898 52.52389)         no
#         268916576   POINT (13.35381 52.4957)        NaN
#         268917395   POINT (13.30968 52.5044)        yes
#         270742541  POINT (13.37608 52.54262)         no
#         270919303   POINT (13.21266 52.4366)        NaN

# %%
clubs_clean.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# MultiIndex: 2691 entries, ('node', np.int64(60775321)) to ('way', np.int64(1427539730))
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              2418 non-null   object
#  1   club              385 non-null    object
#  2   leisure           1377 non-null   object
#  3   sport             907 non-null    object
#  4   amenity           1045 non-null   object
#  5   addr:street       1520 non-null   object
#  6   addr:housenumber  1506 non-null   object
#  7   addr:suburb       1037 non-null   object
#  8   addr:postcode     1450 non-null   object
#  9   addr:city         1416 non-null   object
#  10  website           924 non-null    object
#  11  phone             408 non-null    object
#  12  email             232 non-null    object
#  13  opening_hours     639 non-null    object
#  14  geometry          2691 non-null   geometry
#  15  wheelchair        767 non-null    object
# dtypes: geometry(1), object(15)
# memory usage: 431.3+ KB

# %%
# Ensure geometry type is Point for lat/lon extraction

clubs_clean = clubs_clean.to_crs(epsg=4326)

# %%
clubs_clean['geometry'] = clubs_clean['geometry'].apply(lambda geom: geom if geom.geom_type == 'Point' else geom.representative_point())
#Extract latitude and longitude
clubs_clean["latitude"] = clubs_clean.geometry.y
clubs_clean["longitude"] = clubs_clean.geometry.x
clubs_clean
# Out:
#                                                    name   club  \
# element id
# node    60775321                                   KW76  poker
#         257709121                    Kulturhaus Spandau    NaN
#         266630320                  Buergeramt Mahlsdorf    NaN
#         268915262                           Karame e.V.    NaN
#         268915306                             Biberzahn    NaN
# ...                                                 ...    ...
# way     1391342949                                  NaN    NaN
#         1413458990                          Spirit Joga    NaN
#         1413964279              Vereinsheim Treue Seele    NaN
#         1423837870  Begegnungszentrum im Kölner Viertel    NaN
#         1427539730                                  NaN    NaN
#
#                            leisure sport           amenity  \
# element id
# node    60775321               NaN   NaN               NaN
#         257709121              NaN   NaN       arts_centre
#         266630320              NaN   NaN  community_centre
#         268915262              NaN   NaN  community_centre
#         268915306              NaN   NaN  community_centre
# ...                            ...   ...               ...
# way     1391342949   sports_centre   NaN               NaN
#         1413458990  fitness_centre  yoga               NaN
#         1413964279             NaN   NaN  community_centre
#         1423837870             NaN   NaN  community_centre
#         1427539730  fitness_centre   NaN               NaN
#
#                                addr:street addr:housenumber     addr:suburb  \
# element id
# node    60775321        Konrad-Wolf-Straße               76             NaN
#         257709121                      NaN              NaN             NaN
#         266630320           Hönower Straße               91       Mahlsdorf
#         268915262   Wilhelmshavener Straße               22          Moabit
#         268915306               Jahnstraße                5       Kreuzberg
# ...                                    ...              ...             ...
# way     1391342949                     NaN              NaN             NaN
#         1413458990            Goethestraße              2-3  Charlottenburg
#         1413964279                     NaN              NaN             NaN
#         1423837870    Müngersdorfer Straße               18    Altglienicke
#         1427539730                     NaN              NaN             NaN
#
#                    addr:postcode addr:city                website phone email  \
# element id
# node    60775321             NaN       NaN                    NaN   NaN   NaN
#         257709121            NaN       NaN                    NaN   NaN   NaN
#         266630320          12623    Berlin                    NaN   NaN   NaN
#         268915262          10551    Berlin                    NaN   NaN   NaN
#         268915306          10967    Berlin                    NaN   NaN   NaN
# ...                          ...       ...                    ...   ...   ...
# way     1391342949           NaN       NaN                    NaN   NaN   NaN
#         1413458990         10623    Berlin                    NaN   NaN   NaN
#         1413964279           NaN       NaN                    NaN   NaN   NaN
#         1423837870         12524    Berlin  https://bik-verein.de   NaN   NaN
#         1427539730           NaN       NaN                    NaN   NaN   NaN
#
#                                       opening_hours  \
# element id
# node    60775321                                NaN
#         257709121                               NaN
#         266630320                               NaN
#         268915262   Mo-Fr 13:00-18:00; Sa-Su,PH off
#         268915306                               NaN
# ...                                             ...
# way     1391342949                              NaN
#         1413458990                              NaN
#         1413964279                              NaN
#         1423837870                              NaN
#         1427539730                              NaN
#
#                                      geometry wheelchair   latitude  longitude
# element id
# node    60775321    POINT (13.48162 52.53862)        NaN  52.538623  13.481623
#         257709121   POINT (13.20231 52.53548)        yes  52.535479  13.202312
#         266630320   POINT (13.61206 52.51314)        yes  52.513140  13.612063
#         268915262     POINT (13.34154 52.531)         no  52.531002  13.341544
#         268915306   POINT (13.41931 52.48888)         no  52.488882  13.419308
# ...                                       ...        ...        ...        ...
# way     1391342949  POINT (13.30022 52.56874)        NaN  52.568739  13.300225
#         1413458990  POINT (13.32365 52.50891)         no  52.508913  13.323650
#         1413964279  POINT (13.46274 52.47362)        NaN  52.473617  13.462736
#         1423837870   POINT (13.54737 52.4038)        NaN  52.403802  13.547368
#         1427539730  POINT (13.15883 52.52995)        NaN  52.529947  13.158828
#
# [2691 rows x 18 columns]

# %%
rename_map = {
    "addr:street": "street",
    "addr:housenumber": "housenumber",
    "addr:postcode": "postcode",
    "addr:city": "city",
    "addr:country": "country",
    "addr:suburb": "district"
}

# %%
# Rename the columns
clubs_df = clubs_clean.rename(columns=rename_map)

# %%
clubs_df.head()
# Out:
#                                    name   club leisure sport  \
# element id
# node    60775321                   KW76  poker     NaN   NaN
#         257709121    Kulturhaus Spandau    NaN     NaN   NaN
#         266630320  Buergeramt Mahlsdorf    NaN     NaN   NaN
#         268915262           Karame e.V.    NaN     NaN   NaN
#         268915306             Biberzahn    NaN     NaN   NaN
#
#                             amenity                  street housenumber  \
# element id
# node    60775321                NaN      Konrad-Wolf-Straße          76
#         257709121       arts_centre                     NaN         NaN
#         266630320  community_centre          Hönower Straße          91
#         268915262  community_centre  Wilhelmshavener Straße          22
#         268915306  community_centre              Jahnstraße           5
#
#                     district postcode    city website phone email  \
# element id
# node    60775321         NaN      NaN     NaN     NaN   NaN   NaN
#         257709121        NaN      NaN     NaN     NaN   NaN   NaN
#         266630320  Mahlsdorf    12623  Berlin     NaN   NaN   NaN
#         268915262     Moabit    10551  Berlin     NaN   NaN   NaN
#         268915306  Kreuzberg    10967  Berlin     NaN   NaN   NaN
#
#                                      opening_hours                   geometry  \
# element id
# node    60775321                               NaN  POINT (13.48162 52.53862)
#         257709121                              NaN  POINT (13.20231 52.53548)
#         266630320                              NaN  POINT (13.61206 52.51314)
#         268915262  Mo-Fr 13:00-18:00; Sa-Su,PH off    POINT (13.34154 52.531)
#         268915306                              NaN  POINT (13.41931 52.48888)
#
#                   wheelchair   latitude  longitude
# element id
# node    60775321         NaN  52.538623  13.481623
#         257709121        yes  52.535479  13.202312
#         266630320        yes  52.513140  13.612063
#         268915262         no  52.531002  13.341544
#         268915306         no  52.488882  13.419308

# %%
for col in ["name", "club", "leisure", "sport", "amenity"]:
    print(f"\n--- {col.upper()} ---")
    print(clubs_df[col].dropna().unique())
# Out:
# --- NAME ---
# ['KW76' 'Kulturhaus Spandau' 'Buergeramt Mahlsdorf' ... 'Spirit Joga'
#  'Vereinsheim Treue Seele' 'Begegnungszentrum im Kölner Viertel']
#
# --- CLUB ---
# ['poker' 'scout' 'sport' 'social' 'yes' 'dance' 'amateur_radio'
#  'automobile' 'fishing' 'Körperschaft_des_Öffentlichen_Rechts' 'culture'
#  'fan' 'animals' 'elderly' 'bonsai' 'dog' 'freemasonry' 'student'
#  'business' 'game' 'music' 'ethnic' 'Agrarbörse Deutschland Ost' 'linux'
#  'history' 'education' 'computer' 'religion' 'art' 'politics'
#  'board_games' 'youth_movement' 'archive' 'chess' 'sailing' 'science'
#  'humanist' 'charity' 'nature' 'hdk_0' 'youth' 'academic' 'motorcycle'
#  'allotment_club' 'allotments' 'TC Berolina Biesdorf' 'gardening']
#
# --- LEISURE ---
# ['fitness_centre' 'sports_centre' 'dance' 'hackerspace' 'pitch'
#  'playground' 'music_venue' 'garden' 'marina' 'track']
#
# --- SPORT ---
# ['bowling' '10pin' 'rowing' 'fitness' 'soccer' 'yoga' 'pilates'
#  'gymnastics' 'hapkido' 'swimming' 'kung_fu' 'fitness;weightlifting;yoga'
#  'athletics;fitness;multi' 'sailing' 'cycling' 'karting' 'dance' 'multi'
#  'fitness;gymnastics;exercise' 'judo' 'equestrian' 'scuba_diving'
#  'martial_arts' 'taijiquan' 'tennis' 'table_tennis' 'dancing' 'aikido'
#  'darts' 'climbing_adventure' 'gymnastics;fitness' 'tai_chi'
#  'martial_arts;judo'
#  'handball;athletics;basketball;triatlon;volleyball;gymnastics;water_sports;dance;9pin;fistball'
#  'climbing' 'poledance' 'karate;jiu-jitsu' 'budo' 'ems'
#  'boxing;kickboxing;wendo' 'bowling;table_tennis;badminton' 'yoga;pilates'
#  'rugby_union' 'chess' 'dance;dancing;fitness' 'kickboxing' 'axe_throwing'
#  'shooting' 'yoga;capoeira' 'tennis;ice_hockey' 'boxing'
#  'archery;shooting' 'baseball' 'martial_arts;self_defense' 'yoga;dance'
#  'bouldering' 'pole_dance' 'wingtsun' 'krav_maga' 'aikido;qigong'
#  'taekwondo' 'fitness;climbing' 'bicycle' 'shuffleboard'
#  'fitness;dancing;martial_arts'
#  'volleyball;basketball;badminton;table_tennis;gymnastics;handball;soccer'
#  'wingtsun;escrima' 'fitness;gym'
#  'fitness;basketball;handball;volleyball;orienteering;table_tennis;dancing;dance;gymnastics'
#  'archery' 'bodybuilding;fitness' 'fitness;crossfit' 'basketball'
#  'ems;power_plate' 'fitness;weightlifting' 'arrow_tag' 'laser_tag'
#  'snooker' 'crossfit;martial_arts;hyrox;hiit' 'volleyball'
#  'multi;yoga;fitness;running;swimming' 'canoe' 'padel'
#  'quadball;quidditch' 'yoga;fitness' 'martial_arts,kung_fu,wingtsun'
#  'martial_art' 'kayak' 'kendo' 'athletics; handball; chess; gymnastics'
#  'climbing;bouldering' 'beachvolleyball;soccer'
#  'roller_hockey;roller_derby' 'ice_skating'
#  'soccer;field_hockey;rugby;athletics' 'soccer;hockey' 'surfing'
#  'field_hockey' 'swimming;tennis;badminton' 'squash' 'athletics'
#  'skateboard' 'paddle_tennis' 'gym' 'bowls'
#  'squash;9pin;badminton;table_tennis;billiard;dart' 'soccer;tennis' '9pin'
#  'soccer;basketball' 'canoe;sailing'
#  'Karatedo Doshinkan;Serrada Escrima;Judo;Kung Fu;Karate;Bauchtanz;Boxen;Kick-Boxen'
#  'rowing;sailing'
#  'tennis;fitness;badminton;beachvolleyball;table_tennis;soccer'
#  'miniature_golf' 'boules' 'canoeing' 'hockey;tennis' 'boating' 'fishing'
#  'fitness;table_tennis;gymnastics' 'rowing;scuba_diving;sailing' 'bmx'
#  'beachvolleyball' 'soccer;athletics' 'cycling;swimming'
#  'softball;baseball' 'bmx;mtb']
#
# --- AMENITY ---
# ['arts_centre' 'community_centre' 'social_centre' 'music_school' 'pub'
#  'cafe' 'theatre' 'restaurant' 'dancing_school' 'events_venue' 'dojo'
#  'photo_booth' 'social_club' 'school' 'nightclub']

# %%
print(clubs_df.geometry.geom_type.value_counts())
# Out:
# Point    2691
# Name: count, dtype: int64

# %%
print("Missing geometries:", clubs_df.geometry.isna().sum())
# Out:
# Missing geometries: 0

# %%
# Goal: Verify lat/lon look realistic.
# Why? If values are way off, something went wrong in conversion.

print("Latitude range:", clubs_df["latitude"].min(), "to", clubs_df["latitude"].max())

print("Longitude range:", clubs_df["longitude"].min(), "to", clubs_df["longitude"].max())
# Out:
# Latitude range: 52.37387955 to 52.654758799999996
# Longitude range: 13.12237797012892 to 13.7311336

# %% [markdown]
# ## 1.3 Prepare the /sources Directory
# # Raw Data Files:
#
# - **clubs_raw.geojson** (includes geometry)
# - **clubs_raw.csv** (tabular only, no geometry)
# - **README.md** in /sources will contain:
#
# **Data sources used.**
# **Planned transformation steps.**

# %%
# Save locally
clubs_gdf.to_file("clubs_raw.geojson", driver="GeoJSON")
clubs_gdf.drop(columns="geometry").to_csv("clubs_raw.csv", index=False)
