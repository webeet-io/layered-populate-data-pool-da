# %%
import requests
from bs4 import BeautifulSoup

# URL of the webpage to scrape
url = 'https://edurank.org/geo/de-berlin/'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all university blocks
    university_blocks = soup.find_all('div', class_='block-cont')
    
    # List to store the scraped data
    universities_info = []
    
    for block in university_blocks:
        # Extract the university name
        university_name_tag = block.find('h2', class_='h4 font-weight-bold text-center')
        if university_name_tag and university_name_tag.find('a'):
            university_name = university_name_tag.find('a').text.strip()
        else:
            university_name = 'N/A'
        
        # Extract the rankings
        ranks = block.find_all('div', class_='uni-card__rank')
        rank_in_berlin_brandenburg = ranks[0].text.strip() if len(ranks) > 0 else 'N/A'
        rank_in_germany = ranks[1].text.strip() if len(ranks) > 1 else 'N/A'
        
        # Clean up the rankings to extract just the number
        rank_in_berlin_brandenburg = rank_in_berlin_brandenburg.split('#')[-1].strip()
        rank_in_germany = rank_in_germany.split('#')[-1].strip()
        
        # Append the extracted information to the list
        universities_info.append({
            'University Name': university_name,
            'Rank in Berlin-Brandenburg': rank_in_berlin_brandenburg,
            'Rank in Germany': rank_in_germany
        })
    
    # Print the scraped information
    for uni in universities_info:
        print(f"University Name: {uni['University Name']}")
        print(f"Rank in Berlin-Brandenburg: {uni['Rank in Berlin-Brandenburg']}")
        print(f"Rank in Germany: {uni['Rank in Germany']}")
        print("-" * 50)
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
# Out:
# University Name: N/A
# Rank in Berlin-Brandenburg: N/A
# Rank in Germany: N/A
# --------------------------------------------------
# University Name: 1. Free University of Berlin
# Rank in Berlin-Brandenburg: 1 in Brandenburg
# Rank in Germany: 5 in Germany
# --------------------------------------------------
# University Name: 2. Humboldt University of Berlin
# Rank in Berlin-Brandenburg: 2 in Brandenburg
# Rank in Germany: 8 in Germany
# --------------------------------------------------
# University Name: 3. Technical University of Berlin
# Rank in Berlin-Brandenburg: 3 in Brandenburg
# Rank in Germany: 19 in Germany
# --------------------------------------------------
# University Name: 4. Charite - Medical University of Berlin
# Rank in Berlin-Brandenburg: 4 in Brandenburg
# Rank in Germany: 21 in Germany
# --------------------------------------------------
# University Name: 5. Berlin University of Applied Sciences
# Rank in Berlin-Brandenburg: 7 in Brandenburg
# Rank in Germany: 84 in Germany
# --------------------------------------------------
# University Name: 6. Berlin School of Economics and Law
# Rank in Berlin-Brandenburg: 9 in Brandenburg
# Rank in Germany: 92 in Germany
# --------------------------------------------------
# University Name: 7. Berlin Technical University of Applied Sciences
# Rank in Berlin-Brandenburg: 10 in Brandenburg
# Rank in Germany: 95 in Germany
# --------------------------------------------------
# University Name: 8. Berlin University of the Arts
# Rank in Berlin-Brandenburg: 11 in Brandenburg
# Rank in Germany: 98 in Germany
# --------------------------------------------------
# University Name: 9. Hertie School of Governance
# Rank in Berlin-Brandenburg: 12 in Brandenburg
# Rank in Germany: 100 in Germany
# --------------------------------------------------
# University Name: 10. Steinbeis University
# Rank in Berlin-Brandenburg: 15 in Brandenburg
# Rank in Germany: 135 in Germany
# --------------------------------------------------
# University Name: 11. ESMT Berlin
# Rank in Berlin-Brandenburg: 16 in Brandenburg
# Rank in Germany: 153 in Germany
# --------------------------------------------------
# University Name: 12. Bard College Berlin
# Rank in Berlin-Brandenburg: 17 in Brandenburg
# Rank in Germany: 171 in Germany
# --------------------------------------------------
# University Name: 13. SRH University of Applied Sciences Berlin
# Rank in Berlin-Brandenburg: 18 in Brandenburg
# Rank in Germany: 180 in Germany
# --------------------------------------------------
# University Name: 14. University of Performing Arts Ernst Busch
# Rank in Berlin-Brandenburg: 19 in Brandenburg
# Rank in Germany: 190 in Germany
# --------------------------------------------------
# University Name: 15. International Psychoanalytic University
# Rank in Berlin-Brandenburg: 20 in Brandenburg
# Rank in Germany: 194 in Germany
# --------------------------------------------------
# University Name: 16. Psychological Institute in Berlin
# Rank in Berlin-Brandenburg: 21 in Brandenburg
# Rank in Germany: 201 in Germany
# --------------------------------------------------
# University Name: 17. Alice Salomon University of Applied Sciences, Berlin
# Rank in Berlin-Brandenburg: 24 in Brandenburg
# Rank in Germany: 215 in Germany
# --------------------------------------------------
# University Name: 18. Berlin-Weissensee Art Academy
# Rank in Berlin-Brandenburg: 25 in Brandenburg
# Rank in Germany: 222 in Germany
# --------------------------------------------------
# University Name: 19. Hanns Eisler Academy of Music
# Rank in Berlin-Brandenburg: 26 in Brandenburg
# Rank in Germany: 240 in Germany
# --------------------------------------------------
# University Name: 20. German University for Professional Studies
# Rank in Berlin-Brandenburg: 28 in Brandenburg
# Rank in Germany: 276 in Germany
# --------------------------------------------------
# University Name: 21. Mediadesign University of Applied Social Sciences
# Rank in Berlin-Brandenburg: 29 in Brandenburg
# Rank in Germany: 303 in Germany
# --------------------------------------------------
# University Name: 22. Quadriga University of Applied Social Sciences Berlin
# Rank in Berlin-Brandenburg: 30 in Brandenburg
# Rank in Germany: 304 in Germany
# --------------------------------------------------
# University Name: 23. University of Applied Sciences for Media, Communication and Management
# Rank in Berlin-Brandenburg: 32 in Brandenburg
# Rank in Germany: 312 in Germany
# --------------------------------------------------
# University Name: 24. Catholic University of Applied Social Sciences Berlin
# Rank in Berlin-Brandenburg: 33 in Brandenburg
# Rank in Germany: 313 in Germany
# --------------------------------------------------
# University Name: 25. University of Applied Sciences, Berlin
# Rank in Berlin-Brandenburg: 34 in Brandenburg
# Rank in Germany: 315 in Germany
# --------------------------------------------------
# University Name: 26. Protestant University of Applied Sciences in Berlin
# Rank in Berlin-Brandenburg: 35 in Brandenburg
# Rank in Germany: 316 in Germany
# --------------------------------------------------
# University Name: 27. H:G College of Health and Sports
# Rank in Berlin-Brandenburg: 36 in Brandenburg
# Rank in Germany: 329 in Germany
# --------------------------------------------------
# University Name: 28. MSB Medical School Berlin
# Rank in Berlin-Brandenburg: 37 in Brandenburg
# Rank in Germany: 330 in Germany
# --------------------------------------------------
# University Name: 29. BSP Business School Berlin
# Rank in Berlin-Brandenburg: 38 in Brandenburg
# Rank in Germany: 332 in Germany
# --------------------------------------------------
# University Name: 30. bbw University of Applied Sciences
# Rank in Berlin-Brandenburg: 39 in Brandenburg
# Rank in Germany: 338 in Germany
# --------------------------------------------------
# University Name: 31. ESMOD International University of Art for Fashion
# Rank in Berlin-Brandenburg: 40 in Brandenburg
# Rank in Germany: 341 in Germany
# --------------------------------------------------
# University Name: 32. VICTORIA, International University of Applied Sciences
# Rank in Berlin-Brandenburg: 41 in Brandenburg
# Rank in Germany: 343 in Germany
# --------------------------------------------------
# University Name: 33. DEKRA University of Applied Sciences
# Rank in Berlin-Brandenburg: 42 in Brandenburg
# Rank in Germany: 345 in Germany
# --------------------------------------------------
# University Name: 34. Akkon College of Human Sciences
# Rank in Berlin-Brandenburg: 43 in Brandenburg
# Rank in Germany: 346 in Germany
# --------------------------------------------------
# University Name: 35. IB University of Applied Social Sciences Berlin
# Rank in Berlin-Brandenburg: 44 in Brandenburg
# Rank in Germany: 349 in Germany
# --------------------------------------------------
# University Name: 36. Touro College Berlin
# Rank in Berlin-Brandenburg: 45 in Brandenburg
# Rank in Germany: 359 in Germany
# --------------------------------------------------
# University Name: N/A
# Rank in Berlin-Brandenburg: N/A
# Rank in Germany: N/A
# --------------------------------------------------
# University Name: N/A
# Rank in Berlin-Brandenburg: N/A
# Rank in Germany: N/A
# --------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
import csv
import os  # Import the os module

# URL of the webpage to scrape
url = 'https://edurank.org/geo/de-berlin/'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all university blocks
    university_blocks = soup.find_all('div', class_='block-cont')
    
    # List to store the scraped data
    universities_info = []
    
    for block in university_blocks:
        # Extract the university name
        university_name_tag = block.find('h2', class_='h4 font-weight-bold text-center')
        if university_name_tag and university_name_tag.find('a'):
            university_name = university_name_tag.find('a').text.strip()
        else:
            university_name = 'N/A'
        
        # Extract the rankings
        ranks = block.find_all('div', class_='uni-card__rank')
        rank_in_berlin_brandenburg = ranks[0].text.strip() if len(ranks) > 0 else 'N/A'
        rank_in_germany = ranks[1].text.strip() if len(ranks) > 1 else 'N/A'
        
        # Clean up the rankings to extract just the number
        rank_in_berlin_brandenburg = rank_in_berlin_brandenburg.split('#')[-1].strip()
        rank_in_germany = rank_in_germany.split('#')[-1].strip()
        
        # Append the extracted information to the list
        universities_info.append({
            'University Name': university_name,
            'Rank in Berlin-Brandenburg': rank_in_berlin_brandenburg,
            'Rank in Germany': rank_in_germany
        })
    
    # Specify the exact path to the Downloads directory
    downloads_path = '/Users/peterscheinsohn/Downloads'
    
    # Save the scraped information to a CSV file in the specified Downloads directory
    file_path = os.path.join(downloads_path, 'universities_berlin_rating.csv')
    with open(file_path, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.DictWriter(file, fieldnames=['University Name', 'Rank in Berlin-Brandenburg', 'Rank in Germany'])
        writer.writeheader()
        for uni in universities_info:
            writer.writerow(uni)
    
    print(f"Data has been saved to {file_path}")
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
# Out:
# Data has been saved to /Users/peterscheinsohn/Downloads/universities_berlin_rating.csv

# %%
import pandas as pd

# Load your CSV file into a DataFrame
df = pd.read_csv('universities_berlin_rating.csv')

# Display the initial DataFrame
print("Initial DataFrame:")
print(df)

# Remove rows where 'University Name' or any of the ratings are 'N/A'
df_cleaned = df.dropna(subset=['University Name', 'Rank in Berlin-Brandenburg', 'Rank in Germany'])

# Save the cleaned DataFrame to a new CSV file
df_cleaned.to_csv('universities_berlin_rating_cleaned.csv', index=False)

# Display the cleaned DataFrame
print("\nCleaned DataFrame:")
print(df_cleaned)
# Out:
# Initial DataFrame:
#                                       University Name  \
# 0                                                 NaN
# 1                        1. Free University of Berlin
# 2                    2. Humboldt University of Berlin
# 3                   3. Technical University of Berlin
# 4           4. Charite - Medical University of Berlin
# 5            5. Berlin University of Applied Sciences
# 6               6. Berlin School of Economics and Law
# 7   7. Berlin Technical University of Applied Scie...
# 8                    8. Berlin University of the Arts
# 9                      9. Hertie School of Governance
# 10                           10. Steinbeis University
# 11                                    11. ESMT Berlin
# 12                            12. Bard College Berlin
# 13      13. SRH University of Applied Sciences Berlin
# 14      14. University of Performing Arts Ernst Busch
# 15        15. International Psychoanalytic University
# 16              16. Psychological Institute in Berlin
# 17  17. Alice Salomon University of Applied Scienc...
# 18                  18. Berlin-Weissensee Art Academy
# 19                  19. Hanns Eisler Academy of Music
# 20     20. German University for Professional Studies
# 21  21. Mediadesign University of Applied Social S...
# 22  22. Quadriga University of Applied Social Scie...
# 23  23. University of Applied Sciences for Media, ...
# 24  24. Catholic University of Applied Social Scie...
# 25         25. University of Applied Sciences, Berlin
# 26  26. Protestant University of Applied Sciences ...
# 27               27. H:G College of Health and Sports
# 28                      28. MSB Medical School Berlin
# 29                     29. BSP Business School Berlin
# 30             30. bbw University of Applied Sciences
# 31  31. ESMOD International University of Art for ...
# 32  32. VICTORIA, International University of Appl...
# 33           33. DEKRA University of Applied Sciences
# 34                34. Akkon College of Human Sciences
# 35  35. IB University of Applied Social Sciences B...
# 36                           36. Touro College Berlin
# 37                                                NaN
# 38                                                NaN
#
#    Rank in Berlin-Brandenburg Rank in Germany
# 0                         NaN             NaN
# 1            1 in Brandenburg    5 in Germany
# 2            2 in Brandenburg    8 in Germany
# 3            3 in Brandenburg   19 in Germany
# 4            4 in Brandenburg   21 in Germany
# 5            7 in Brandenburg   84 in Germany
# 6            9 in Brandenburg   92 in Germany
# 7           10 in Brandenburg   95 in Germany
# 8           11 in Brandenburg   98 in Germany
# 9           12 in Brandenburg  100 in Germany
# 10          15 in Brandenburg  135 in Germany
# 11          16 in Brandenburg  153 in Germany
# 12          17 in Brandenburg  171 in Germany
# 13          18 in Brandenburg  180 in Germany
# 14          19 in Brandenburg  190 in Germany
# 15          20 in Brandenburg  194 in Germany
# 16          21 in Brandenburg  201 in Germany
# 17          24 in Brandenburg  215 in Germany
# 18          25 in Brandenburg  222 in Germany
# 19          26 in Brandenburg  240 in Germany
# 20          28 in Brandenburg  276 in Germany
# 21          29 in Brandenburg  303 in Germany
# 22          30 in Brandenburg  304 in Germany
# 23          32 in Brandenburg  312 in Germany
# 24          33 in Brandenburg  313 in Germany
# 25          34 in Brandenburg  315 in Germany
# 26          35 in Brandenburg  316 in Germany
# 27          36 in Brandenburg  329 in Germany
# 28          37 in Brandenburg  330 in Germany
# 29          38 in Brandenburg  332 in Germany
# 30          39 in Brandenburg  338 in Germany
# 31          40 in Brandenburg  341 in Germany
# 32          41 in Brandenburg  343 in Germany
# 33          42 in Brandenburg  345 in Germany
# 34          43 in Brandenburg  346 in Germany
# 35          44 in Brandenburg  349 in Germany
# 36          45 in Brandenburg  359 in Germany
# 37                        NaN             NaN
# 38                        NaN             NaN
#
# Cleaned DataFrame:
#                                       University Name  \
# 1                        1. Free University of Berlin
# 2                    2. Humboldt University of Berlin
# 3                   3. Technical University of Berlin
# 4           4. Charite - Medical University of Berlin
# 5            5. Berlin University of Applied Sciences
# 6               6. Berlin School of Economics and Law
# 7   7. Berlin Technical University of Applied Scie...
# 8                    8. Berlin University of the Arts
# 9                      9. Hertie School of Governance
# 10                           10. Steinbeis University
# 11                                    11. ESMT Berlin
# 12                            12. Bard College Berlin
# 13      13. SRH University of Applied Sciences Berlin
# 14      14. University of Performing Arts Ernst Busch
# 15        15. International Psychoanalytic University
# 16              16. Psychological Institute in Berlin
# 17  17. Alice Salomon University of Applied Scienc...
# 18                  18. Berlin-Weissensee Art Academy
# 19                  19. Hanns Eisler Academy of Music
# 20     20. German University for Professional Studies
# 21  21. Mediadesign University of Applied Social S...
# 22  22. Quadriga University of Applied Social Scie...
# 23  23. University of Applied Sciences for Media, ...
# 24  24. Catholic University of Applied Social Scie...
# 25         25. University of Applied Sciences, Berlin
# 26  26. Protestant University of Applied Sciences ...
# 27               27. H:G College of Health and Sports
# 28                      28. MSB Medical School Berlin
# 29                     29. BSP Business School Berlin
# 30             30. bbw University of Applied Sciences
# 31  31. ESMOD International University of Art for ...
# 32  32. VICTORIA, International University of Appl...
# 33           33. DEKRA University of Applied Sciences
# 34                34. Akkon College of Human Sciences
# 35  35. IB University of Applied Social Sciences B...
# 36                           36. Touro College Berlin
#
#    Rank in Berlin-Brandenburg Rank in Germany
# 1            1 in Brandenburg    5 in Germany
# 2            2 in Brandenburg    8 in Germany
# 3            3 in Brandenburg   19 in Germany
# 4            4 in Brandenburg   21 in Germany
# 5            7 in Brandenburg   84 in Germany
# 6            9 in Brandenburg   92 in Germany
# 7           10 in Brandenburg   95 in Germany
# 8           11 in Brandenburg   98 in Germany
# 9           12 in Brandenburg  100 in Germany
# 10          15 in Brandenburg  135 in Germany
# 11          16 in Brandenburg  153 in Germany
# 12          17 in Brandenburg  171 in Germany
# 13          18 in Brandenburg  180 in Germany
# 14          19 in Brandenburg  190 in Germany
# 15          20 in Brandenburg  194 in Germany
# 16          21 in Brandenburg  201 in Germany
# 17          24 in Brandenburg  215 in Germany
# 18          25 in Brandenburg  222 in Germany
# 19          26 in Brandenburg  240 in Germany
# 20          28 in Brandenburg  276 in Germany
# 21          29 in Brandenburg  303 in Germany
# 22          30 in Brandenburg  304 in Germany
# 23          32 in Brandenburg  312 in Germany
# 24          33 in Brandenburg  313 in Germany
# 25          34 in Brandenburg  315 in Germany
# 26          35 in Brandenburg  316 in Germany
# 27          36 in Brandenburg  329 in Germany
# 28          37 in Brandenburg  330 in Germany
# 29          38 in Brandenburg  332 in Germany
# 30          39 in Brandenburg  338 in Germany
# 31          40 in Brandenburg  341 in Germany
# 32          41 in Brandenburg  343 in Germany
# 33          42 in Brandenburg  345 in Germany
# 34          43 in Brandenburg  346 in Germany
# 35          44 in Brandenburg  349 in Germany
# 36          45 in Brandenburg  359 in Germany

# %%
import pandas as pd

# Load your CSV file into a DataFrame
df = pd.read_csv('universities_berlin_rating_cleaned.csv')

# Display the initial DataFrame
print("Initial DataFrame:")
print(df)

# Function to extract numeric part from a string
def extract_numeric(value):
    if pd.isna(value):
        return None
    return int(''.join(filter(str.isdigit, str(value))))

# Apply the function to the rating columns
df['Rank in Berlin-Brandenburg'] = df['Rank in Berlin-Brandenburg'].apply(extract_numeric)
df['Rank in Germany'] = df['Rank in Germany'].apply(extract_numeric)

# Convert the rating columns to integers
df['Rank in Berlin-Brandenburg'] = pd.to_numeric(df['Rank in Berlin-Brandenburg'], errors='coerce')
df['Rank in Germany'] = pd.to_numeric(df['Rank in Germany'], errors='coerce')

# Save the updated DataFrame to a new CSV file
df.to_csv('universities_berlin_rating_final.csv', index=False)

# Display the cleaned DataFrame
print("\nFinal DataFrame:")
print(df)
# Out:
# Initial DataFrame:
#                                       University Name  \
# 0                        1. Free University of Berlin
# 1                    2. Humboldt University of Berlin
# 2                   3. Technical University of Berlin
# 3           4. Charite - Medical University of Berlin
# 4            5. Berlin University of Applied Sciences
# 5               6. Berlin School of Economics and Law
# 6   7. Berlin Technical University of Applied Scie...
# 7                    8. Berlin University of the Arts
# 8                      9. Hertie School of Governance
# 9                            10. Steinbeis University
# 10                                    11. ESMT Berlin
# 11                            12. Bard College Berlin
# 12      13. SRH University of Applied Sciences Berlin
# 13      14. University of Performing Arts Ernst Busch
# 14        15. International Psychoanalytic University
# 15              16. Psychological Institute in Berlin
# 16  17. Alice Salomon University of Applied Scienc...
# 17                  18. Berlin-Weissensee Art Academy
# 18                  19. Hanns Eisler Academy of Music
# 19     20. German University for Professional Studies
# 20  21. Mediadesign University of Applied Social S...
# 21  22. Quadriga University of Applied Social Scie...
# 22  23. University of Applied Sciences for Media, ...
# 23  24. Catholic University of Applied Social Scie...
# 24         25. University of Applied Sciences, Berlin
# 25  26. Protestant University of Applied Sciences ...
# 26               27. H:G College of Health and Sports
# 27                      28. MSB Medical School Berlin
# 28                     29. BSP Business School Berlin
# 29             30. bbw University of Applied Sciences
# 30  31. ESMOD International University of Art for ...
# 31  32. VICTORIA, International University of Appl...
# 32           33. DEKRA University of Applied Sciences
# 33                34. Akkon College of Human Sciences
# 34  35. IB University of Applied Social Sciences B...
# 35                           36. Touro College Berlin
#
#    Rank in Berlin-Brandenburg Rank in Germany
# 0            1 in Brandenburg    5 in Germany
# 1            2 in Brandenburg    8 in Germany
# 2            3 in Brandenburg   19 in Germany
# 3            4 in Brandenburg   21 in Germany
# 4            7 in Brandenburg   84 in Germany
# 5            9 in Brandenburg   92 in Germany
# 6           10 in Brandenburg   95 in Germany
# 7           11 in Brandenburg   98 in Germany
# 8           12 in Brandenburg  100 in Germany
# 9           15 in Brandenburg  135 in Germany
# 10          16 in Brandenburg  153 in Germany
# 11          17 in Brandenburg  171 in Germany
# 12          18 in Brandenburg  180 in Germany
# 13          19 in Brandenburg  190 in Germany
# 14          20 in Brandenburg  194 in Germany
# 15          21 in Brandenburg  201 in Germany
# 16          24 in Brandenburg  215 in Germany
# 17          25 in Brandenburg  222 in Germany
# 18          26 in Brandenburg  240 in Germany
# 19          28 in Brandenburg  276 in Germany
# 20          29 in Brandenburg  303 in Germany
# 21          30 in Brandenburg  304 in Germany
# 22          32 in Brandenburg  312 in Germany
# 23          33 in Brandenburg  313 in Germany
# 24          34 in Brandenburg  315 in Germany
# 25          35 in Brandenburg  316 in Germany
# 26          36 in Brandenburg  329 in Germany
# 27          37 in Brandenburg  330 in Germany
# 28          38 in Brandenburg  332 in Germany
# 29          39 in Brandenburg  338 in Germany
# 30          40 in Brandenburg  341 in Germany
# 31          41 in Brandenburg  343 in Germany
# 32          42 in Brandenburg  345 in Germany
# 33          43 in Brandenburg  346 in Germany
# 34          44 in Brandenburg  349 in Germany
# 35          45 in Brandenburg  359 in Germany
#
# Final DataFrame:
#                                       University Name  \
# 0                        1. Free University of Berlin
# 1                    2. Humboldt University of Berlin
# 2                   3. Technical University of Berlin
# 3           4. Charite - Medical University of Berlin
# 4            5. Berlin University of Applied Sciences
# 5               6. Berlin School of Economics and Law
# 6   7. Berlin Technical University of Applied Scie...
# 7                    8. Berlin University of the Arts
# 8                      9. Hertie School of Governance
# 9                            10. Steinbeis University
# 10                                    11. ESMT Berlin
# 11                            12. Bard College Berlin
# 12      13. SRH University of Applied Sciences Berlin
# 13      14. University of Performing Arts Ernst Busch
# 14        15. International Psychoanalytic University
# 15              16. Psychological Institute in Berlin
# 16  17. Alice Salomon University of Applied Scienc...
# 17                  18. Berlin-Weissensee Art Academy
# 18                  19. Hanns Eisler Academy of Music
# 19     20. German University for Professional Studies
# 20  21. Mediadesign University of Applied Social S...
# 21  22. Quadriga University of Applied Social Scie...
# 22  23. University of Applied Sciences for Media, ...
# 23  24. Catholic University of Applied Social Scie...
# 24         25. University of Applied Sciences, Berlin
# 25  26. Protestant University of Applied Sciences ...
# 26               27. H:G College of Health and Sports
# 27                      28. MSB Medical School Berlin
# 28                     29. BSP Business School Berlin
# 29             30. bbw University of Applied Sciences
# 30  31. ESMOD International University of Art for ...
# 31  32. VICTORIA, International University of Appl...
# 32           33. DEKRA University of Applied Sciences
# 33                34. Akkon College of Human Sciences
# 34  35. IB University of Applied Social Sciences B...
# 35                           36. Touro College Berlin
#
#     Rank in Berlin-Brandenburg  Rank in Germany
# 0                            1                5
# 1                            2                8
# 2                            3               19
# 3                            4               21
# 4                            7               84
# 5                            9               92
# 6                           10               95
# 7                           11               98
# 8                           12              100
# 9                           15              135
# 10                          16              153
# 11                          17              171
# 12                          18              180
# 13                          19              190
# 14                          20              194
# 15                          21              201
# 16                          24              215
# 17                          25              222
# 18                          26              240
# 19                          28              276
# 20                          29              303
# 21                          30              304
# 22                          32              312
# 23                          33              313
# 24                          34              315
# 25                          35              316
# 26                          36              329
# 27                          37              330
# 28                          38              332
# 29                          39              338
# 30                          40              341
# 31                          41              343
# 32                          42              345
# 33                          43              346
# 34                          44              349
# 35                          45              359
