# %% [markdown]
# # Malls In Berlin

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, Table, Column, Integer, String, MetaData, ForeignKey, Float, BigInteger
import psycopg2
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Connect to Database

# %%
user_name='hakim_murphy'
password='R7y12MdUu6L3w8wC'

# %%
host = 'localhost'
port = '5433'
database = 'layereddb'
schema='berlin_source_data'

#connection to db after you opened tunnel
engine = create_engine(f'postgresql+psycopg2://{user_name}:{password}@{host}:{port}/{database}')

# %% [markdown]
# ## Import CSV

# %%
df = pd.read_csv("../sources/osm_malls_with_boundaries.csv")
df.head()
# Out:
#   osm_type      osm_id             name_left              website  \
# 0     node   360009454         Cladow-Center                  NaN
# 1     node  2782835444             Nordmeile                  NaN
# 2     node  3982921774   Springpfuhl-Passage                  NaN
# 3     node  5024078544      Fennpfuhl-Karree                  NaN
# 4      way    10632546  Hallen am Borsigturm  http://www.hab-2.de
#
#        opening_hours    addr_street addr_housenumber  addr_postcode addr_city  \
# 0                NaN            NaN              NaN            NaN       NaN
# 1  Mo-Sa 07:00-21:00    Oraniendamm             6-10        13469.0    Berlin
# 2                NaN            NaN              NaN            NaN       NaN
# 3               24/7            NaN              NaN            NaN       NaN
# 4  Mo-Sa 10:00-20:00  Am Borsigturm                2        13507.0    Berlin
#
#          lat  ...  gem_left namgem_left namlan_left lan_left index__neigh  \
# 0  52.455157  ...       NaN         NaN         NaN      NaN          NaN
# 1  52.607867  ...       NaN         NaN         NaN      NaN          NaN
# 2  52.526728  ...       NaN         NaN         NaN      NaN          NaN
# 3  52.528781  ...       NaN         NaN         NaN      NaN          NaN
# 4  52.584576  ...       NaN         NaN         NaN      NaN          NaN
#
#    name gem__neigh namgem__neigh  namlan__neigh  lan__neigh
# 0   NaN        NaN           NaN            NaN         NaN
# 1   NaN        NaN           NaN            NaN         NaN
# 2   NaN        NaN           NaN            NaN         NaN
# 3   NaN        NaN           NaN            NaN         NaN
# 4   NaN        NaN           NaN            NaN         NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Exploring the Data

# %%
df.T
# Out:
#                                             0    \
# osm_type                                   node
# osm_id                                360009454
# name_left                         Cladow-Center
# website                                     NaN
# opening_hours                               NaN
# addr_street                                 NaN
# addr_housenumber                            NaN
# addr_postcode                               NaN
# addr_city                                   NaN
# lat                                   52.455157
# lon                                   13.144413
# wheelchair                                  yes
# operator                                    NaN
# brand                                       NaN
# start_date                                  NaN
# level                                       NaN
# source                             OSM Overpass
# geometry          POINT (13.1444131 52.4551567)
# index__district                             NaN
# name__district                              NaN
# gem_left                                    NaN
# namgem_left                                 NaN
# namlan_left                                 NaN
# lan_left                                    NaN
# index__neigh                                NaN
# name                                        NaN
# gem__neigh                                  NaN
# namgem__neigh                               NaN
# namlan__neigh                               NaN
# lan__neigh                                  NaN
#
#                                             1    \
# osm_type                                   node
# osm_id                               2782835444
# name_left                             Nordmeile
# website                                     NaN
# opening_hours                 Mo-Sa 07:00-21:00
# addr_street                         Oraniendamm
# addr_housenumber                           6-10
# addr_postcode                           13469.0
# addr_city                                Berlin
# lat                                   52.607867
# lon                                   13.325992
# wheelchair                                  NaN
# operator                                    NaN
# brand                                       NaN
# start_date                                  NaN
# level                                       NaN
# source                             OSM Overpass
# geometry          POINT (13.3259918 52.6078674)
# index__district                             NaN
# name__district                              NaN
# gem_left                                    NaN
# namgem_left                                 NaN
# namlan_left                                 NaN
# lan_left                                    NaN
# index__neigh                                NaN
# name                                        NaN
# gem__neigh                                  NaN
# namgem__neigh                               NaN
# namlan__neigh                               NaN
# lan__neigh                                  NaN
#
#                                             2    \
# osm_type                                   node
# osm_id                               3982921774
# name_left                   Springpfuhl-Passage
# website                                     NaN
# opening_hours                               NaN
# addr_street                                 NaN
# addr_housenumber                            NaN
# addr_postcode                               NaN
# addr_city                                   NaN
# lat                                   52.526728
# lon                                   13.540104
# wheelchair                                  yes
# operator                                    NaN
# brand                                       NaN
# start_date                                  NaN
# level                                       NaN
# source                             OSM Overpass
# geometry          POINT (13.5401045 52.5267284)
# index__district                             NaN
# name__district                              NaN
# gem_left                                    NaN
# namgem_left                                 NaN
# namlan_left                                 NaN
# lan_left                                    NaN
# index__neigh                                NaN
# name                                        NaN
# gem__neigh                                  NaN
# namgem__neigh                               NaN
# namlan__neigh                               NaN
# lan__neigh                                  NaN
#
#                                             3    \
# osm_type                                   node
# osm_id                               5024078544
# name_left                      Fennpfuhl-Karree
# website                                     NaN
# opening_hours                              24/7
# addr_street                                 NaN
# addr_housenumber                            NaN
# addr_postcode                               NaN
# addr_city                                   NaN
# lat                                   52.528781
# lon                                   13.471797
# wheelchair                                  yes
# operator                                    NaN
# brand                                       NaN
# start_date                                  NaN
# level                                       NaN
# source                             OSM Overpass
# geometry          POINT (13.4717971 52.5287807)
# index__district                             NaN
# name__district                              NaN
# gem_left                                    NaN
# namgem_left                                 NaN
# namlan_left                                 NaN
# lan_left                                    NaN
# index__neigh                                NaN
# name                                        NaN
# gem__neigh                                  NaN
# namgem__neigh                               NaN
# namlan__neigh                               NaN
# lan__neigh                                  NaN
#
#                                             4    \
# osm_type                                    way
# osm_id                                 10632546
# name_left                  Hallen am Borsigturm
# website                     http://www.hab-2.de
# opening_hours                 Mo-Sa 10:00-20:00
# addr_street                       Am Borsigturm
# addr_housenumber                              2
# addr_postcode                           13507.0
# addr_city                                Berlin
# lat                                   52.584576
# lon                                   13.285772
# wheelchair                                  yes
# operator                                    NaN
# brand                                       NaN
# start_date                                  NaN
# level                                       NaN
# source                             OSM Overpass
# geometry          POINT (13.2857717 52.5845756)
# index__district                             NaN
# name__district                              NaN
# gem_left                                    NaN
# namgem_left                                 NaN
# namlan_left                                 NaN
# lan_left                                    NaN
# index__neigh                                NaN
# name                                        NaN
# gem__neigh                                  NaN
# namgem__neigh                               NaN
# namlan__neigh                               NaN
# lan__neigh                                  NaN
#
#                                             5    \
# osm_type                                    way
# osm_id                                 11076700
# name_left            Einkaufszentrum »Der Clou«
# website           https://www.derclouberlin.de/
# opening_hours                 Mo-Sa 10:00-20:00
# addr_street                   Scharnweberstraße
# addr_housenumber                            140
# addr_postcode                           13405.0
# addr_city                                Berlin
# lat                                   52.563039
# lon                                   13.328485
# wheelchair                                  yes
# operator                                    NaN
# brand                                       NaN
# start_date                                  NaN
# level                                       NaN
# source                             OSM Overpass
# geometry          POINT (13.3284849 52.5630387)
# index__district                             NaN
# name__district                              NaN
# gem_left                                    NaN
# namgem_left                                 NaN
# namlan_left                                 NaN
# lan_left                                    NaN
# index__neigh                                NaN
# name                                        NaN
# gem__neigh                                  NaN
# namgem__neigh                               NaN
# namlan__neigh                               NaN
# lan__neigh                                  NaN
#
#                                                 6    \
# osm_type                                        way
# osm_id                                     11249452
# name_left                             Linden Center
# website           https://m.linden-center-berlin.de
# opening_hours                     Mo-Sa 09:30-20:00
# addr_street                          Prerower Platz
# addr_housenumber                                  1
# addr_postcode                               13051.0
# addr_city                                    Berlin
# lat                                       52.564378
# lon                                        13.50604
# wheelchair                                      yes
# operator                                        NaN
# brand                                           NaN
# start_date                                      NaN
# level                                           NaN
# source                                 OSM Overpass
# geometry              POINT (13.5060401 52.5643776)
# index__district                                 NaN
# name__district                                  NaN
# gem_left                                        NaN
# namgem_left                                     NaN
# namlan_left                                     NaN
# lan_left                                        NaN
# index__neigh                                    NaN
# name                                            NaN
# gem__neigh                                      NaN
# namgem__neigh                                   NaN
# namlan__neigh                                   NaN
# lan__neigh                                      NaN
#
#                                            7                              8    \
# osm_type                                   way                            way
# osm_id                                11249566                       18771934
# name_left                  Allee-Center Berlin            Bahnhof Lichtenberg
# website                                    NaN                            NaN
# opening_hours                Mo-Sa 07:00-20:00                    06:00-22:00
# addr_street                  Landsberger Allee                 Weitlingstraße
# addr_housenumber                           277                             22
# addr_postcode                          13055.0                        10317.0
# addr_city                               Berlin                         Berlin
# lat                                  52.535248                      52.509421
# lon                                  13.496467                      13.496944
# wheelchair                                 yes                            yes
# operator                                   NaN                            NaN
# brand                                      NaN                            NaN
# start_date                                 NaN                            NaN
# level                                      NaN                            NaN
# source                            OSM Overpass                   OSM Overpass
# geometry          POINT (13.4964673 52.535248)  POINT (13.4969436 52.5094209)
# index__district                            NaN                            NaN
# name__district                             NaN                            NaN
# gem_left                                   NaN                            NaN
# namgem_left                                NaN                            NaN
# namlan_left                                NaN                            NaN
# lan_left                                   NaN                            NaN
# index__neigh                               NaN                            NaN
# name                                       NaN                            NaN
# gem__neigh                                 NaN                            NaN
# namgem__neigh                              NaN                            NaN
# namlan__neigh                              NaN                            NaN
# lan__neigh                                 NaN                            NaN
#
#                                                    9    ...  \
# osm_type                                           way  ...
# osm_id                                        20980117  ...
# name_left                         Gesundbrunnen-Center  ...
# website           https://www.gesundbrunnen-center.de/  ...
# opening_hours                        Mo-Sa 08:00-21:00  ...
# addr_street                                  Badstraße  ...
# addr_housenumber                                     4  ...
# addr_postcode                                  13357.0  ...
# addr_city                                       Berlin  ...
# lat                                          52.549773  ...
# lon                                           13.38953  ...
# wheelchair                                         yes  ...
# operator                                           NaN  ...
# brand                                              NaN  ...
# start_date                                         NaN  ...
# level                                              NaN  ...
# source                                    OSM Overpass  ...
# geometry                  POINT (13.3895302 52.549773)  ...
# index__district                                    NaN  ...
# name__district                                     NaN  ...
# gem_left                                           NaN  ...
# namgem_left                                        NaN  ...
# namlan_left                                        NaN  ...
# lan_left                                           NaN  ...
# index__neigh                                       NaN  ...
# name                                               NaN  ...
# gem__neigh                                         NaN  ...
# namgem__neigh                                      NaN  ...
# namlan__neigh                                      NaN  ...
# lan__neigh                                         NaN  ...
#
#                                             94                            95   \
# osm_type                                    way                           way
# osm_id                               1065811824                    1238152790
# name_left                 Ring-Center Berlin II             Tempelhofer Hafen
# website                                     NaN                           NaN
# opening_hours         Mo-Sa 10:00-20:00; PH off             Mo-Sa 10:00-20:00
# addr_street                   Frankfurter Allee                           NaN
# addr_housenumber                        113-117                           NaN
# addr_postcode                           10365.0                           NaN
# addr_city                                Berlin                           NaN
# lat                                   52.514327                     52.455806
# lon                                   13.476502                     13.386016
# wheelchair                                  yes                           yes
# operator                                    NaN                           NaN
# brand                                       NaN                           NaN
# start_date                                  NaN                    2009-04-29
# level                                       NaN                           NaN
# source                             OSM Overpass                  OSM Overpass
# geometry          POINT (13.4765019 52.5143274)  POINT (13.386016 52.4558061)
# index__district                             NaN                           NaN
# name__district                              NaN                           NaN
# gem_left                                    NaN                           NaN
# namgem_left                                 NaN                           NaN
# namlan_left                                 NaN                           NaN
# lan_left                                    NaN                           NaN
# index__neigh                                NaN                           NaN
# name                                        NaN                           NaN
# gem__neigh                                  NaN                           NaN
# namgem__neigh                               NaN                           NaN
# namlan__neigh                               NaN                           NaN
# lan__neigh                                  NaN                           NaN
#
#                                                   96   \
# osm_type                                          way
# osm_id                                     1244901436
# name_left                          Märkisches Zentrum
# website           https://www.maerkisches-zentrum.de/
# opening_hours                                     NaN
# addr_street                        Senftenberger Ring
# addr_housenumber                                   3a
# addr_postcode                                 13439.0
# addr_city                                      Berlin
# lat                                         52.597613
# lon                                         13.354518
# wheelchair                                        yes
# operator              MV Geschäftshaus-Marketing GmbH
# brand                                             NaN
# start_date                                        NaN
# level                                             NaN
# source                                   OSM Overpass
# geometry                POINT (13.3545182 52.5976128)
# index__district                                   NaN
# name__district                                    NaN
# gem_left                                          NaN
# namgem_left                                       NaN
# namlan_left                                       NaN
# lan_left                                          NaN
# index__neigh                                      NaN
# name                                              NaN
# gem__neigh                                        NaN
# namgem__neigh                                     NaN
# namlan__neigh                                     NaN
# lan__neigh                                        NaN
#
#                                            97                            98   \
# osm_type                              relation                      relation
# osm_id                                  380240                       2671992
# name_left                                The Q                           NaN
# website                                    NaN                           NaN
# opening_hours                Mo-Sa 08:00-22:00                           NaN
# addr_street                    Friedrichstraße                           NaN
# addr_housenumber                            67                           NaN
# addr_postcode                          10117.0                           NaN
# addr_city                               Berlin                           NaN
# lat                                  52.512614                     52.522378
# lon                                  13.390499                     13.465988
# wheelchair                                 yes                           yes
# operator                                   NaN                           NaN
# brand                                      NaN                           NaN
# start_date                                 NaN                           NaN
# level                                      NaN                           NaN
# source                            OSM Overpass                  OSM Overpass
# geometry          POINT (13.390499 52.5126135)  POINT (13.465988 52.5223779)
# index__district                            NaN                           NaN
# name__district                             NaN                           NaN
# gem_left                                   NaN                           NaN
# namgem_left                                NaN                           NaN
# namlan_left                                NaN                           NaN
# lan_left                                   NaN                           NaN
# index__neigh                               NaN                           NaN
# name                                       NaN                           NaN
# gem__neigh                                 NaN                           NaN
# namgem__neigh                              NaN                           NaN
# namlan__neigh                              NaN                           NaN
# lan__neigh                                 NaN                           NaN
#
#                                             99   \
# osm_type                               relation
# osm_id                                  4540346
# name_left                         Neumann-Forum
# website                                     NaN
# opening_hours                 Mo-Sa 07:00-21:00
# addr_street                                 NaN
# addr_housenumber                            NaN
# addr_postcode                               NaN
# addr_city                                   NaN
# lat                                   52.561378
# lon                                   13.422762
# wheelchair                                  NaN
# operator                                    NaN
# brand                                       NaN
# start_date                                  NaN
# level                                       NaN
# source                             OSM Overpass
# geometry          POINT (13.4227619 52.5613783)
# index__district                             NaN
# name__district                              NaN
# gem_left                                    NaN
# namgem_left                                 NaN
# namlan_left                                 NaN
# lan_left                                    NaN
# index__neigh                                NaN
# name                                        NaN
# gem__neigh                                  NaN
# namgem__neigh                               NaN
# namlan__neigh                               NaN
# lan__neigh                                  NaN
#
#                                                100  \
# osm_type                                  relation
# osm_id                                     7701165
# name_left                         Gropius Passagen
# website           https://www.gropius-passagen.de/
# opening_hours                    Mo-Sa 10:00-20:00
# addr_street                                    NaN
# addr_housenumber                               NaN
# addr_postcode                                  NaN
# addr_city                                      NaN
# lat                                      52.430128
# lon                                      13.455199
# wheelchair                                     yes
# operator                 Unibail-Rodamco-Westfield
# brand                                    Westfield
# start_date                                     NaN
# level                                          NaN
# source                                OSM Overpass
# geometry             POINT (13.4551989 52.4301282)
# index__district                                NaN
# name__district                                 NaN
# gem_left                                       NaN
# namgem_left                                    NaN
# namlan_left                                    NaN
# lan_left                                       NaN
# index__neigh                                   NaN
# name                                           NaN
# gem__neigh                                     NaN
# namgem__neigh                                  NaN
# namlan__neigh                                  NaN
# lan__neigh                                     NaN
#
#                                             101  \
# osm_type                               relation
# osm_id                                  8504555
# name_left               Forum Landsberger Allee
# website                                     NaN
# opening_hours                               NaN
# addr_street                                 NaN
# addr_housenumber                            NaN
# addr_postcode                               NaN
# addr_city                                   NaN
# lat                                    52.52926
# lon                                    13.45634
# wheelchair                                  yes
# operator                                    NaN
# brand                                       NaN
# start_date                                  NaN
# level                                       NaN
# source                             OSM Overpass
# geometry          POINT (13.4563404 52.5292601)
# index__district                             NaN
# name__district                              NaN
# gem_left                                    NaN
# namgem_left                                 NaN
# namlan_left                                 NaN
# lan_left                                    NaN
# index__neigh                                NaN
# name                                        NaN
# gem__neigh                                  NaN
# namgem__neigh                               NaN
# namlan__neigh                               NaN
# lan__neigh                                  NaN
#
#                                             102                            103
# osm_type                               relation                       relation
# osm_id                                 17353905                       19445153
# name_left                  GEHAG Einkaufzentrum               Dolgensee-Center
# website                                     NaN                            NaN
# opening_hours                               NaN                            NaN
# addr_street                                 NaN                            NaN
# addr_housenumber                            NaN                            NaN
# addr_postcode                               NaN                            NaN
# addr_city                                   NaN                            NaN
# lat                                   52.437559                      52.493574
# lon                                   13.446334                      13.507232
# wheelchair                                  NaN                            NaN
# operator                                    NaN                            NaN
# brand                                       NaN                            NaN
# start_date                                  NaN                            NaN
# level                                       NaN                            NaN
# source                             OSM Overpass                   OSM Overpass
# geometry          POINT (13.4463336 52.4375589)  POINT (13.5072316 52.4935737)
# index__district                             NaN                            NaN
# name__district                              NaN                            NaN
# gem_left                                    NaN                            NaN
# namgem_left                                 NaN                            NaN
# namlan_left                                 NaN                            NaN
# lan_left                                    NaN                            NaN
# index__neigh                                NaN                            NaN
# name                                        NaN                            NaN
# gem__neigh                                  NaN                            NaN
# namgem__neigh                               NaN                            NaN
# namlan__neigh                               NaN                            NaN
# lan__neigh                                  NaN                            NaN
#
# [30 rows x 104 columns]

# %%
df = df.drop_duplicates()

# %%
df.isna().sum()
# Out:
# osm_type              0
# osm_id                0
# name_left             4
# website              76
# opening_hours        41
# addr_street          41
# addr_housenumber     42
# addr_postcode        41
# addr_city            45
# lat                   0
# lon                   0
# wheelchair           23
# operator             98
# brand               103
# start_date           96
# level               104
# source                0
# geometry              0
# index__district     104
# name__district      104
# gem_left            104
# namgem_left         104
# namlan_left         104
# lan_left            104
# index__neigh        104
# name                104
# gem__neigh          104
# namgem__neigh       104
# namlan__neigh       104
# lan__neigh          104
# dtype: int64

# %%
df_columns_drop = df.copy()
columns_to_drop = [
    'operator', 
    'brand',
    'start_date', 
    'level', 
    'index__district',
    'name__district',
    'gem_left',
    'namgem_left',
    'namlan_left',
    'lan_left',
    'index__neigh',
    'name',
    'gem__neigh',
    'namgem__neigh',
    'namlan__neigh',
    'lan__neigh'
]  
df_kept = df_columns_drop.drop(columns=columns_to_drop)
df_kept.head()
# Out:
#   osm_type      osm_id             name_left              website  \
# 0     node   360009454         Cladow-Center                  NaN
# 1     node  2782835444             Nordmeile                  NaN
# 2     node  3982921774   Springpfuhl-Passage                  NaN
# 3     node  5024078544      Fennpfuhl-Karree                  NaN
# 4      way    10632546  Hallen am Borsigturm  http://www.hab-2.de
#
#        opening_hours    addr_street addr_housenumber  addr_postcode addr_city  \
# 0                NaN            NaN              NaN            NaN       NaN
# 1  Mo-Sa 07:00-21:00    Oraniendamm             6-10        13469.0    Berlin
# 2                NaN            NaN              NaN            NaN       NaN
# 3               24/7            NaN              NaN            NaN       NaN
# 4  Mo-Sa 10:00-20:00  Am Borsigturm                2        13507.0    Berlin
#
#          lat        lon wheelchair        source  \
# 0  52.455157  13.144413        yes  OSM Overpass
# 1  52.607867  13.325992        NaN  OSM Overpass
# 2  52.526728  13.540104        yes  OSM Overpass
# 3  52.528781  13.471797        yes  OSM Overpass
# 4  52.584576  13.285772        yes  OSM Overpass
#
#                         geometry
# 0  POINT (13.1444131 52.4551567)
# 1  POINT (13.3259918 52.6078674)
# 2  POINT (13.5401045 52.5267284)
# 3  POINT (13.4717971 52.5287807)
# 4  POINT (13.2857717 52.5845756)

# %%
df_kept.dtypes
# Out:
# osm_type             object
# osm_id                int64
# name_left            object
# website              object
# opening_hours        object
# addr_street          object
# addr_housenumber     object
# addr_postcode       float64
# addr_city            object
# lat                 float64
# lon                 float64
# wheelchair           object
# source               object
# geometry             object
# dtype: object

# %%
df_kept.isna().sum()
# Out:
# osm_type             0
# osm_id               0
# name_left            4
# website             76
# opening_hours       41
# addr_street         41
# addr_housenumber    42
# addr_postcode       41
# addr_city           45
# lat                  0
# lon                  0
# wheelchair          23
# source               0
# geometry             0
# dtype: int64

# %% [markdown]
# ### Dealing with Null Values

# %%
df_kept = df_kept.fillna({
    'name_left': 'None',
    'website': 'None',
    'opening_hours': 'None',
    'addr_street': 'None',
    'addr_housenumber': '',
    'addr_postcode': '',
    'addr_city': '',
    'wheelchair': 'None'
})

# %%
df_kept.isna().sum()
# Out:
# osm_type            0
# osm_id              0
# name_left           0
# website             0
# opening_hours       0
# addr_street         0
# addr_housenumber    0
# addr_postcode       0
# addr_city           0
# lat                 0
# lon                 0
# wheelchair          0
# source              0
# geometry            0
# dtype: int64

# %%
df_kept
# Out:
#      osm_type      osm_id                name_left  \
# 0        node   360009454            Cladow-Center
# 1        node  2782835444                Nordmeile
# 2        node  3982921774      Springpfuhl-Passage
# 3        node  5024078544         Fennpfuhl-Karree
# 4         way    10632546     Hallen am Borsigturm
# ..        ...         ...                      ...
# 99   relation     4540346            Neumann-Forum
# 100  relation     7701165         Gropius Passagen
# 101  relation     8504555  Forum Landsberger Allee
# 102  relation    17353905     GEHAG Einkaufzentrum
# 103  relation    19445153         Dolgensee-Center
#
#                               website      opening_hours    addr_street  \
# 0                                None               None           None
# 1                                None  Mo-Sa 07:00-21:00    Oraniendamm
# 2                                None               None           None
# 3                                None               24/7           None
# 4                 http://www.hab-2.de  Mo-Sa 10:00-20:00  Am Borsigturm
# ..                                ...                ...            ...
# 99                               None  Mo-Sa 07:00-21:00           None
# 100  https://www.gropius-passagen.de/  Mo-Sa 10:00-20:00           None
# 101                              None               None           None
# 102                              None               None           None
# 103                              None               None           None
#
#     addr_housenumber addr_postcode addr_city        lat        lon wheelchair  \
# 0                                             52.455157  13.144413        yes
# 1               6-10       13469.0    Berlin  52.607867  13.325992       None
# 2                                             52.526728  13.540104        yes
# 3                                             52.528781  13.471797        yes
# 4                  2       13507.0    Berlin  52.584576  13.285772        yes
# ..               ...           ...       ...        ...        ...        ...
# 99                                            52.561378  13.422762       None
# 100                                           52.430128  13.455199        yes
# 101                                           52.529260  13.456340        yes
# 102                                           52.437559  13.446334       None
# 103                                           52.493574  13.507232       None
#
#            source                       geometry
# 0    OSM Overpass  POINT (13.1444131 52.4551567)
# 1    OSM Overpass  POINT (13.3259918 52.6078674)
# 2    OSM Overpass  POINT (13.5401045 52.5267284)
# 3    OSM Overpass  POINT (13.4717971 52.5287807)
# 4    OSM Overpass  POINT (13.2857717 52.5845756)
# ..            ...                            ...
# 99   OSM Overpass  POINT (13.4227619 52.5613783)
# 100  OSM Overpass  POINT (13.4551989 52.4301282)
# 101  OSM Overpass  POINT (13.4563404 52.5292601)
# 102  OSM Overpass  POINT (13.4463336 52.4375589)
# 103  OSM Overpass  POINT (13.5072316 52.4935737)
#
# [104 rows x 14 columns]

# %% [markdown]
# ### Rename Columns

# %%
df_kept = df_kept.rename(columns={
    'osm_id': 'id',
    'name_left': 'name',
    'addr_street': 'street',
    'addr_housenumber': 'housenumber',
    'addr_postcode': 'postcode',
    'addr_city': 'city',
    'lat': 'latitude',
    'lon': 'longitude'    
})

# %%
for col in df_kept.select_dtypes(include='object').columns:
    df_kept[col] = df_kept[col].astype(str).str.strip().str.title()

# %%
df_kept.T
# Out:
#                                          0                              1    \
# osm_type                                Node                           Node
# id                                 360009454                     2782835444
# name                           Cladow-Center                      Nordmeile
# website                                 None                           None
# opening_hours                           None              Mo-Sa 07:00-21:00
# street                                  None                    Oraniendamm
# housenumber                                                            6-10
# postcode                                                            13469.0
# city                                                                 Berlin
# latitude                           52.455157                      52.607867
# longitude                          13.144413                      13.325992
# wheelchair                               Yes                           None
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.1444131 52.4551567)  Point (13.3259918 52.6078674)
#
#                                          2                              3    \
# osm_type                                Node                           Node
# id                                3982921774                     5024078544
# name                     Springpfuhl-Passage               Fennpfuhl-Karree
# website                                 None                           None
# opening_hours                           None                           24/7
# street                                  None                           None
# housenumber
# postcode
# city
# latitude                           52.526728                      52.528781
# longitude                          13.540104                      13.471797
# wheelchair                               Yes                            Yes
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.5401045 52.5267284)  Point (13.4717971 52.5287807)
#
#                                          4                              5    \
# osm_type                                 Way                            Way
# id                                  10632546                       11076700
# name                    Hallen Am Borsigturm     Einkaufszentrum »Der Clou«
# website                  Http://Www.Hab-2.De  Https://Www.Derclouberlin.De/
# opening_hours              Mo-Sa 10:00-20:00              Mo-Sa 10:00-20:00
# street                         Am Borsigturm              Scharnweberstraße
# housenumber                                2                            140
# postcode                             13507.0                        13405.0
# city                                  Berlin                         Berlin
# latitude                           52.584576                      52.563039
# longitude                          13.285772                      13.328485
# wheelchair                               Yes                            Yes
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.2857717 52.5845756)  Point (13.3284849 52.5630387)
#
#                                              6    \
# osm_type                                     Way
# id                                      11249452
# name                               Linden Center
# website        Https://M.Linden-Center-Berlin.De
# opening_hours                  Mo-Sa 09:30-20:00
# street                            Prerower Platz
# housenumber                                    1
# postcode                                 13051.0
# city                                      Berlin
# latitude                               52.564378
# longitude                               13.50604
# wheelchair                                   Yes
# source                              Osm Overpass
# geometry           Point (13.5060401 52.5643776)
#
#                                         7                              8    \
# osm_type                                Way                            Way
# id                                 11249566                       18771934
# name                    Allee-Center Berlin            Bahnhof Lichtenberg
# website                                None                           None
# opening_hours             Mo-Sa 07:00-20:00                    06:00-22:00
# street                    Landsberger Allee                 Weitlingstraße
# housenumber                             277                             22
# postcode                            13055.0                        10317.0
# city                                 Berlin                         Berlin
# latitude                          52.535248                      52.509421
# longitude                         13.496467                      13.496944
# wheelchair                              Yes                            Yes
# source                         Osm Overpass                   Osm Overpass
# geometry       Point (13.4964673 52.535248)  Point (13.4969436 52.5094209)
#
#                                                 9    ...  \
# osm_type                                        Way  ...
# id                                         20980117  ...
# name                           Gesundbrunnen-Center  ...
# website        Https://Www.Gesundbrunnen-Center.De/  ...
# opening_hours                     Mo-Sa 08:00-21:00  ...
# street                                    Badstraße  ...
# housenumber                                       4  ...
# postcode                                    13357.0  ...
# city                                         Berlin  ...
# latitude                                  52.549773  ...
# longitude                                  13.38953  ...
# wheelchair                                      Yes  ...
# source                                 Osm Overpass  ...
# geometry               Point (13.3895302 52.549773)  ...
#
#                                          94                            95   \
# osm_type                                 Way                           Way
# id                                1065811824                    1238152790
# name                   Ring-Center Berlin Ii             Tempelhofer Hafen
# website                                 None                          None
# opening_hours      Mo-Sa 10:00-20:00; Ph Off             Mo-Sa 10:00-20:00
# street                     Frankfurter Allee                          None
# housenumber                          113-117
# postcode                             10365.0
# city                                  Berlin
# latitude                           52.514327                     52.455806
# longitude                          13.476502                     13.386016
# wheelchair                               Yes                           Yes
# source                          Osm Overpass                  Osm Overpass
# geometry       Point (13.4765019 52.5143274)  Point (13.386016 52.4558061)
#
#                                                96   \
# osm_type                                       Way
# id                                      1244901436
# name                            Märkisches Zentrum
# website        Https://Www.Maerkisches-Zentrum.De/
# opening_hours                                 None
# street                          Senftenberger Ring
# housenumber                                     3A
# postcode                                   13439.0
# city                                        Berlin
# latitude                                 52.597613
# longitude                                13.354518
# wheelchair                                     Yes
# source                                Osm Overpass
# geometry             Point (13.3545182 52.5976128)
#
#                                         97                            98   \
# osm_type                           Relation                      Relation
# id                                   380240                       2671992
# name                                  The Q                          None
# website                                None                          None
# opening_hours             Mo-Sa 08:00-22:00                          None
# street                      Friedrichstraße                          None
# housenumber                              67
# postcode                            10117.0
# city                                 Berlin
# latitude                          52.512614                     52.522378
# longitude                         13.390499                     13.465988
# wheelchair                              Yes                           Yes
# source                         Osm Overpass                  Osm Overpass
# geometry       Point (13.390499 52.5126135)  Point (13.465988 52.5223779)
#
#                                          99   \
# osm_type                            Relation
# id                                   4540346
# name                           Neumann-Forum
# website                                 None
# opening_hours              Mo-Sa 07:00-21:00
# street                                  None
# housenumber
# postcode
# city
# latitude                           52.561378
# longitude                          13.422762
# wheelchair                              None
# source                          Osm Overpass
# geometry       Point (13.4227619 52.5613783)
#
#                                             100  \
# osm_type                               Relation
# id                                      7701165
# name                           Gropius Passagen
# website        Https://Www.Gropius-Passagen.De/
# opening_hours                 Mo-Sa 10:00-20:00
# street                                     None
# housenumber
# postcode
# city
# latitude                              52.430128
# longitude                             13.455199
# wheelchair                                  Yes
# source                             Osm Overpass
# geometry          Point (13.4551989 52.4301282)
#
#                                          101                            102  \
# osm_type                            Relation                       Relation
# id                                   8504555                       17353905
# name                 Forum Landsberger Allee           Gehag Einkaufzentrum
# website                                 None                           None
# opening_hours                           None                           None
# street                                  None                           None
# housenumber
# postcode
# city
# latitude                            52.52926                      52.437559
# longitude                           13.45634                      13.446334
# wheelchair                               Yes                           None
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.4563404 52.5292601)  Point (13.4463336 52.4375589)
#
#                                          103
# osm_type                            Relation
# id                                  19445153
# name                        Dolgensee-Center
# website                                 None
# opening_hours                           None
# street                                  None
# housenumber
# postcode
# city
# latitude                           52.493574
# longitude                          13.507232
# wheelchair                              None
# source                          Osm Overpass
# geometry       Point (13.5072316 52.4935737)
#
# [14 rows x 104 columns]

# %%
df_kept.dtypes
# Out:
# osm_type          object
# id                 int64
# name              object
# website           object
# opening_hours     object
# street            object
# housenumber       object
# postcode          object
# city              object
# latitude         float64
# longitude        float64
# wheelchair        object
# source            object
# geometry          object
# dtype: object

# %% [markdown]
# ### Changing Datatypes

# %%
df_kept['postcode'] = pd.to_numeric(df_kept['postcode'], errors='coerce').astype('Int64')

# %%
df_kept.dtypes
# Out:
# osm_type          object
# id                 int64
# name              object
# website           object
# opening_hours     object
# street            object
# housenumber       object
# postcode           Int64
# city              object
# latitude         float64
# longitude        float64
# wheelchair        object
# source            object
# geometry          object
# dtype: object

# %%
df_kept['postcode'] = df_kept['postcode'].fillna(0).astype('int64')

# %% [markdown]
# ### Checking Datatypes for 'city' column

# %%
df_kept.value_counts('city')
# Out:
# city
# Berlin    59
#           45
# Name: count, dtype: int64

# %%
in_berlin = (
    (df_kept['latitude'] >= 52.3383) & (df_kept['latitude'] <= 52.6755) &
    (df_kept['longitude'] >= 13.0884) & (df_kept['longitude'] <= 13.7612)
)
print(f"All coordinates in Berlin: {in_berlin.all()}")
print(f"Rows outside Berlin: {df_kept[~in_berlin]}")
# Out:
# All coordinates in Berlin: True
# Rows outside Berlin: Empty DataFrame
# Columns: [osm_type, id, name, website, opening_hours, street, housenumber, postcode, city, latitude, longitude, wheelchair, source, geometry]
# Index: []

# %%
df_kept['city'] = df_kept['city'].replace('', 'Berlin')

# %%
df_kept['housenumber'] = df_kept['housenumber'].replace('', 'None')

# %%
df_kept.T
# Out:
#                                          0                              1    \
# osm_type                                Node                           Node
# id                                 360009454                     2782835444
# name                           Cladow-Center                      Nordmeile
# website                                 None                           None
# opening_hours                           None              Mo-Sa 07:00-21:00
# street                                  None                    Oraniendamm
# housenumber                             None                           6-10
# postcode                                   0                          13469
# city                                  Berlin                         Berlin
# latitude                           52.455157                      52.607867
# longitude                          13.144413                      13.325992
# wheelchair                               Yes                           None
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.1444131 52.4551567)  Point (13.3259918 52.6078674)
#
#                                          2                              3    \
# osm_type                                Node                           Node
# id                                3982921774                     5024078544
# name                     Springpfuhl-Passage               Fennpfuhl-Karree
# website                                 None                           None
# opening_hours                           None                           24/7
# street                                  None                           None
# housenumber                             None                           None
# postcode                                   0                              0
# city                                  Berlin                         Berlin
# latitude                           52.526728                      52.528781
# longitude                          13.540104                      13.471797
# wheelchair                               Yes                            Yes
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.5401045 52.5267284)  Point (13.4717971 52.5287807)
#
#                                          4                              5    \
# osm_type                                 Way                            Way
# id                                  10632546                       11076700
# name                    Hallen Am Borsigturm     Einkaufszentrum »Der Clou«
# website                  Http://Www.Hab-2.De  Https://Www.Derclouberlin.De/
# opening_hours              Mo-Sa 10:00-20:00              Mo-Sa 10:00-20:00
# street                         Am Borsigturm              Scharnweberstraße
# housenumber                                2                            140
# postcode                               13507                          13405
# city                                  Berlin                         Berlin
# latitude                           52.584576                      52.563039
# longitude                          13.285772                      13.328485
# wheelchair                               Yes                            Yes
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.2857717 52.5845756)  Point (13.3284849 52.5630387)
#
#                                              6    \
# osm_type                                     Way
# id                                      11249452
# name                               Linden Center
# website        Https://M.Linden-Center-Berlin.De
# opening_hours                  Mo-Sa 09:30-20:00
# street                            Prerower Platz
# housenumber                                    1
# postcode                                   13051
# city                                      Berlin
# latitude                               52.564378
# longitude                               13.50604
# wheelchair                                   Yes
# source                              Osm Overpass
# geometry           Point (13.5060401 52.5643776)
#
#                                         7                              8    \
# osm_type                                Way                            Way
# id                                 11249566                       18771934
# name                    Allee-Center Berlin            Bahnhof Lichtenberg
# website                                None                           None
# opening_hours             Mo-Sa 07:00-20:00                    06:00-22:00
# street                    Landsberger Allee                 Weitlingstraße
# housenumber                             277                             22
# postcode                              13055                          10317
# city                                 Berlin                         Berlin
# latitude                          52.535248                      52.509421
# longitude                         13.496467                      13.496944
# wheelchair                              Yes                            Yes
# source                         Osm Overpass                   Osm Overpass
# geometry       Point (13.4964673 52.535248)  Point (13.4969436 52.5094209)
#
#                                                 9    ...  \
# osm_type                                        Way  ...
# id                                         20980117  ...
# name                           Gesundbrunnen-Center  ...
# website        Https://Www.Gesundbrunnen-Center.De/  ...
# opening_hours                     Mo-Sa 08:00-21:00  ...
# street                                    Badstraße  ...
# housenumber                                       4  ...
# postcode                                      13357  ...
# city                                         Berlin  ...
# latitude                                  52.549773  ...
# longitude                                  13.38953  ...
# wheelchair                                      Yes  ...
# source                                 Osm Overpass  ...
# geometry               Point (13.3895302 52.549773)  ...
#
#                                          94                            95   \
# osm_type                                 Way                           Way
# id                                1065811824                    1238152790
# name                   Ring-Center Berlin Ii             Tempelhofer Hafen
# website                                 None                          None
# opening_hours      Mo-Sa 10:00-20:00; Ph Off             Mo-Sa 10:00-20:00
# street                     Frankfurter Allee                          None
# housenumber                          113-117                          None
# postcode                               10365                             0
# city                                  Berlin                        Berlin
# latitude                           52.514327                     52.455806
# longitude                          13.476502                     13.386016
# wheelchair                               Yes                           Yes
# source                          Osm Overpass                  Osm Overpass
# geometry       Point (13.4765019 52.5143274)  Point (13.386016 52.4558061)
#
#                                                96   \
# osm_type                                       Way
# id                                      1244901436
# name                            Märkisches Zentrum
# website        Https://Www.Maerkisches-Zentrum.De/
# opening_hours                                 None
# street                          Senftenberger Ring
# housenumber                                     3A
# postcode                                     13439
# city                                        Berlin
# latitude                                 52.597613
# longitude                                13.354518
# wheelchair                                     Yes
# source                                Osm Overpass
# geometry             Point (13.3545182 52.5976128)
#
#                                         97                            98   \
# osm_type                           Relation                      Relation
# id                                   380240                       2671992
# name                                  The Q                          None
# website                                None                          None
# opening_hours             Mo-Sa 08:00-22:00                          None
# street                      Friedrichstraße                          None
# housenumber                              67                          None
# postcode                              10117                             0
# city                                 Berlin                        Berlin
# latitude                          52.512614                     52.522378
# longitude                         13.390499                     13.465988
# wheelchair                              Yes                           Yes
# source                         Osm Overpass                  Osm Overpass
# geometry       Point (13.390499 52.5126135)  Point (13.465988 52.5223779)
#
#                                          99   \
# osm_type                            Relation
# id                                   4540346
# name                           Neumann-Forum
# website                                 None
# opening_hours              Mo-Sa 07:00-21:00
# street                                  None
# housenumber                             None
# postcode                                   0
# city                                  Berlin
# latitude                           52.561378
# longitude                          13.422762
# wheelchair                              None
# source                          Osm Overpass
# geometry       Point (13.4227619 52.5613783)
#
#                                             100  \
# osm_type                               Relation
# id                                      7701165
# name                           Gropius Passagen
# website        Https://Www.Gropius-Passagen.De/
# opening_hours                 Mo-Sa 10:00-20:00
# street                                     None
# housenumber                                None
# postcode                                      0
# city                                     Berlin
# latitude                              52.430128
# longitude                             13.455199
# wheelchair                                  Yes
# source                             Osm Overpass
# geometry          Point (13.4551989 52.4301282)
#
#                                          101                            102  \
# osm_type                            Relation                       Relation
# id                                   8504555                       17353905
# name                 Forum Landsberger Allee           Gehag Einkaufzentrum
# website                                 None                           None
# opening_hours                           None                           None
# street                                  None                           None
# housenumber                             None                           None
# postcode                                   0                              0
# city                                  Berlin                         Berlin
# latitude                            52.52926                      52.437559
# longitude                           13.45634                      13.446334
# wheelchair                               Yes                           None
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.4563404 52.5292601)  Point (13.4463336 52.4375589)
#
#                                          103
# osm_type                            Relation
# id                                  19445153
# name                        Dolgensee-Center
# website                                 None
# opening_hours                           None
# street                                  None
# housenumber                             None
# postcode                                   0
# city                                  Berlin
# latitude                           52.493574
# longitude                          13.507232
# wheelchair                              None
# source                          Osm Overpass
# geometry       Point (13.5072316 52.4935737)
#
# [14 rows x 104 columns]

# %%
engine.dispose()

# %%
df_kept.dtypes
# Out:
# osm_type          object
# id                 int64
# name              object
# website           object
# opening_hours     object
# street            object
# housenumber       object
# postcode           int64
# city              object
# latitude         float64
# longitude        float64
# wheelchair        object
# source            object
# geometry          object
# dtype: object

# %% [markdown]
# ## Create the Table

# %%
metadata = MetaData()

create_table_query = Table(
    'malls',
    metadata,
    Column('id', BigInteger, primary_key=True),
    Column('osm_type', String),
    Column('name', String),
    Column('website', String),
    Column('opening_hours', String),
    Column('street', String),
    Column('housenumber', String),
    Column('postcode', Integer),
    Column('city', String),
    Column('latitude', Float),
    Column('longitude', Float),
    Column('wheelchair', String),
    Column('source', String),
    Column('geometry', String),
    schema='berlin_source_data'
)

# Create the table in the database
metadata.create_all(engine)

# %% [markdown]
# ## Populat4 Table to Database

# %%
df_kept.to_sql(
    f'malls',        # table name
    engine,
    schema=schema,
    if_exists='append', # append table if it exists
    index=False
)

print("DataFrame sent to PostgreSQL using .to_sql() with psycopg2!")
# Out:
# DataFrame sent to PostgreSQL using .to_sql() with psycopg2!
