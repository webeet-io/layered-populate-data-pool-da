# %%
import sys
import os

# Simple path fix - go up one level to data_loader directory
sys.path.append('../')

print(f"Added parent directory to path")
print(f"Current working directory: {os.getcwd()}")
# Out:
# Added parent directory to path
# Current working directory: /Users/svitlanakovalivska/layered-populate-data-pool-da/db_population_utils/data_loader/test

# %%
# Import the SmartAutoDataLoader and test CSV loading
from smart_auto_data_loader import SmartAutoDataLoader
df = loader.load("/Users/svitlanakovalivska/layered-populate-data-pool-da/db_population_utils/data/test.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Import the SmartAutoDataLoader and test CSV loading
#       2 from smart_auto_data_loader import SmartAutoDataLoader
# ----> 3 df = loader.load("/Users/svitlanakovalivska/layered-populate-data-pool-da/db_population_utils/data/test.csv")
#
# NameError: name 'loader' is not defined

# %%
df
# Out:
#          id keyword location  \
# 0         0     NaN      NaN
# 1         2     NaN      NaN
# 2         3     NaN      NaN
# 3         9     NaN      NaN
# 4        11     NaN      NaN
# ...     ...     ...      ...
# 3258  10861     NaN      NaN
# 3259  10865     NaN      NaN
# 3260  10868     NaN      NaN
# 3261  10874     NaN      NaN
# 3262  10875     NaN      NaN
#
#                                                    text
# 0                    Just happened a terrible car crash
# 1     Heard about #earthquake is different cities, s...
# 2     there is a forest fire at spot pond, geese are...
# 3              Apocalypse lighting. #Spokane #wildfires
# 4         Typhoon Soudelor kills 28 in China and Taiwan
# ...                                                 ...
# 3258  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...
# 3259  Storm in RI worse than last hurricane. My city...
# 3260  Green Line derailment in Chicago http://t.co/U...
# 3261  MEG issues Hazardous Weather Outlook (HWO) htt...
# 3262  #CityofCalgary has activated its Municipal Eme...
#
# [3263 rows x 4 columns]

# %%
# Cell 1: Install dependencies
# !pip install openpyxl xlrd
print("📦 Excel support installed!")


# Cell 4: Test Excel
import importlib
import smart_auto_data_loader
importlib.reload(smart_auto_data_loader)

from smart_auto_data_loader import SmartAutoDataLoader

loader = SmartAutoDataLoader(verbose=True)
df = loader.load("/Users/svitlanakovalivska/layered-populate-data-pool-da/db_population_utils/data/statistischer-bericht-auslaend-bevoelkerung-2010200247005.xlsx")
# Out:
# Requirement already satisfied: openpyxl in /Users/svitlanakovalivska/layered-populate-data-pool-da/.conda/lib/python3.12/site-packages (3.1.5)
# Requirement already satisfied: xlrd in /Users/svitlanakovalivska/layered-populate-data-pool-da/.conda/lib/python3.12/site-packages (2.0.2)
# Requirement already satisfied: et-xmlfile in /Users/svitlanakovalivska/layered-populate-data-pool-da/.conda/lib/python3.12/site-packages (from openpyxl) (2.0.0)
# 📦 Excel support installed!
# 🎯 SmartAutoDataLoader ready!
# 🎯 Loading file: statistischer-bericht-auslaend-bevoelkerung-2010200247005.xlsx
# 🔍 Format detected: excel
# 📈 Loading Excel file...
#    📋 Available sheets: ['Titel', 'Inhaltsübersicht', 'GENESIS-Online', 'Impressum', 'Informationen zur Statistik', '12521-01', '12521-02', '12521-03', '12521-04', '12521-05', '12521-06', '12521-07', '12521-08', '12521-09', '12521-10', '12521-11', '12521-12', '12521-13', '12521-14', '12521-15', '12521-16', 'Erläuterung_zu_CSV-Tabellen', 'csv-12521-01', 'csv-12521-02', 'csv-12521-03', 'csv-12521-04', 'csv-12521-05', 'csv-12521-06', 'csv-12521-07', 'csv-12521-08', 'csv-12521-09', 'csv-12521-10', 'csv-12521-11', 'csv-12521-12', 'csv-12521-13', 'csv-12521-14', 'csv-12521-15', 'csv-12521-16']
#    ✅ Selected sheet: 'csv-12521-15'
# 🗓️ Searching for date columns...
#    ✅ Found date column: 'Stichtag' (%d.%m.%Y)
#    📅 Total date columns found: 1
# ✅ Excel loaded: 1309 rows, 24 columns
#    📊 Column names: ['Statistik_Code', 'Statistik_Label', 'Stichtag', 'Region', 'AGS_Kreis', 'Geschlecht', 'Bestand_am_31_12_2023_Anzahl', 'Zugaenge_in_2024_Insgesamt_Anzahl', 'Erstzuzug_aus_dem_Ausland_in_2024_Anzahl', 'Wiederzuzug_aus_dem_Ausland_in_2024_Anzahl', 'Geburten_in_2024_Anzahl', 'Zuzug_im_Inland_in_2024_Anzahl', 'Abgaenge_in_2024_Insgesamt_Anzahl', 'Fortzuege_ins_Ausland_in_2024_Anzahl', 'Abmeldungen_ins_Ausland_in_2024_Anzahl', 'Tod_in_2024_Anzahl', 'Registerloeschung_in_2024_Anzahl', 'Fortzug_im_Inland_in_2024_Anzahl', 'Geburtenueberschuss_in_2024_Anzahl', 'Nettozuwanderung_aus_Ausland_in_2024_Anzahl', 'Nettozuwanderung_aus_Inland_in_2024_Anzahl', 'Bestand_am_31_12_2024_Anzahl', 'Nachrichtlich_Zugaenge_in_2024_Anzahl', 'Nachrichtlich_Abgaenge_in_2024_Anzahl']

# %%
df
# Out:
#          Statistik_Code      Statistik_Label   Stichtag  \
# 0                 12521  Auslaenderstatistik 2024-12-31
# 1                 12521  Auslaenderstatistik 2024-12-31
# 2                 12521  Auslaenderstatistik 2024-12-31
# 3                 12521  Auslaenderstatistik 2024-12-31
# 4                 12521  Auslaenderstatistik 2024-12-31
# ...                 ...                  ...        ...
# 1304              12521  Auslaenderstatistik 2024-12-31
# 1305              12521  Auslaenderstatistik 2024-12-31
# 1306              12521  Auslaenderstatistik 2024-12-31
# 1307              12521  Auslaenderstatistik 2024-12-31
# 1308  Ende der Tabelle.                  NaN        NaT
#
#                                                  Region  \
# 0     Deutschland                                   ...
# 1     Deutschland                                   ...
# 2     Deutschland                                   ...
# 3     Schleswig-Holstein                            ...
# 4     Schleswig-Holstein                            ...
# ...                                                 ...
# 1304  Greiz                                         ...
# 1305  Altenburger_Land                              ...
# 1306  Altenburger_Land                              ...
# 1307  Altenburger_Land                              ...
# 1308                                                NaN
#
#                                               AGS_Kreis   Geschlecht  \
# 0     Kein_AGS                                      ...  Insgesamt
# 1     Kein_AGS                                      ...  Maennlich
# 2     Kein_AGS                                      ...  Weiblich
# 3     Kein_AGS                                      ...  Insgesamt
# 4     Kein_AGS                                      ...  Maennlich
# ...                                                 ...          ...
# 1304  16076                                         ...  Weiblich
# 1305  16077                                         ...  Insgesamt
# 1306  16077                                         ...  Maennlich
# 1307  16077                                         ...  Weiblich
# 1308                                                NaN          NaN
#
#       Bestand_am_31_12_2023_Anzahl  Zugaenge_in_2024_Insgesamt_Anzahl  \
# 0                       13895865.0                          1285655.0
# 1                        7305105.0                           728825.0
# 2                        6590755.0                           556835.0
# 3                         346690.0                            54800.0
# 4                         181985.0                            31310.0
# ...                            ...                                ...
# 1304                        2035.0                              385.0
# 1305                        6750.0                             1695.0
# 1306                        3530.0                              855.0
# 1307                        3220.0                              840.0
# 1308                           NaN                                NaN
#
#       Erstzuzug_aus_dem_Ausland_in_2024_Anzahl  \
# 0                                     972850.0
# 1                                     539235.0
# 2                                     433610.0
# 3                                      28625.0
# 4                                      15835.0
# ...                                        ...
# 1304                                     235.0
# 1305                                    1225.0
# 1306                                     590.0
# 1307                                     640.0
# 1308                                       NaN
#
#       Wiederzuzug_aus_dem_Ausland_in_2024_Anzahl  ...  \
# 0                                       205350.0  ...
# 1                                       134420.0  ...
# 2                                        70930.0  ...
# 3                                         4835.0  ...
# 4                                         3115.0  ...
# ...                                          ...  ...
# 1304                                        50.0  ...
# 1305                                        90.0  ...
# 1306                                        50.0  ...
# 1307                                        35.0  ...
# 1308                                         NaN  ...
#
#       Abmeldungen_ins_Ausland_in_2024_Anzahl Tod_in_2024_Anzahl  \
# 0                                   324415.0              46605
# 1                                   219910.0              27440
# 2                                   104505.0              19160
# 3                                     9155.0                970
# 4                                     6250.0                525
# ...                                      ...                ...
# 1304                                    90.0                  5
# 1305                                   130.0                 10
# 1306                                    85.0                  5
# 1307                                    45.0                  5
# 1308                                     NaN                NaN
#
#       Registerloeschung_in_2024_Anzahl  Fortzug_im_Inland_in_2024_Anzahl  \
# 0                             354780.0                                 .
# 1                             188065.0                                 .
# 2                             166720.0                                 .
# 3                              10830.0                             19485
# 4                               5845.0                             11215
# ...                                ...                               ...
# 1304                               5.0                               125
# 1305                             125.0                               355
# 1306                              70.0                               220
# 1307                              55.0                               140
# 1308                               NaN                               NaN
#
#       Geburtenueberschuss_in_2024_Anzahl  \
# 0                                60850.0
# 1                                27725.0
# 2                                33130.0
# 3                                 2115.0
# 4                                 1070.0
# ...                                  ...
# 1304                                20.0
# 1305                                60.0
# 1306                                20.0
# 1307                                40.0
# 1308                                 NaN
#
#      Nettozuwanderung_aus_Ausland_in_2024_Anzahl  \
# 0                                       459705.0
# 1                                       232455.0
# 2                                       227245.0
# 3                                        13920.0
# 4                                         7030.0
# ...                                          ...
# 1304                                       110.0
# 1305                                       905.0
# 1306                                       395.0
# 1307                                       515.0
# 1308                                         NaN
#
#       Nettozuwanderung_aus_Inland_in_2024_Anzahl Bestand_am_31_12_2024_Anzahl  \
# 0                                              .                   14061640.0
# 1                                              .                    7377225.0
# 2                                              .                    6684415.0
# 3                                          -1235                     350665.0
# 4                                           -450                     183790.0
# ...                                          ...                          ...
# 1304                                         -50                       2110.0
# 1305                                         -50                       7545.0
# 1306                                         -30                       3845.0
# 1307                                         -25                       3700.0
# 1308                                         NaN                          NaN
#
#       Nachrichtlich_Zugaenge_in_2024_Anzahl  \
# 0                                  226800.0
# 1                                  128280.0
# 2                                   98520.0
# 3                                    5540.0
# 4                                    3095.0
# ...                                     ...
# 1304                                   20.0
# 1305                                  120.0
# 1306                                   55.0
# 1307                                   65.0
# 1308                                    NaN
#
#       Nachrichtlich_Abgaenge_in_2024_Anzahl
# 0                                  225380.0
# 1                                  138090.0
# 2                                   87290.0
# 3                                    7140.0
# 4                                    4370.0
# ...                                     ...
# 1304                                   50.0
# 1305                                   55.0
# 1306                                   45.0
# 1307                                   10.0
# 1308                                    NaN
#
# [1309 rows x 24 columns]
