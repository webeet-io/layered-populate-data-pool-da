# %%
import pandas as pd

# %%
# Load raw data
df = pd.read_csv(r'C:\Users\oytun\Downloads\Berlin_pop_stats - berlin-neighborhood-population.csv')

# %%
df.head()
# Out:
#                      district    male  female  germans  foreigners  single  \
# 0                       Mitte  204542  192462   249053      147951  240196
# 1    Friedrichshain-Kreuzberg  150002  142622   202632       89992  188392
# 2                      Pankow  209773  217503   343105       84171  246687
# 3  Charlottenburg-Wilmersdorf  166037  177463   249994       93506  176967
# 4                     Spandau  127361  131916   189914       69363  125965
#
#    married  widowed  divorced  civil_partnership  ...  \
# 0   113277    13119     28623               1789  ...
# 1    76076     7369     19227               1560  ...
# 2   130125    17014     31848               1602  ...
# 3   114706    17823     32281               1723  ...
# 4    93781    15779     23333                419  ...
#
#    römisch_katholische_kirche  religion_other_or_none    0-6   6-15  15-18  \
# 0                       28294                  333248  20516  29120   9461
# ...

# %%
df.columns = df.columns.str.replace('\n', '', regex=True)\
                       .str.lower()

# %%
df['district'] = df['district'].str.lower()

# %%
print(df['district'].unique())
# Out:
# ['mitte' 'friedrichshain-kreuzberg' 'pankow' 'charlottenburg-wilmersdorf'
#  'spandau' 'steglitz-zehlendorf' 'tempelhof-schöneberg' 'neukölln'
#  'treptow-köpenick' 'marzahn-hellersdorf' 'lichtenberg' 'reinickendorf']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   district                    12 non-null     object
#  1   male                        12 non-null     int64
#  2   female                      12 non-null     int64
#  3   germans                     12 non-null     int64
#  4   foreigners                  12 non-null     int64
#  5   single                      12 non-null     int64
#  6   married                     12 non-null     int64
#  7   widowed                     12 non-null     int64
#  8   divorced                    12 non-null     int64
#  9   civil_partnership           12 non-null     int64
#  10  evangelische_kirchen        12 non-null     int64
#  11  römisch_katholische_kirche  12 non-null     int64
#  12  religion_other_or_none      12 non-null     int64
# ...

# %%
df.isnull().sum()
# Out:
# district                      0
# male                          0
# female                        0
# germans                       0
# foreigners                    0
# single                        0
# married                       0
# widowed                       0
# divorced                      0
# civil_partnership             0
# evangelische_kirchen          0
# römisch_katholische_kirche    0
# religion_other_or_none        0
# 0-6                           0
# 6-15                          0
# 15-18                         0
# 18-27                         0
# 27-45                         0
# 45-55                         0
# 55-65                         0
# 65+                           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['district', 'male', 'female', 'germans', 'foreigners', 'single',
#        'married', 'widowed', 'divorced', 'civil_partnership',
#        'evangelische_kirchen', 'römisch_katholische_kirche',
#        'religion_other_or_none', '0-6', '6-15', '15-18', '18-27', '27-45',
#        '45-55', '55-65', '65+'],
#       dtype='object')

# %%
# Mapping of District Name to ID
district_id_map = {
    'mitte': '01',
    'friedrichshain-kreuzberg': '02',
    'pankow': '03',
    'charlottenburg-wilmersdorf': '04',
    'spandau': '05',
    'steglitz-zehlendorf': '06',
    'tempelhof-schöneberg': '07',
    'neukölln': '08',
    'treptow-köpenick': '09',
    'marzahn-hellersdorf': '10',
    'lichtenberg': '11',
    'reinickendorf': '12'
}

# %%
# Assign district_id using map
df['district_id'] = df['district'].map(district_id_map)

# %%
df
# Out:
#                       district    male  female  germans  foreigners  single  \
# 0                        mitte  204542  192462   249053      147951  240196
# 1     friedrichshain-kreuzberg  150002  142622   202632       89992  188392
# 2                       pankow  209773  217503   343105       84171  246687
# 3   charlottenburg-wilmersdorf  166037  177463   249994       93506  176967
# 4                      spandau  127361  131916   189914       69363  125965
# 5          steglitz-zehlendorf  146477  163567   254706       55338  143312
# 6         tempelhof-schöneberg  175519  181440   273377       83582  183234
# 7                     neukölln  164886  164602   235693       93795  180627
# 8             treptow-köpenick  147067  150169   246400       50836  153570
# 9          marzahn-hellersdorf  146277  147814   236448       57643  145307
# 10                 lichtenberg  156934  158614   235846       79702  174707
# ...

# %%
df.describe()
# Out:
#                 male         female        germans     foreigners  \
# count      12.000000      12.000000      12.000000      12.000000
# mean   160887.500000  163874.583333  243772.250000   80989.833333
# std     25321.599111   24838.434266   39293.813166   25895.268809
# min    127361.000000  131916.000000  189914.000000   50836.000000
# 25%    146427.000000  146516.000000  228794.500000   63910.000000
# 50%    153468.000000  161090.500000  241424.000000   81642.000000
# 75%    168407.500000  178457.250000  251172.000000   90870.500000
# max    209773.000000  217503.000000  343105.000000  147951.000000
#
#               single        married       widowed      divorced  \
# count      12.000000      12.000000     12.000000     12.000000
# mean   174168.000000  106447.250000  16205.916667  26857.666667
# std     38547.381241   14387.273285   3281.888549   3752.012002
# min    125965.000000   76076.000000   7369.000000  19227.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   district                    12 non-null     object
#  1   male                        12 non-null     int64
#  2   female                      12 non-null     int64
#  3   germans                     12 non-null     int64
#  4   foreigners                  12 non-null     int64
#  5   single                      12 non-null     int64
#  6   married                     12 non-null     int64
#  7   widowed                     12 non-null     int64
#  8   divorced                    12 non-null     int64
#  9   civil_partnership           12 non-null     int64
#  10  evangelische_kirchen        12 non-null     int64
#  11  römisch_katholische_kirche  12 non-null     int64
#  12  religion_other_or_none      12 non-null     int64
# ...

# %%
# Export the cleaned and transformed DataFrame to a CSV file
df.to_csv('berlin_neighbourhood_population.csv', index=False)
