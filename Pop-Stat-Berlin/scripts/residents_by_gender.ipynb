# %%
import pandas as pd

# %%
# Load raw data
df = pd.read_csv('/Users/haritha/Downloads/Berlin_pop_stats - Berlin residents by gender.csv')

# %%
df.head()
# Out:
#   last_updated_date  total_residents  total_residents_male  \
# 0        31-12-2000          3331232               1616893
# 1        31-12-2001          3337232               1620941
# 2        31-12-2002          3336248               1621209
# 3        31-12-2003          3330242               1619735
# 4        31-12-2004          3333108               1623246
#
#    total_residents_female  german_residents  german_residents_male  \
# 0                 1714339           2896115                1383190
# 1                 1716291           2896886                1386122
# 2                 1715039           2893694                1387171
# 3                 1710507           2886215                1386302
# 4                 1709862           2882208                1386858
#
#    german_residents_female  foreigner_residents  foreigner_residents_male  \
# 0                  1512925               435117                    233703
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   last_updated_date           25 non-null     datetime64[ns]
#  1   total_residents             25 non-null     int64
#  2   total_residents_male        25 non-null     int64
#  3   total_residents_female      25 non-null     int64
#  4   german_residents            25 non-null     int64
#  5   german_residents_male       25 non-null     int64
#  6   german_residents_female     25 non-null     int64
#  7   foreigner_residents         25 non-null     int64
#  8   foreigner_residents_male    25 non-null     int64
#  9   foreginer_residents_female  25 non-null     int64
# dtypes: datetime64[ns](1), int64(9)
# memory usage: 2.1 KB

# %%
print(df['last_updated_date'].head(10))
# Out:
# 0    31-12-2000
# 1    31-12-2001
# 2    31-12-2002
# 3    31-12-2003
# 4    31-12-2004
# 5    31-12-2005
# 6    31-12-2006
# 7    31-12-2007
# 8    31-12-2008
# 9    31-12-2009
# Name: last_updated_date, dtype: object

# %%
# Convert the 'last_updated_date' column to datetime format
df['last_updated_date'] = pd.to_datetime(df['last_updated_date'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   last_updated_date           25 non-null     datetime64[ns]
#  1   total_residents             25 non-null     int64
#  2   total_residents_male        25 non-null     int64
#  3   total_residents_female      25 non-null     int64
#  4   german_residents            25 non-null     int64
#  5   german_residents_male       25 non-null     int64
#  6   german_residents_female     25 non-null     int64
#  7   foreigner_residents         25 non-null     int64
#  8   foreigner_residents_male    25 non-null     int64
#  9   foreginer_residents_female  25 non-null     int64
# dtypes: datetime64[ns](1), int64(9)
# memory usage: 2.1 KB

# %%
# Display the number of missing (null) values in each column of the DataFrame
df.isnull().sum()
# Out:
# last_updated_date             0
# total_residents               0
# total_residents_male          0
# total_residents_female        0
# german_residents              0
# german_residents_male         0
# german_residents_female       0
# foreigner_residents           0
# foreigner_residents_male      0
# foreginer_residents_female    0
# dtype: int64

# %%
# Rename the column 'foreginer_residents_female' to the correct name 'foreigner_residents_female' in the DataFrame
df.rename(columns={'foreginer_residents_female': 'foreigner_residents_female'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   last_updated_date           25 non-null     datetime64[ns]
#  1   total_residents             25 non-null     int64
#  2   total_residents_male        25 non-null     int64
#  3   total_residents_female      25 non-null     int64
#  4   german_residents            25 non-null     int64
#  5   german_residents_male       25 non-null     int64
#  6   german_residents_female     25 non-null     int64
#  7   foreigner_residents         25 non-null     int64
#  8   foreigner_residents_male    25 non-null     int64
#  9   foreigner_residents_female  25 non-null     int64
# dtypes: datetime64[ns](1), int64(9)
# memory usage: 2.1 KB

# %%
df
# Out:
#    last_updated_date  total_residents  total_residents_male  \
# 0         2000-12-31          3331232               1616893
# 1         2001-12-31          3337232               1620941
# 2         2002-12-31          3336248               1621209
# 3         2003-12-31          3330242               1619735
# 4         2004-12-31          3333108               1623246
# 5         2005-12-31          3339436               1628776
# 6         2006-12-31          3348805               1635848
# 7         2007-12-31          3353858               1638743
# 8         2008-12-31          3362843               1643408
# 9         2009-12-31          3369672               1646698
# 10        2010-12-31          3387562               1655631
# 11        2011-12-31          3427114               1676434
# 12        2012-12-31          3469621               1699007
# 13        2013-12-31          3517424               1725465
# 14        2014-12-31          3562166               1750121
# ...

# %%
# Generates summary statistics 
df.describe()
# Out:
#          last_updated_date  total_residents  total_residents_male  \
# count                   25     2.500000e+01          2.500000e+01
# mean   2012-12-30 15:21:36     3.539536e+06          1.737523e+06
# min    2000-12-31 00:00:00     3.330242e+06          1.616893e+06
# 25%    2006-12-31 00:00:00     3.348805e+06          1.635848e+06
# 50%    2012-12-31 00:00:00     3.469621e+06          1.699007e+06
# 75%    2018-12-31 00:00:00     3.748148e+06          1.855248e+06
# max    2024-12-31 00:00:00     3.897145e+06          1.930650e+06
# std                    NaN     2.062674e+05          1.133336e+05
#
#        total_residents_female  german_residents  german_residents_male  \
# count            2.500000e+01      2.500000e+01           2.500000e+01
# mean             1.802013e+06      2.937649e+06           1.424189e+06
# min              1.709862e+06      2.878881e+06           1.383190e+06
# 25%              1.715115e+06      2.893694e+06           1.390817e+06
# ...

# %%
df
# Out:
#    last_updated_date  total_residents  total_residents_male  \
# 0         2000-12-31          3331232               1616893
# 1         2001-12-31          3337232               1620941
# 2         2002-12-31          3336248               1621209
# 3         2003-12-31          3330242               1619735
# 4         2004-12-31          3333108               1623246
# 5         2005-12-31          3339436               1628776
# 6         2006-12-31          3348805               1635848
# 7         2007-12-31          3353858               1638743
# 8         2008-12-31          3362843               1643408
# 9         2009-12-31          3369672               1646698
# 10        2010-12-31          3387562               1655631
# 11        2011-12-31          3427114               1676434
# 12        2012-12-31          3469621               1699007
# 13        2013-12-31          3517424               1725465
# 14        2014-12-31          3562166               1750121
# ...

# %%
# Export the cleaned and transformed DataFrame to a CSV file
df.to_csv('residents_by_gender_transformed.csv', index=False)
