# %%
import pandas as pd

# %%
# Load the CSV file
df = pd.read_csv('/Users/haritha/Downloads/Berlin_pop_stats - Berlin foreign residents by district.csv')

# %%
df.head()
# Out:
#   last_updated_date  Berlin   Mitte  Friedrichs-\nhain-\nKreuz-\nberg  Pankow  \
# 0        31-12-2013  538729  101204                             63644   33056
# 1        31-12-2014  573342  107069                             65364   37472
# 2        31-12-2015  621075  113210                             68366   41620
# 3        31-12-2016  676741  120931                             71932   47683
# 4        31-12-2017  711282  126075                             74449   51711
#
#    Charlotten-\nburg-\nWilmers-\ndorf  Spandau  Steglitz-\nZehlen-\ndorf  \
# 0                               68082    28761                     36076
# 1                               71480    32159                     36974
# 2                               75870    37207                     38180
# 3                               81241    43144                     41163
# 4                               82730    45906                     43142
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   last_updated_date                12 non-null     object
#  1   Berlin                           12 non-null     int64
#  2   Mitte                            12 non-null     int64
#  3   Friedrichs-
# hain-
# Kreuz-
# berg    12 non-null     int64
#  4   Pankow                           12 non-null     int64
#  5   Charlotten-
# burg-
# Wilmers-
# dorf  12 non-null     int64
#  6   Spandau                          12 non-null     int64
#  7   Steglitz-
# Zehlen-
# dorf           12 non-null     int64
#  8   Tempel-
# hof-
# Schöne-
# berg        12 non-null     int64
#  9   Neukölln                         12 non-null     int64
#  10  Treptow-
# Köpenick                12 non-null     int64
#  11  Marzahn-
# Hellers-
# ...

# %%
# Convert the 'last_updated_date' column to datetime format
df['last_updated_date'] = pd.to_datetime(df['last_updated_date'], errors='coerce')

# %%
df['last_updated_date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# Clean column names by removing newlines and hyphens, then converting to lowercase

df.columns = df.columns.str.replace('\n', '', regex=True) \
                       .str.replace('-', '', regex=True) \
                       .str.lower()

# %%
df.columns
# Out:
# Index(['last_updated_date', 'berlin', 'mitte', 'friedrichshainkreuzberg',
#        'pankow', 'charlottenburgwilmersdorf', 'spandau', 'steglitzzehlendorf',
#        'tempelhofschöneberg', 'neukölln', 'treptowköpenick',
#        'marzahnhellersdorf', 'lichtenberg', 'reinickendorf'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   last_updated_date          12 non-null     datetime64[ns]
#  1   berlin                     12 non-null     int64
#  2   mitte                      12 non-null     int64
#  3   friedrichshainkreuzberg    12 non-null     int64
#  4   pankow                     12 non-null     int64
#  5   charlottenburgwilmersdorf  12 non-null     int64
#  6   spandau                    12 non-null     int64
#  7   steglitzzehlendorf         12 non-null     int64
#  8   tempelhofschöneberg        12 non-null     int64
#  9   neukölln                   12 non-null     int64
#  10  treptowköpenick            12 non-null     int64
#  11  marzahnhellersdorf         12 non-null     int64
#  12  lichtenberg                12 non-null     int64
# ...

# %%
# Display the number of missing (null) values in each column of the DataFrame
df.isnull().sum()
# Out:
# last_updated_date            0
# berlin                       0
# mitte                        0
# friedrichshainkreuzberg      0
# pankow                       0
# charlottenburgwilmersdorf    0
# spandau                      0
# steglitzzehlendorf           0
# tempelhofschöneberg          0
# neukölln                     0
# treptowköpenick              0
# marzahnhellersdorf           0
# lichtenberg                  0
# reinickendorf                0
# dtype: int64

# %%
df
# Out:
#    last_updated_date  berlin   mitte  friedrichshainkreuzberg  pankow  \
# 0         2013-12-31  538729  101204                    63644   33056
# 1         2014-12-31  573342  107069                    65364   37472
# 2         2015-12-31  621075  113210                    68366   41620
# 3         2016-12-31  676741  120931                    71932   47683
# 4         2017-12-31  711282  126075                    74449   51711
# 5         2018-12-31  748472  131070                    78890   56249
# 6         2019-12-31  777345  132815                    80829   59105
# 7         2020-12-31  789076  130851                    81363   61151
# 8         2021-12-31  811334  134342                    82495   65470
# 9         2022-12-31  900144  144990                    87944   75586
# 10        2023-12-31  946369  148409                    89525   81457
# 11        2024-12-31  971878  147951                    89992   84171
#
# ...

# %%
df.describe()
# Out:
#          last_updated_date        berlin          mitte  \
# count                   12      12.00000      12.000000
# mean   2019-07-01 18:00:00  755482.25000  128243.083333
# min    2013-12-31 00:00:00  538729.00000  101204.000000
# 25%    2016-09-30 12:00:00  662824.50000  119000.750000
# 50%    2019-07-01 12:00:00  762908.50000  130960.500000
# 75%    2022-04-01 06:00:00  833536.50000  137004.000000
# max    2024-12-31 00:00:00  971878.00000  148409.000000
# std                    NaN  139916.58969   15409.654179
#
#        friedrichshainkreuzberg        pankow  charlottenburgwilmersdorf  \
# count                12.000000     12.000000                  12.000000
# mean              77899.416667  57894.250000               82982.750000
# min               63644.000000  33056.000000               68082.000000
# 25%               71040.500000  46167.250000               79833.000000
# 50%               79859.500000  57677.000000               83987.000000
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# dtype: bool

# %%
df
# Out:
#    last_updated_date  berlin   mitte  friedrichshainkreuzberg  pankow  \
# 0         2013-12-31  538729  101204                    63644   33056
# 1         2014-12-31  573342  107069                    65364   37472
# 2         2015-12-31  621075  113210                    68366   41620
# 3         2016-12-31  676741  120931                    71932   47683
# 4         2017-12-31  711282  126075                    74449   51711
# 5         2018-12-31  748472  131070                    78890   56249
# 6         2019-12-31  777345  132815                    80829   59105
# 7         2020-12-31  789076  130851                    81363   61151
# 8         2021-12-31  811334  134342                    82495   65470
# 9         2022-12-31  900144  144990                    87944   75586
# 10        2023-12-31  946369  148409                    89525   81457
# 11        2024-12-31  971878  147951                    89992   84171
#
# ...

# %%
# Export the cleaned and transformed DataFrame to a CSV file
df.to_csv('foreign_residents_by_district_transformed.csv', index=False)
