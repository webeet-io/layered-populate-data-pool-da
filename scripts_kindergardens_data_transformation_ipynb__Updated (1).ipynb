# %%
import pandas as pd
from geopy.geocoders import Nominatim
from time import sleep

# -------- Paths --------
kg_path = "kindergartens_berlin_final (1).csv"

# -------- Load data --------
kg = pd.read_csv(kg_path)

# 1) Rename id -> kindergarten_id (if present)
if "id" in kg.columns and "kindergarten_id" not in kg.columns:
    kg = kg.rename(columns={"id": "kindergarten_id"}).copy()

# 2) Official Berlin district (Bezirk) -> official district_id map
DISTRICT_ID_MAP = {
    "Mitte": "11001001",
    "Friedrichshain-Kreuzberg": "11002002",
    "Pankow": "11003003",
    "Charlottenburg-Wilmersdorf": "11004004",
    "Spandau": "11005005",
    "Steglitz-Zehlendorf": "11006006",
    "Tempelhof-Schöneberg": "11007007",
    "Neukölln": "11008008",
    "Treptow-Köpenick": "11009009",
    "Marzahn-Hellersdorf": "11010010",
    "Lichtenberg": "11011011",
    "Reinickendorf": "11012012",
}
OFFICIAL_BEZIRKE = set(DISTRICT_ID_MAP.keys())

# 3) Ortsteil (locality) -> Bezirk mapping (no postcodes)
ortsteil_to_bezirk = {
    # Mitte
    "Moabit": "Mitte", "Tiergarten": "Mitte", "Gesundbrunnen": "Mitte", "Wedding": "Mitte", "Hansaviertel": "Mitte",
    # Reinickendorf
    "Wittenau": "Reinickendorf", "Tegel": "Reinickendorf", "Hermsdorf": "Reinickendorf", "Frohnau": "Reinickendorf",
    "Konradshöhe": "Reinickendorf", "Heiligensee": "Reinickendorf", "Waidmannslust": "Reinickendorf",
    "Märkisches Viertel": "Reinickendorf", "Borsigwalde": "Reinickendorf",
    # Charlottenburg-Wilmersdorf
    "Charlottenburg": "Charlottenburg-Wilmersdorf", "Charlottenburg-Nord": "Charlottenburg-Wilmersdorf",
    "Wilmersdorf": "Charlottenburg-Wilmersdorf", "Schmargendorf": "Charlottenburg-Wilmersdorf",
    "Grunewald": "Charlottenburg-Wilmersdorf", "Halensee": "Charlottenburg-Wilmersdorf",
    "Westend": "Charlottenburg-Wilmersdorf",
    # Tempelhof-Schöneberg
    "Tempelhof": "Tempelhof-Schöneberg", "Schöneberg": "Tempelhof-Schöneberg", "Friedenau": "Tempelhof-Schöneberg",
    "Mariendorf": "Tempelhof-Schöneberg", "Marienfelde": "Tempelhof-Schöneberg", "Lichtenrade": "Tempelhof-Schöneberg",
    # Steglitz-Zehlendorf
    "Steglitz": "Steglitz-Zehlendorf", "Lichterfelde": "Steglitz-Zehlendorf", "Zehlendorf": "Steglitz-Zehlendorf",
    "Dahlem": "Steglitz-Zehlendorf", "Nikolassee": "Steglitz-Zehlendorf", "Wannsee": "Steglitz-Zehlendorf",
    "Schlachtensee": "Steglitz-Zehlendorf", "Lankwitz": "Steglitz-Zehlendorf",
    # Pankow
    "Prenzlauer Berg": "Pankow", "Weißensee": "Pankow", "Niederschönhausen": "Pankow", "Pankow": "Pankow",
    "Heinersdorf": "Pankow", "Karow": "Pankow", "Buch": "Pankow", "Französisch Buchholz": "Pankow",
    "Wilhelmsruh": "Pankow", "Rosenthal": "Pankow",
    # Neukölln
    "Britz": "Neukölln", "Buckow": "Neukölln", "Rudow": "Neukölln", "Gropiusstadt": "Neukölln",
    # Treptow-Köpenick
    "Alt-Treptow": "Treptow-Köpenick", "Plänterwald": "Treptow-Köpenick", "Baumschulenweg": "Treptow-Köpenick",
    "Niederschöneweide": "Treptow-Köpenick", "Johannisthal": "Treptow-Köpenick", "Adlershof": "Treptow-Köpenick",
    "Oberschöneweide": "Treptow-Köpenick", "Spindlersfeld": "Treptow-Köpenick", "Altglienicke": "Treptow-Köpenick",
    "Bohnsdorf": "Treptow-Köpenick", "Grünau": "Treptow-Köpenick", "Köpenick": "Treptow-Köpenick",
    "Friedrichshagen": "Treptow-Köpenick", "Rahnsdorf": "Treptow-Köpenick", "Schmöckwitz": "Treptow-Köpenick",
    # Marzahn-Hellersdorf
    "Marzahn": "Marzahn-Hellersdorf", "Hellersdorf": "Marzahn-Hellersdorf", "Biesdorf": "Marzahn-Hellersdorf",
    "Kaulsdorf": "Marzahn-Hellersdorf", "Mahlsdorf": "Marzahn-Hellersdorf", "Hönow": "Marzahn-Hellersdorf",
    # Lichtenberg
    "Fennpfuhl": "Lichtenberg", "Rummelsburg": "Lichtenberg", "Friedrichsfelde": "Lichtenberg",
    "Karlshorst": "Lichtenberg", "Alt-Hohenschönhausen": "Lichtenberg", "Neu-Hohenschönhausen": "Lichtenberg",
    "Malchow": "Lichtenberg", "Wartenberg": "Lichtenberg", "Falkenberg": "Lichtenberg",
    # Friedrichshain-Kreuzberg
    "Friedrichshain": "Friedrichshain-Kreuzberg", "Kreuzberg": "Friedrichshain-Kreuzberg",
    # Spandau
    "Haselhorst": "Spandau", "Siemensstadt": "Spandau", "Staaken": "Spandau", "Wilhelmstadt": "Spandau",
    "Hakenfelde": "Spandau", "Falkenhagener Feld": "Spandau", "Kladow": "Spandau", "Gatow": "Spandau",
}

def _norm(s):
    if pd.isna(s):
        return None
    return str(s).strip()

# Normalize raw fields
kg["district_raw"] = kg.get("district")
kg["neighborhood_raw"] = kg.get("neighborhood")
kg["district_norm"] = kg["district_raw"].apply(_norm)
kg["neighborhood_norm"] = kg["neighborhood_raw"].apply(_norm)

# 4) Resolve official Bezirk (district = 12 only)
def resolve_bezirk(row):
    d = row["district_norm"]
    n = row["neighborhood_norm"]
    if d in OFFICIAL_BEZIRKE:
        return d
    if n in OFFICIAL_BEZIRKE:
        return n
    if d in ortsteil_to_bezirk:
        return ortsteil_to_bezirk[d]
    if n in ortsteil_to_bezirk:
        return ortsteil_to_bezirk[n]
    return None

kg["district"] = kg.apply(resolve_bezirk, axis=1)
kg["district_id"] = kg["district"].map(DISTRICT_ID_MAP)

# 5) Reverse geocode neighborhood from lat/lon (Ortsteil/Kiez only)
#    Priority: suburb -> neighbourhood -> quarter -> city_district
geolocator = Nominatim(user_agent="berlin_kindergartens_neighborhood_extractor")
_cache = {}  # (lat, lon) -> neighborhood

def get_neighborhood(lat, lon):
    key = (lat, lon)
    if key in _cache:
        return _cache[key]
    try:
        location = geolocator.reverse((lat, lon), exactly_one=True, language="de")
        sleep(1)  # respect Nominatim rate limits
        if not location:
            _cache[key] = None
            return None
        addr = location.raw.get("address", {}) or {}
        neigh = (
            addr.get("suburb")
            or addr.get("neighbourhood")
            or addr.get("quarter")
            or addr.get("city_district")
        )
        neigh = neigh.strip() if isinstance(neigh, str) else None
        _cache[key] = neigh
        return neigh
    except Exception:
        _cache[key] = None
        return None

# Fill/overwrite neighborhood using reverse geocoding when lat/lon present
if "latitude" in kg.columns and "longitude" in kg.columns:
    kg["neighborhood"] = kg.apply(
        lambda r: get_neighborhood(r["latitude"], r["longitude"])
        if pd.notna(r.get("latitude")) and pd.notna(r.get("longitude"))
        else None,
        axis=1
    )
else:
    # If no coordinates, keep existing neighborhood values (but they may be messy)
    kg["neighborhood"] = kg["neighborhood_norm"]

# 6) Clean postal codes: replace integer 0 with "Unknown"
if "postal_code" in kg.columns:
    kg["postal_code"] = kg["postal_code"].replace(0, "Unknown")

# 7) Final column order (removed phone_number, email, website, coordinates)
final_cols = [
    "kindergarten_id", "district_id", "name", "address", "postal_code",
    "latitude", "longitude", "neighborhood", "district",
    "operator", "capacity", "source", "created_at", "updated_at"
]
for c in final_cols:
    if c not in kg.columns:
        kg[c] = None

final_df = kg[final_cols]

# 8) Quality checks
print("Total rows:", len(final_df))
print("Rows missing district:", final_df["district"].isna().sum())
print("Rows missing district_id:", final_df["district_id"].isna().sum())
print("Rows missing neighborhood (after geocoding):", final_df["neighborhood"].isna().sum())

# 9) Save output
out_path = "kindergartens_berlin_final_ready.csv"
final_df.to_csv(out_path, index=False)
print("Saved:", out_path)
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4767411&lon=13.3258251&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4685223&lon=13.3325044&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5006833&lon=13.3587022&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5916324&lon=13.3258382&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5504682&lon=13.2698094&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.3853393&lon=13.4057689&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.504493&lon=13.2870406&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.447636&lon=13.3274376&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.453963&lon=13.144791&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5082915&lon=13.3139551&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4939543&lon=13.3268807&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4939543&lon=13.3268807&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5414858&lon=13.267403&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4561079&lon=13.3186112&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4053643&lon=13.4022689&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.529794&lon=13.3156844&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5466679&lon=13.4152842&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.575228&lon=13.3545645&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4941875&lon=13.4189042&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4941875&lon=13.4189042&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5876141&lon=13.4027318&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5876141&lon=13.4027318&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5357939&lon=13.4099167&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5336213&lon=13.433538&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4957971&lon=13.2661489&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5477809&lon=13.208227&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5176797&lon=13.2942317&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5176797&lon=13.2942317&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5216126&lon=13.3356677&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5216126&lon=13.3356677&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5164659&lon=13.1952586&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4527716&lon=13.6266929&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5036346&lon=13.2922663&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5129861&lon=13.4624114&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5058571&lon=13.283573&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4749536&lon=13.4259728&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4945776&lon=13.4142671&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5087759&lon=13.3163335&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5087759&lon=13.3163335&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4580628&lon=13.3129269&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4136709&lon=13.3609857&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.3979214&lon=13.1456997&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4821774&lon=13.4303005&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5305594&lon=13.3310802&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5279034&lon=13.4487198&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5268144&lon=13.3322242&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.552623&lon=13.4094616&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4379236&lon=13.3310448&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5240603&lon=13.1947021&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5469066&lon=13.3515249&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4164048&lon=13.3725083&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4952999&lon=13.3593122&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5549151&lon=13.3494033&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5323176&lon=13.2021686&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4757679&lon=13.3380896&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.467184&lon=13.5067504&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5499228&lon=13.4051777&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5499228&lon=13.4051777&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4935829&lon=13.3503378&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5539049&lon=13.5035683&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5223529&lon=13.584299&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5333274&lon=13.4327706&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4752501&lon=13.3330522&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5425889&lon=13.3626312&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.495803&lon=13.4265669&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.567623&lon=13.422091&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5293522&lon=13.3999347&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5293522&lon=13.3999347&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5226583&lon=13.4526872&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5204056&lon=13.4603709&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5045328&lon=13.2945456&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5218727&lon=13.4017995&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5218727&lon=13.4017995&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5341872&lon=13.4065682&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5341872&lon=13.4065682&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5129253&lon=13.3124965&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4208647&lon=13.5365952&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5469016&lon=13.3689555&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5469016&lon=13.3689555&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5565472&lon=13.3882364&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5985524&lon=13.3431242&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5601303&lon=13.3608223&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.6010903&lon=13.42967&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4581456&lon=13.3827437&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4581456&lon=13.3827437&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5420205&lon=13.3610639&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.450765&lon=13.3218198&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4935137&lon=13.3511617&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4889997&lon=13.3493536&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5208599&lon=13.4325745&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.444789&lon=13.372418&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4347158&lon=13.3480029&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5716276&lon=13.3130128&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.386116&lon=13.3977561&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4889788&lon=13.4004521&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5204869&lon=13.3196886&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4366286&lon=13.3158615&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5308439&lon=13.3477391&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.508407&lon=13.4700245&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.4761959&lon=13.4332349&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5034295&lon=13.4817456&format=json&accept-language=de&addressdetails=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /reverse?lat=52.5543741&lon=13.4181903&format=json&accept-language=de&addressdetails=1
# Total rows: 2298
# Rows missing district: 636
# Rows missing district_id: 636
# Rows missing neighborhood (after geocoding): 1165
# Saved: kindergartens_berlin_final_ready.csv
